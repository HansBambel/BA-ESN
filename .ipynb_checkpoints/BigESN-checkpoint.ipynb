# %%
import Parity_Data_Generator
import numpy as np
from pyESN import ESN
import matplotlib.pyplot as plt
import time

rng = np.random.RandomState(42)

N = 4000   
n = 3       # n-parity
timescale=50

start_time = time.time()
# produce Data
bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, randomstate=rng)

# Divide in training and test data
traintest_cutoff = int(np.ceil(0.7 * len(bits)))
train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
# train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.008003473281860352 seconds ---

# %%
def runSomeConfigs(spectral_rad, leak_r, d_t, train_b, test_b, train_t, test_t, n_neurons):
#     print("Spectral-radius:",spectral_rad, "leak-rate:", leak_r)
    nParityESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=n_neurons,  # from 200 onwards test error decreases significantly
                          spectral_radius=spectral_rad,  # high spectral rad is better (high fluctuations 0->1->0)
                          leak_rate= leak_r,   # adjust leak_rate
                          delta_t= d_t,
                          sparsity=0.95,
                          noise=0.01,
                          input_shift=0,
                          input_scaling=3,  # 3 seems to be fine. Maybe use lower
                          teacher_forcing=False,
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          random_state=rng,
                          silent=False)
    # print(np.shape(bits),np.shape(parity),np.shape(target))
    nParityESN.fit(train_b, train_t)
    pred_test = nParityESN.predict(test_b)

    predictedParity = pred_test 
    
    print("Testing error")
    test_error = np.sqrt(np.mean((predictedParity - test_t) ** 2))
    print(test_error)
    return test_error

def produceTrainingData(i):
    bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(i))

    # Divide in training and test data
    traintest_cutoff = int(np.ceil(0.7 * len(bits)))
    train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
#     train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
    train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
    return train_bits, test_bits, train_targets, test_targets

# %%
trials=1
sp_rad = np.linspace(0.1, 1, num=10)
l_rate = np.linspace(0.1, 1, num=10)
num_neurons = 350
delta_t = [0.05, 0.1, 0.15, 0.2]

run_time = time.time()
iterations, iterationcount = trials*len(sp_rad)*len(l_rate)*len(delta_t), 0

delta_t_error = []
for dt in delta_t:
    all_errors = [{} for _ in range(trials)] # empty dict
    for i in range(trials):
        errors = []
        # produce training and testing data
        train_bits, test_bits, train_target, test_target = produceTrainingData(i)
        for l in l_rate:
            for s in sp_rad:
                print("Neurons:", num_neurons,"Leak-rate:",l,"Spectral-radius:",s,"Delta_t:",dt)
                errors.append(runSomeConfigs(s,l,dt, train_bits, test_bits, train_target, test_target, num_neurons))
                iterationcount = iterationcount + 1
                print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
        ## Save leak-rate,spectral-radius and error in dictionary
        all_errors[i] = errors

    ### Average errors
    errors_averaged_over_trials = np.zeros(100)
    for i in range(len(all_errors)):
        e = all_errors[i]
        errors_averaged_over_trials = np.add(errors_averaged_over_trials, np.array(e))
    errors_averaged_over_trials = np.divide(errors_averaged_over_trials, trials)
    
    delta_t_error.append(errors_averaged_over_trials)
    
print("Total time:")
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.451087767958
# Testing error
# 0.455416264059
# --- Progress: 0.25% --- 0.29 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.432986642452
# Testing error
# 0.441961150465
# --- Progress: 0.50% --- 0.56 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.418191564751
# Testing error
# 0.446066278281
# --- Progress: 0.75% --- 0.84 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.41929250403
# Testing error
# 0.454185917738
# --- Progress: 1.00% --- 1.12 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.4015715235
# Testing error
# 0.472619874031
# --- Progress: 1.25% --- 1.40 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.423707493129
# Testing error
# 0.553521565819
# --- Progress: 1.50% --- 1.67 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.423958908231
# Testing error
# 0.519073633084
# --- Progress: 1.75% --- 1.95 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.436615245658
# Testing error
# 0.489740887532
# --- Progress: 2.00% --- 2.22 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.446728166196
# Testing error
# 0.512525740188
# --- Progress: 2.25% --- 2.50 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.443387374322
# Testing error
# 0.514631223956
# --- Progress: 2.50% --- 2.78 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.408462428783
# Testing error
# 0.412766514345
# --- Progress: 2.75% --- 3.06 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.360141368905
# Testing error
# 0.363268430969
# --- Progress: 3.00% --- 3.34 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.312267220492
# Testing error
# 0.314711053595
# --- Progress: 3.25% --- 3.61 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.297618648413
# Testing error
# 0.329456597031
# --- Progress: 3.50% --- 3.89 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.293453142766
# Testing error
# 0.352417179352
# --- Progress: 3.75% --- 4.17 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.301244213858
# Testing error
# 0.361142803703
# --- Progress: 4.00% --- 4.44 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.336312221777
# Testing error
# 0.444410623794
# --- Progress: 4.25% --- 4.72 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.342327119918
# Testing error
# 0.396184014759
# --- Progress: 4.50% --- 5.00 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.337896319521
# Testing error
# 0.449268563982
# --- Progress: 4.75% --- 5.28 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.372663482437
# Testing error
# 0.448486192599
# --- Progress: 5.00% --- 5.56 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.381390390717
# Testing error
# 0.381369895983
# --- Progress: 5.25% --- 5.83 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.32608546898
# Testing error
# 0.325008368563
# --- Progress: 5.50% --- 6.10 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.291744426314
# Testing error
# 0.29230417796
# --- Progress: 5.75% --- 6.37 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.278931992783
# Testing error
# 0.279855467358
# --- Progress: 6.00% --- 6.65 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.237544347515
# Testing error
# 0.267811263786
# --- Progress: 6.25% --- 6.92 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.246217102332
# Testing error
# 0.280502809855
# --- Progress: 6.50% --- 7.20 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.226222990894
# Testing error
# 0.246131258648
# --- Progress: 6.75% --- 7.47 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.257641128399
# Testing error
# 0.336569495055
# --- Progress: 7.00% --- 7.75 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.280006635544
# Testing error
# 0.339308660856
# --- Progress: 7.25% --- 8.02 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.305962584263
# Testing error
# 0.363824143884
# --- Progress: 7.50% --- 8.30 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.385115962185
# Testing error
# 0.38442698337
# --- Progress: 7.75% --- 8.58 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.327282533995
# Testing error
# 0.325309338502
# --- Progress: 8.00% --- 8.85 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.291619201287
# Testing error
# 0.292573198307
# --- Progress: 8.25% --- 9.12 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.271865713367
# Testing error
# 0.27321407262
# --- Progress: 8.50% --- 9.39 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.252470760098
# Testing error
# 0.255156509587
# --- Progress: 8.75% --- 9.66 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.230015359868
# Testing error
# 0.237590322388
# --- Progress: 9.00% --- 9.94 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.213670248327
# Testing error
# 0.233150273378
# --- Progress: 9.25% --- 10.22 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.226951931095
# Testing error
# 0.26726177424
# --- Progress: 9.50% --- 10.49 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.215886941481
# Testing error
# 0.241979565791
# --- Progress: 9.75% --- 10.76 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.231111948358
# Testing error
# 0.279695405763
# --- Progress: 10.00% --- 11.03 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.397750114965
# Testing error
# 0.399161811015
# --- Progress: 10.25% --- 11.30 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.347247633502
# Testing error
# 0.345567138205
# --- Progress: 10.50% --- 11.58 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.300912523087
# Testing error
# 0.300870484381
# --- Progress: 10.75% --- 11.86 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.289741512248
# Testing error
# 0.28997473641
# --- Progress: 11.00% --- 12.14 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.25395036423
# Testing error
# 0.255688558849
# --- Progress: 11.25% --- 12.42 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.239112348937
# Testing error
# 0.24221760663
# --- Progress: 11.50% --- 12.70 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.212246851144
# Testing error
# 0.215420232089
# --- Progress: 11.75% --- 12.97 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.198673845189
# Testing error
# 0.221397759321
# --- Progress: 12.00% --- 13.25 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.205283012779
# Testing error
# 0.231561607249
# --- Progress: 12.25% --- 13.52 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.223970211321
# Testing error
# 0.30968398668
# --- Progress: 12.50% --- 13.81 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.437384651262
# Testing error
# 0.44096475389
# --- Progress: 12.75% --- 14.09 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.389780154648
# Testing error
# 0.391043870492
# --- Progress: 13.00% --- 14.38 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.340654047342
# Testing error
# 0.340045998008
# --- Progress: 13.25% --- 14.65 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.296968476809
# Testing error
# 0.299101777005
# --- Progress: 13.50% --- 14.93 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.271651439847
# Testing error
# 0.273657622146
# --- Progress: 13.75% --- 15.20 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.24640457679
# Testing error
# 0.248533222809
# --- Progress: 14.00% --- 15.49 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.229255717196
# Testing error
# 0.233051476311
# --- Progress: 14.25% --- 15.77 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.202249024127
# Testing error
# 0.207093684775
# --- Progress: 14.50% --- 16.04 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.192636747894
# Testing error
# 0.202557686968
# --- Progress: 14.75% --- 16.31 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.195801048331
# Testing error
# 0.216648543123
# --- Progress: 15.00% --- 16.58 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.470413435409
# Testing error
# 0.477105591736
# --- Progress: 15.25% --- 16.86 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.41805621152
# Testing error
# 0.423240685075
# --- Progress: 15.50% --- 17.12 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.368704594846
# Testing error
# 0.369257658472
# --- Progress: 15.75% --- 17.40 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.326886886435
# Testing error
# 0.32808945295
# --- Progress: 16.00% --- 17.68 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.291308083639
# Testing error
# 0.293851374061
# --- Progress: 16.25% --- 17.95 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.272878610772
# Testing error
# 0.276193784973
# --- Progress: 16.50% --- 18.21 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.254420622333
# Testing error
# 0.258142630446
# --- Progress: 16.75% --- 18.50 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.236518699575
# Testing error
# 0.239508681085
# --- Progress: 17.00% --- 18.78 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.21648148704
# Testing error
# 0.221652387597
# --- Progress: 17.25% --- 19.06 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.196499779597
# Testing error
# 0.206341657375
# --- Progress: 17.50% --- 19.33 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.489369444909
# Testing error
# 0.495475719431
# --- Progress: 17.75% --- 19.61 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.455789326039
# Testing error
# 0.464744427546
# --- Progress: 18.00% --- 19.89 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.414838683284
# Testing error
# 0.421501402942
# --- Progress: 18.25% --- 20.17 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.370124792038
# Testing error
# 0.371617168832
# --- Progress: 18.50% --- 20.45 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.334387275152
# Testing error
# 0.335543915977
# --- Progress: 18.75% --- 20.73 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.299978382336
# Testing error
# 0.301379022795
# --- Progress: 19.00% --- 21.01 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.263556787345
# Testing error
# 0.266853268506
# --- Progress: 19.25% --- 21.29 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.238707985567
# Testing error
# 0.241762557204
# --- Progress: 19.50% --- 21.56 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.240510840838
# Testing error
# 0.24339860053
# --- Progress: 19.75% --- 21.83 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.203177846253
# Testing error
# 0.212864452956
# --- Progress: 20.00% --- 22.10 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.497484510997
# Testing error
# 0.504042665112
# --- Progress: 20.25% --- 22.37 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.480877130864
# Testing error
# 0.487437716047
# --- Progress: 20.50% --- 22.64 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.443749226469
# Testing error
# 0.452485378665
# --- Progress: 20.75% --- 22.90 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.413509578111
# Testing error
# 0.418802504807
# --- Progress: 21.00% --- 23.17 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.385621648655
# Testing error
# 0.387437717546
# --- Progress: 21.25% --- 23.44 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.335527106259
# Testing error
# 0.337459542879
# --- Progress: 21.50% --- 23.71 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.322140978257
# Testing error
# 0.322722783386
# --- Progress: 21.75% --- 23.98 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.283390683055
# Testing error
# 0.28608536552
# --- Progress: 22.00% --- 24.25 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.252604752585
# Testing error
# 0.254857824075
# --- Progress: 22.25% --- 24.52 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.255836225072
# Testing error
# 0.259439880119
# --- Progress: 22.50% --- 24.80 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.499351616229
# Testing error
# 0.506007581892
# --- Progress: 22.75% --- 25.08 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.494205325072
# Testing error
# 0.501064566646
# --- Progress: 23.00% --- 25.34 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.475834815737
# Testing error
# 0.483353168888
# --- Progress: 23.25% --- 25.61 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.449675976914
# Testing error
# 0.458159107435
# --- Progress: 23.50% --- 25.88 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.423410163428
# Testing error
# 0.42946319566
# --- Progress: 23.75% --- 26.15 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.377540901008
# Testing error
# 0.380537454535
# --- Progress: 24.00% --- 26.42 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.35259627928
# Testing error
# 0.352710719005
# --- Progress: 24.25% --- 26.70 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.308460918883
# Testing error
# 0.310584151569
# --- Progress: 24.50% --- 26.97 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.282636781293
# Testing error
# 0.283805707875
# --- Progress: 24.75% --- 27.25 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.05
# harvesting states...
# fitting...
# training error:
# 0.271055408832
# Testing error
# 0.274797211708
# --- Progress: 25.00% --- 27.54 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.380389403167
# Testing error
# 0.379882162687
# --- Progress: 25.25% --- 27.83 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.353840621868
# Testing error
# 0.362255525997
# --- Progress: 25.50% --- 28.11 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.320697156259
# Testing error
# 0.33983222987
# --- Progress: 25.75% --- 28.40 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.319543532538
# Testing error
# 0.351081181417
# --- Progress: 26.00% --- 28.70 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.343079375935
# Testing error
# 0.420098072376
# --- Progress: 26.25% --- 28.98 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.360272382373
# Testing error
# 0.381261793634
# --- Progress: 26.50% --- 29.26 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.371786559478
# Testing error
# 0.441692399426
# --- Progress: 26.75% --- 29.54 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.353439850517
# Testing error
# 0.398998882233
# --- Progress: 27.00% --- 29.83 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.376136737319
# Testing error
# 0.416014110733
# --- Progress: 27.25% --- 30.10 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.390919944702
# Testing error
# 0.546928531618
# --- Progress: 27.50% --- 30.38 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.356783506773
# Testing error
# 0.354296526126
# --- Progress: 27.75% --- 30.66 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.290149813273
# Testing error
# 0.290666434257
# --- Progress: 28.00% --- 30.94 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.242805535736
# Testing error
# 0.248576159729
# --- Progress: 28.25% --- 31.21 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227544877318
# Testing error
# 0.27509451887
# --- Progress: 28.50% --- 31.49 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221944394825
# Testing error
# 0.24587071077
# --- Progress: 28.75% --- 31.77 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.225300466029
# Testing error
# 0.257216257065
# --- Progress: 29.00% --- 32.05 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.241997762794
# Testing error
# 0.273047366663
# --- Progress: 29.25% --- 32.32 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.264311454173
# Testing error
# 0.318154722411
# --- Progress: 29.50% --- 32.61 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.314717469962
# Testing error
# 0.347681060343
# --- Progress: 29.75% --- 32.88 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.316635958109
# Testing error
# 0.353672215954
# --- Progress: 30.00% --- 33.16 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.387324689034
# Testing error
# 0.386695474437
# --- Progress: 30.25% --- 33.43 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.322301308342
# Testing error
# 0.321438059269
# --- Progress: 30.50% --- 33.70 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.271472548158
# Testing error
# 0.273276658471
# --- Progress: 30.75% --- 33.97 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.252305538057
# Testing error
# 0.254970053559
# --- Progress: 31.00% --- 34.25 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226179689764
# Testing error
# 0.233067139077
# --- Progress: 31.25% --- 34.53 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227933218452
# Testing error
# 0.249465788019
# --- Progress: 31.50% --- 34.80 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205840701094
# Testing error
# 0.249227121188
# --- Progress: 31.75% --- 35.08 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.225898322895
# Testing error
# 0.295213609521
# --- Progress: 32.00% --- 35.36 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.243840453818
# Testing error
# 0.285573318838
# --- Progress: 32.25% --- 35.64 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.224521375804
# Testing error
# 0.262662951382
# --- Progress: 32.50% --- 35.91 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.456510074814
# Testing error
# 0.463140099817
# --- Progress: 32.75% --- 36.19 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.381726902486
# Testing error
# 0.382029908464
# --- Progress: 33.00% --- 36.47 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.33031414235
# Testing error
# 0.331892250093
# --- Progress: 33.25% --- 36.74 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.304682615651
# Testing error
# 0.307860026759
# --- Progress: 33.50% --- 37.01 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.274857968532
# Testing error
# 0.275285069408
# --- Progress: 33.75% --- 37.28 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227042255219
# Testing error
# 0.234727513578
# --- Progress: 34.00% --- 37.55 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.20408596187
# Testing error
# 0.212149890144
# --- Progress: 34.25% --- 37.82 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.21564182293
# Testing error
# 0.292338131572
# --- Progress: 34.50% --- 38.09 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.215936759395
# Testing error
# 0.274250036397
# --- Progress: 34.75% --- 38.37 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.209579317671
# Testing error
# 0.240089277701
# --- Progress: 35.00% --- 38.64 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.489389246473
# Testing error
# 0.496535824431
# --- Progress: 35.25% --- 38.92 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.433454157507
# Testing error
# 0.439658453552
# --- Progress: 35.50% --- 39.19 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.390074893989
# Testing error
# 0.391670213529
# --- Progress: 35.75% --- 39.45 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.348604789046
# Testing error
# 0.351080486875
# --- Progress: 36.00% --- 39.72 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.304660379124
# Testing error
# 0.306416793282
# --- Progress: 36.25% --- 40.01 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.280080973
# Testing error
# 0.28216398621
# --- Progress: 36.50% --- 40.28 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.244452441595
# Testing error
# 0.248171923802
# --- Progress: 36.75% --- 40.57 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.246995747427
# Testing error
# 0.253351361686
# --- Progress: 37.00% --- 40.87 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.187373670377
# Testing error
# 0.1979575085
# --- Progress: 37.25% --- 41.16 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.242434643142
# Testing error
# 0.289562952989
# --- Progress: 37.50% --- 41.44 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499056762111
# Testing error
# 0.505909240239
# --- Progress: 37.75% --- 41.70 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.484681399076
# Testing error
# 0.489810422758
# --- Progress: 38.00% --- 41.97 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.449138631174
# Testing error
# 0.455086717344
# --- Progress: 38.25% --- 42.24 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.395603402924
# Testing error
# 0.397976312451
# --- Progress: 38.50% --- 42.51 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.369936909612
# Testing error
# 0.371451623393
# --- Progress: 38.75% --- 42.78 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.336070095268
# Testing error
# 0.33800252404
# --- Progress: 39.00% --- 43.05 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.288971160252
# Testing error
# 0.292443864029
# --- Progress: 39.25% --- 43.32 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.294669071357
# Testing error
# 0.300369879898
# --- Progress: 39.50% --- 43.59 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.255243479104
# Testing error
# 0.263506389324
# --- Progress: 39.75% --- 43.87 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207442284097
# Testing error
# 0.21454843014
# --- Progress: 40.00% --- 44.14 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500045874145
# Testing error
# 0.506709396625
# --- Progress: 40.25% --- 44.41 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.497517268527
# Testing error
# 0.504235374964
# --- Progress: 40.50% --- 44.68 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.483181947175
# Testing error
# 0.49053535637
# --- Progress: 40.75% --- 44.95 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.455369296854
# Testing error
# 0.461393941489
# --- Progress: 41.00% --- 45.21 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.406473744478
# Testing error
# 0.40762842866
# --- Progress: 41.25% --- 45.49 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.375652837926
# Testing error
# 0.376630685475
# --- Progress: 41.50% --- 45.75 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.345226201792
# Testing error
# 0.347715211516
# --- Progress: 41.75% --- 46.02 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.311997890358
# Testing error
# 0.313698851778
# --- Progress: 42.00% --- 46.31 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.282093515814
# Testing error
# 0.286862967257
# --- Progress: 42.25% --- 46.75 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.273885938888
# Testing error
# 0.277535429681
# --- Progress: 42.50% --- 47.03 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500242243573
# Testing error
# 0.506516192642
# --- Progress: 42.75% --- 47.31 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499972923579
# Testing error
# 0.50635540056
# --- Progress: 43.00% --- 47.60 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.497467170312
# Testing error
# 0.504286250245
# --- Progress: 43.25% --- 47.88 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.485757555841
# Testing error
# 0.49273937618
# --- Progress: 43.50% --- 48.16 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.465811919781
# Testing error
# 0.470121665596
# --- Progress: 43.75% --- 48.44 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.420811494463
# Testing error
# 0.423570463052
# --- Progress: 44.00% --- 48.71 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.39297782379
# Testing error
# 0.394680024815
# --- Progress: 44.25% --- 48.98 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.351125326512
# Testing error
# 0.35419352226
# --- Progress: 44.50% --- 49.26 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.302566309941
# Testing error
# 0.306042982265
# --- Progress: 44.75% --- 49.56 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.306681589973
# Testing error
# 0.310990128705
# --- Progress: 45.00% --- 49.84 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500539519113
# Testing error
# 0.507049369562
# --- Progress: 45.25% --- 50.11 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500174183075
# Testing error
# 0.506562719668
# --- Progress: 45.50% --- 50.39 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499980374919
# Testing error
# 0.506440973942
# --- Progress: 45.75% --- 50.68 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.497877217052
# Testing error
# 0.5045411274
# --- Progress: 46.00% --- 50.96 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.486864172268
# Testing error
# 0.492766015481
# --- Progress: 46.25% --- 51.24 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.475561586315
# Testing error
# 0.480610866576
# --- Progress: 46.50% --- 51.51 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.42551340734
# Testing error
# 0.426635732559
# --- Progress: 46.75% --- 51.79 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.381641246213
# Testing error
# 0.384488613387
# --- Progress: 47.00% --- 52.06 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.362823493135
# Testing error
# 0.365860077316
# --- Progress: 47.25% --- 52.34 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.318917562811
# Testing error
# 0.324658568999
# --- Progress: 47.50% --- 52.62 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500845459937
# Testing error
# 0.507241319556
# --- Progress: 47.75% --- 52.91 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500447631908
# Testing error
# 0.5070236179
# --- Progress: 48.00% --- 53.21 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500171199233
# Testing error
# 0.506423672766
# --- Progress: 48.25% --- 53.49 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.49983029726
# Testing error
# 0.506415448647
# --- Progress: 48.50% --- 53.77 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.497273253243
# Testing error
# 0.503816696218
# --- Progress: 48.75% --- 54.04 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.49363297954
# Testing error
# 0.499797468802
# --- Progress: 49.00% --- 54.31 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.47440006428
# Testing error
# 0.480621926699
# --- Progress: 49.25% --- 54.58 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.441767632813
# Testing error
# 0.441669880538
# --- Progress: 49.50% --- 54.86 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.408716289772
# Testing error
# 0.406894240082
# --- Progress: 49.75% --- 55.14 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.387613227748
# Testing error
# 0.388865897956
# --- Progress: 50.00% --- 55.41 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.337103458604
# Testing error
# 0.335998587039
# --- Progress: 50.25% --- 55.70 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.296771408301
# Testing error
# 0.299111280291
# --- Progress: 50.50% --- 55.99 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.272686512442
# Testing error
# 0.293759630047
# --- Progress: 50.75% --- 56.27 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.290844499841
# Testing error
# 0.320613718126
# --- Progress: 51.00% --- 56.56 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.285564282571
# Testing error
# 0.384038893368
# --- Progress: 51.25% --- 56.85 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.305603143833
# Testing error
# 0.335383712431
# --- Progress: 51.50% --- 57.14 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.304517863256
# Testing error
# 0.353352934592
# --- Progress: 51.75% --- 57.43 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.326044693662
# Testing error
# 0.375390003659
# --- Progress: 52.00% --- 57.72 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.354605510888
# Testing error
# 0.383775329797
# --- Progress: 52.25% --- 58.02 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.369402036275
# Testing error
# 0.406548415846
# --- Progress: 52.50% --- 58.30 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.34417369901
# Testing error
# 0.343101804038
# --- Progress: 52.75% --- 58.59 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.308396582306
# Testing error
# 0.310616966438
# --- Progress: 53.00% --- 58.89 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.258988131144
# Testing error
# 0.262161906611
# --- Progress: 53.25% --- 59.18 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.229721112121
# Testing error
# 0.244567413093
# --- Progress: 53.50% --- 59.47 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.225413275166
# Testing error
# 0.274058571998
# --- Progress: 53.75% --- 59.76 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.212504314118
# Testing error
# 0.256404753026
# --- Progress: 54.00% --- 60.05 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.233605727391
# Testing error
# 0.298650534145
# --- Progress: 54.25% --- 60.35 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.237686161708
# Testing error
# 0.317391022917
# --- Progress: 54.50% --- 60.65 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.269111781375
# Testing error
# 0.326595519524
# --- Progress: 54.75% --- 60.95 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.306497414812
# Testing error
# 0.334791113547
# --- Progress: 55.00% --- 61.24 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.439041203437
# Testing error
# 0.44601036259
# --- Progress: 55.25% --- 61.52 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.369475969599
# Testing error
# 0.370861145002
# --- Progress: 55.50% --- 61.80 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.317231513779
# Testing error
# 0.319438162463
# --- Progress: 55.75% --- 62.08 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.288144014725
# Testing error
# 0.288524469616
# --- Progress: 56.00% --- 62.37 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.272692615463
# Testing error
# 0.273924910453
# --- Progress: 56.25% --- 62.65 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.247649938309
# Testing error
# 0.358572192864
# --- Progress: 56.50% --- 62.93 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.227672073857
# Testing error
# 0.305735339929
# --- Progress: 56.75% --- 63.22 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.211259487993
# Testing error
# 0.259951887401
# --- Progress: 57.00% --- 63.50 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.212521329232
# Testing error
# 0.262668764537
# --- Progress: 57.25% --- 63.79 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.24793121184
# Testing error
# 0.29729078771
# --- Progress: 57.50% --- 64.07 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.493789953366
# Testing error
# 0.500174465249
# --- Progress: 57.75% --- 64.34 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.450862965003
# Testing error
# 0.456780918533
# --- Progress: 58.00% --- 64.62 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.386382023463
# Testing error
# 0.387818639818
# --- Progress: 58.25% --- 64.90 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.348790661627
# Testing error
# 0.349910660931
# --- Progress: 58.50% --- 65.17 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.324627366104
# Testing error
# 0.326169827903
# --- Progress: 58.75% --- 65.45 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.290983643096
# Testing error
# 0.296883288496
# --- Progress: 59.00% --- 65.73 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.265952650921
# Testing error
# 0.285224933183
# --- Progress: 59.25% --- 66.01 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.245950461518
# Testing error
# 0.271314279192
# --- Progress: 59.50% --- 66.30 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.276683492903
# Testing error
# 0.320617812827
# --- Progress: 59.75% --- 66.58 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.263741773853
# Testing error
# 0.365411100169
# --- Progress: 60.00% --- 66.86 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.499609471681
# Testing error
# 0.506202235147
# --- Progress: 60.25% --- 67.14 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.491816817375
# Testing error
# 0.498915017593
# --- Progress: 60.50% --- 67.42 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# 0.466764366561
# Testing error
# 0.470424053629
# --- Progress: 60.75% --- 67.69 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.15
# harvesting states...
# fitting...
# training error:
# ...
# harvesting states...
# fitting...
# training error:
# 0.285975048655
# Testing error
# 0.330346325176
# --- Progress: 80.00% --- 88.93 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.482407343431
# Testing error
# 0.488742323318
# --- Progress: 80.25% --- 89.20 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.408882772357
# Testing error
# 0.40965191685
# --- Progress: 80.50% --- 89.48 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.374969346138
# Testing error
# 0.377000164238
# --- Progress: 80.75% --- 89.76 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.328673402688
# Testing error
# 0.332300756666
# --- Progress: 81.00% --- 90.03 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.310954578516
# Testing error
# 0.321665871693
# --- Progress: 81.25% --- 90.31 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.27513572867
# Testing error
# 0.338105306451
# --- Progress: 81.50% --- 90.59 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.294213765274
# Testing error
# 0.347974135794
# --- Progress: 81.75% --- 90.87 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.241333468687
# Testing error
# 0.270951499036
# --- Progress: 82.00% --- 91.15 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.31745039407
# Testing error
# 0.349818270154
# --- Progress: 82.25% --- 91.43 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.227157576283
# Testing error
# 0.288654610022
# --- Progress: 82.50% --- 91.72 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.499756186567
# Testing error
# 0.506233174949
# --- Progress: 82.75% --- 91.99 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.490295783513
# Testing error
# 0.49640125123
# --- Progress: 83.00% --- 92.27 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.442468619342
# Testing error
# 0.443369541367
# --- Progress: 83.25% --- 92.54 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.411389467495
# Testing error
# 0.412593655361
# --- Progress: 83.50% --- 92.82 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.366699510255
# Testing error
# 0.371291435266
# --- Progress: 83.75% --- 93.09 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.34914581516
# Testing error
# 0.352321200545
# --- Progress: 84.00% --- 93.37 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.288857457776
# Testing error
# 0.296944195991
# --- Progress: 84.25% --- 93.65 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.269215110795
# Testing error
# 0.289106238979
# --- Progress: 84.50% --- 93.93 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.280183102066
# Testing error
# 0.323431787339
# --- Progress: 84.75% --- 94.20 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.292212258534
# Testing error
# 0.422462426993
# --- Progress: 85.00% --- 94.48 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500222971088
# Testing error
# 0.50645653722
# --- Progress: 85.25% --- 94.75 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.499787818405
# Testing error
# 0.506247352293
# --- Progress: 85.50% --- 95.03 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.490629133115
# Testing error
# 0.496807572468
# --- Progress: 85.75% --- 95.30 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.455933863299
# Testing error
# 0.45751440071
# --- Progress: 86.00% --- 95.58 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.435259228323
# Testing error
# 0.434988658628
# --- Progress: 86.25% --- 95.85 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.388741395162
# Testing error
# 0.391189120296
# --- Progress: 86.50% --- 96.13 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.359949539294
# Testing error
# 0.364062152852
# --- Progress: 86.75% --- 96.40 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.352402247187
# Testing error
# 0.356705154407
# --- Progress: 87.00% --- 96.68 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.291959078805
# Testing error
# 0.300801661144
# --- Progress: 87.25% --- 96.96 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.329629966552
# Testing error
# 0.364032684485
# --- Progress: 87.50% --- 97.24 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500826105215
# Testing error
# 0.507544660327
# --- Progress: 87.75% --- 97.52 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500204464292
# Testing error
# 0.506493624286
# --- Progress: 88.00% --- 97.79 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.499846402047
# Testing error
# 0.506218522057
# --- Progress: 88.25% --- 98.06 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.495042120178
# Testing error
# 0.501640647045
# --- Progress: 88.50% --- 98.33 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.468415364816
# Testing error
# 0.470539848452
# --- Progress: 88.75% --- 98.60 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.44512008527
# Testing error
# 0.447015513142
# --- Progress: 89.00% --- 98.88 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.408242541968
# Testing error
# 0.41152744642
# --- Progress: 89.25% --- 99.15 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.393847678554
# Testing error
# 0.397489006371
# --- Progress: 89.50% --- 99.42 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.362921934641
# Testing error
# 0.365600660418
# --- Progress: 89.75% --- 99.70 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.337797210443
# Testing error
# 0.351527153925
# --- Progress: 90.00% --- 99.97 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.501337073835
# Testing error
# 0.507923058796
# --- Progress: 90.25% --- 100.25 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500627065169
# Testing error
# 0.507445143174
# --- Progress: 90.50% --- 100.52 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500215413532
# Testing error
# 0.50667225645
# --- Progress: 90.75% --- 100.79 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.499944334124
# Testing error
# 0.505939871288
# --- Progress: 91.00% --- 101.06 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.49595933104
# Testing error
# 0.502711337623
# --- Progress: 91.25% --- 101.34 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.4759424885
# Testing error
# 0.478797028507
# --- Progress: 91.50% --- 101.61 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.45113867174
# Testing error
# 0.45029236587
# --- Progress: 91.75% --- 101.88 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.4432912736
# Testing error
# 0.443040231486
# --- Progress: 92.00% --- 102.15 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.40566581856
# Testing error
# 0.409572063865
# --- Progress: 92.25% --- 102.43 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.353909265157
# Testing error
# 0.356591732946
# --- Progress: 92.50% --- 102.70 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.502147366309
# Testing error
# 0.508296443455
# --- Progress: 92.75% --- 102.97 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.501182238704
# Testing error
# 0.507895464932
# --- Progress: 93.00% --- 103.24 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500770314296
# Testing error
# 0.507251153299
# --- Progress: 93.25% --- 103.52 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500258415527
# Testing error
# 0.506478705889
# --- Progress: 93.50% --- 103.79 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500062473222
# Testing error
# 0.506155141178
# --- Progress: 93.75% --- 104.06 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.495962814088
# Testing error
# 0.502390283615
# --- Progress: 94.00% --- 104.33 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.468874150332
# Testing error
# 0.469987285989
# --- Progress: 94.25% --- 104.60 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.450202899269
# Testing error
# 0.450085169682
# --- Progress: 94.50% --- 104.87 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.445699596569
# Testing error
# 0.446038376481
# --- Progress: 94.75% --- 105.14 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.435312467439
# Testing error
# 0.43559929445
# --- Progress: 95.00% --- 105.41 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.502921928884
# Testing error
# 0.508323868153
# --- Progress: 95.25% --- 105.68 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.502154527127
# Testing error
# 0.508002933393
# --- Progress: 95.50% --- 105.95 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.50136007365
# Testing error
# 0.507763095425
# --- Progress: 95.75% --- 106.22 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500725167427
# Testing error
# 0.507312104816
# --- Progress: 96.00% --- 106.50 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500269267277
# Testing error
# 0.506818096578
# --- Progress: 96.25% --- 106.77 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.499846016248
# Testing error
# 0.506066098503
# --- Progress: 96.50% --- 107.04 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.495715443435
# Testing error
# 0.502071096659
# --- Progress: 96.75% --- 107.31 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.480515175152
# Testing error
# 0.48281891841
# --- Progress: 97.00% --- 107.60 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.459512936067
# Testing error
# 0.458085874318
# --- Progress: 97.25% --- 107.87 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.44874584168
# Testing error
# 0.448520233015
# --- Progress: 97.50% --- 108.14 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.503635653788
# Testing error
# 0.508412208612
# --- Progress: 97.75% --- 108.41 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.502863561845
# Testing error
# 0.508005380848
# --- Progress: 98.00% --- 108.68 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.50188348303
# Testing error
# 0.508084072118
# --- Progress: 98.25% --- 108.95 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.501251318713
# Testing error
# 0.507905053564
# --- Progress: 98.50% --- 109.22 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500792128724
# Testing error
# 0.5077690665
# --- Progress: 98.75% --- 109.49 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.500313000784
# Testing error
# 0.5066395629
# --- Progress: 99.00% --- 109.76 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.499946362739
# Testing error
# 0.506149194746
# --- Progress: 99.25% --- 110.03 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.495471393694
# Testing error
# 0.501756443178
# --- Progress: 99.50% --- 110.30 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.48513505534
# Testing error
# 0.489438211525
# --- Progress: 99.75% --- 110.57 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.2
# harvesting states...
# fitting...
# training error:
# 0.467764591912
# Testing error
# 0.468378809794
# --- Progress: 100.00% --- 110.84 minutes ---
# Total time:
# --- 110.84 minutes ---

# %%
import pickle
#### Save Data
# with open('bigESN.p', 'wb') as outputFile:
#     pickle.dump(delta_t_error, outputFile)
#     pickle.dump(num_neurons, outputFile)
#     pickle.dump(delta_t, outputFile)
#     pickle.dump(trials, outputFile)
#     pickle.dump(l_rate, outputFile)
#     pickle.dump(sp_rad, outputFile)
#### Load Data
with open('bigESN.p', 'rb') as inputFile:
    delta_t_error = pickle.load(inputFile)
    num_neurons = pickle.load(inputFile)
    delta_t = pickle.load(inputFile)
    trials = pickle.load(inputFile)
    l_rate = pickle.load(inputFile)
    sp_rad = pickle.load(inputFile)

# %%
### Plot Errors

from matplotlib import pyplot
# %matplotlib inline
print(delta_t)
xx, yy = np.meshgrid(l_rate, sp_rad)
pyplot.figure(figsize=(12,14))
for p in range(len(delta_t)):
    pyplot.subplot(3,2,p+1)
    pyplot.contourf(xx,
                    yy,delta_t_error[p].reshape(10,10).T)
    pyplot.title(("delta_t", delta_t[p]))
    pyplot.xlabel("Leak-rate")
    pyplot.ylabel("Spectral-radius")
    pyplot.colorbar()
# Out:
# [0.05, 0.1, 0.15, 0.2]

# %%
bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(i))

# Divide in training and test data
traintest_cutoff = int(np.ceil(0.7 * len(bits)))
train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
#     train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]

bigESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=350,  # from 200 onwards test error decreases significantly
                          spectral_radius=0.6,  # high spectral rad is better (high fluctuations 0->1->0)
                          leak_rate= 0.3,   # adjust leak_rate
                          delta_t= 0.1,
                          sparsity=0.95,     # 0.95
                          noise=0.01,      # 0.01
                          input_shift=0,    # 0
                          input_scaling=3,  # 3 seems to be fine. Maybe use lower
                          teacher_forcing=False, # No need for teacher forcing because we have no pattern
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          random_state=rng,
                          silent=False)
bigESN.fit(train_bits, train_target)#, inspect= True)
pred_test = bigESN.predict(test_bits)

predictedTarget = pred_test
print("Testing error")
test_error = np.sqrt(np.mean((predictedTarget - test_target) ** 2))
print(test_error)
# Out:
# harvesting states...
# fitting...
# training error:
# 0.225962132237
# Testing error
# 0.247664006669

# %%
plt.figure(figsize=(12,6))
plt.subplot(111)
print(len(predictedTarget))
# plt.plot(predictedParity[66600:66800])
plt.plot(predictedTarget[6000:8000],"b")
plt.plot(test_target[6000:8000], "r")
plt.show()
# Out:
# 60000
