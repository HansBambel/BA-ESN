# %%
import Parity_Data_Generator
import numpy as np
from pyESN import ESN
import matplotlib.pyplot as plt
import time

rng = np.random.RandomState(42)

N = 4000   
n = 3       # n-parity
timescale=50

start_time = time.time()
# produce Data
bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, randomstate=rng)

# Divide in training and test data
traintest_cutoff = int(np.ceil(0.7 * len(bits)))
train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
# train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.009002447128295898 seconds ---

# %%
def runSomeConfigs(spectral_rad, leak_r, d_t, train_b, test_b, train_t, test_t, n_neurons):
#     print("Spectral-radius:",spectral_rad, "leak-rate:", leak_r)
    nParityESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=n_neurons,  # from 200 onwards test error decreases significantly
                          spectral_radius=spectral_rad,  # high spectral rad is better (high fluctuations 0->1->0)
                          leak_rate= leak_r,   # adjust leak_rate
                          delta_t= d_t,
                          sparsity=0.95,
                          noise=0.01,
                          input_shift=0,
                          input_scaling=3,  # 3 seems to be fine. Maybe use lower
                          teacher_forcing=False,
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          random_state=rng,
                          silent=False)
    # print(np.shape(bits),np.shape(parity),np.shape(target))
    nParityESN.fit(train_b, train_t)
    pred_test = nParityESN.predict(test_b)

    predictedParity = pred_test 
    
    print("Testing error")
    test_error = np.sqrt(np.mean((predictedParity - test_t) ** 2))
    print(test_error)
    return test_error

def produceTrainingData(i):
    bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(i))

    # Divide in training and test data
    traintest_cutoff = int(np.ceil(0.7 * len(bits)))
    train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
#     train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
    train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
    return train_bits, test_bits, train_targets, test_targets

# %%
trials=10
sp_rad = np.linspace(0.1, 1, num=10)
l_rate = np.linspace(0.1, 1, num=10)
num_neurons = 350
delta_t = [0.1]

run_time = time.time()
iterations, iterationcount = trials*len(sp_rad)*len(l_rate)*len(delta_t), 0

delta_t_error = []
for dt in delta_t:
    all_errors = [{} for _ in range(trials)] # empty dict
    for i in range(trials):
        errors = []
        # produce training and testing data
        train_bits, test_bits, train_target, test_target = produceTrainingData(i)
        for l in l_rate:
            for s in sp_rad:
                print("Neurons:", num_neurons,"Leak-rate:",l,"Spectral-radius:",s,"Delta_t:",dt)
                errors.append(runSomeConfigs(s,l,dt, train_bits, test_bits, train_target, test_target, num_neurons))
                iterationcount = iterationcount + 1
                print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
        ## Save leak-rate,spectral-radius and error in dictionary
        all_errors[i] = errors

    ### Average errors
    errors_averaged_over_trials = np.zeros(100)
    for i in range(len(all_errors)):
        e = all_errors[i]
        errors_averaged_over_trials = np.add(errors_averaged_over_trials, np.array(e))
    errors_averaged_over_trials = np.divide(errors_averaged_over_trials, trials)
    
    delta_t_error.append(errors_averaged_over_trials)
    
print("Total time:")
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.37797581239
# Testing error
# 0.377242909348
# --- Progress: 0.10% --- 0.32 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.355731382688
# Testing error
# 0.367055291866
# --- Progress: 0.20% --- 0.59 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.340493015074
# Testing error
# 0.375022868052
# --- Progress: 0.30% --- 0.88 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.340199603512
# Testing error
# 0.387970372646
# --- Progress: 0.40% --- 1.17 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.349517333256
# Testing error
# 0.426261743554
# --- Progress: 0.50% --- 1.44 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.353347403251
# Testing error
# 0.458139755193
# --- Progress: 0.60% --- 1.72 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.360650619279
# Testing error
# 0.472004575539
# --- Progress: 0.70% --- 2.00 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.3760975253
# Testing error
# 0.434901681479
# --- Progress: 0.80% --- 2.29 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.415015459502
# Testing error
# 0.46597342874
# --- Progress: 0.90% --- 2.57 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.391595253901
# Testing error
# 0.431630500317
# --- Progress: 1.00% --- 2.85 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.361981544365
# Testing error
# 0.361507697575
# --- Progress: 1.10% --- 3.17 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.287486025507
# Testing error
# 0.286993014002
# --- Progress: 1.20% --- 3.47 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.251148300119
# Testing error
# 0.257932322439
# --- Progress: 1.30% --- 3.76 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217754026484
# Testing error
# 0.23241213526
# --- Progress: 1.40% --- 4.06 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.228884804195
# Testing error
# 0.290771710057
# --- Progress: 1.50% --- 4.38 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221913827196
# Testing error
# 0.26137193392
# --- Progress: 1.60% --- 4.67 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.265416876996
# Testing error
# 0.322054656777
# --- Progress: 1.70% --- 4.98 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.245853193179
# Testing error
# 0.335275702701
# --- Progress: 1.80% --- 5.28 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.259786576428
# Testing error
# 0.315287736738
# --- Progress: 1.90% --- 5.58 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.277607649632
# Testing error
# 0.31209855304
# --- Progress: 2.00% --- 5.89 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.387678109768
# Testing error
# 0.385246742498
# --- Progress: 2.10% --- 6.20 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.316197686258
# Testing error
# 0.317526981737
# --- Progress: 2.20% --- 6.49 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.252309144108
# Testing error
# 0.255259133608
# --- Progress: 2.30% --- 6.78 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.247700229849
# Testing error
# 0.251477968608
# --- Progress: 2.40% --- 7.08 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226312942615
# Testing error
# 0.240283468231
# --- Progress: 2.50% --- 7.38 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217250769492
# Testing error
# 0.258402454903
# --- Progress: 2.60% --- 7.67 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198815004877
# Testing error
# 0.27886440336
# --- Progress: 2.70% --- 7.97 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.241121372358
# Testing error
# 0.30525468621
# --- Progress: 2.80% --- 8.27 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.224987817323
# Testing error
# 0.266822852547
# --- Progress: 2.90% --- 8.58 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.254943529202
# Testing error
# 0.298882661663
# --- Progress: 3.00% --- 8.92 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.44922664605
# Testing error
# 0.45352853956
# --- Progress: 3.10% --- 9.25 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.368120359836
# Testing error
# 0.368713039925
# --- Progress: 3.20% --- 9.59 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.329902404611
# Testing error
# 0.331753251681
# --- Progress: 3.30% --- 9.93 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.293375453216
# Testing error
# 0.296547120034
# --- Progress: 3.40% --- 10.25 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.266392168048
# Testing error
# 0.26792760521
# --- Progress: 3.50% --- 10.53 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218781031645
# Testing error
# 0.222787400768
# --- Progress: 3.60% --- 10.86 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.184144880998
# Testing error
# 0.198223005286
# --- Progress: 3.70% --- 11.17 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.222269095864
# Testing error
# 0.29377305105
# --- Progress: 3.80% --- 11.46 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207153321271
# Testing error
# 0.2493083225
# --- Progress: 3.90% --- 11.77 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219062809587
# Testing error
# 0.292960579683
# --- Progress: 4.00% --- 12.07 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.487958110157
# Testing error
# 0.495530530512
# --- Progress: 4.10% --- 12.37 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.444922017923
# Testing error
# 0.452299388296
# --- Progress: 4.20% --- 12.68 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.369103925582
# Testing error
# 0.369996028492
# --- Progress: 4.30% --- 12.98 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.349171156498
# Testing error
# 0.351164555078
# --- Progress: 4.40% --- 13.26 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.311600565254
# Testing error
# 0.313804380215
# --- Progress: 4.50% --- 13.55 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.286036502134
# Testing error
# 0.288370575191
# --- Progress: 4.60% --- 13.83 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.241576602603
# Testing error
# 0.245803618643
# --- Progress: 4.70% --- 14.11 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205462565882
# Testing error
# 0.244789181931
# --- Progress: 4.80% --- 14.40 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226916795989
# Testing error
# 0.251667967683
# --- Progress: 4.90% --- 14.69 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.258754136116
# Testing error
# 0.344623664352
# --- Progress: 5.00% --- 14.98 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.498958005522
# Testing error
# 0.505375450583
# --- Progress: 5.10% --- 15.27 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.482232773264
# Testing error
# 0.490275895598
# --- Progress: 5.20% --- 15.57 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.448568646755
# Testing error
# 0.455798923894
# --- Progress: 5.30% --- 15.89 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.391457238227
# Testing error
# 0.393631823278
# --- Progress: 5.40% --- 16.21 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.369152375338
# Testing error
# 0.369616430692
# --- Progress: 5.50% --- 16.53 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.325915346582
# Testing error
# 0.326254421573
# --- Progress: 5.60% --- 16.85 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.299728904005
# Testing error
# 0.304661607641
# --- Progress: 5.70% --- 17.18 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.250555543304
# Testing error
# 0.252400192485
# --- Progress: 5.80% --- 17.52 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.200581658914
# Testing error
# 0.204382314065
# --- Progress: 5.90% --- 17.88 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211246279086
# Testing error
# 0.233848324364
# --- Progress: 6.00% --- 18.26 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499994373558
# Testing error
# 0.506372807073
# --- Progress: 6.10% --- 18.63 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.498145640435
# Testing error
# 0.50467911123
# --- Progress: 6.20% --- 19.00 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.483538484189
# Testing error
# 0.490270442077
# --- Progress: 6.30% --- 19.36 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.462807440919
# Testing error
# 0.469106170111
# --- Progress: 6.40% --- 19.72 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.401121272236
# Testing error
# 0.401744070015
# --- Progress: 6.50% --- 20.09 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.379897650659
# Testing error
# 0.38193923277
# --- Progress: 6.60% --- 20.46 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.333818587588
# Testing error
# 0.338632565069
# --- Progress: 6.70% --- 20.83 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.329244774757
# Testing error
# 0.331058719216
# --- Progress: 6.80% --- 21.19 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.29724458423
# Testing error
# 0.299695338173
# --- Progress: 6.90% --- 21.55 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.248750529485
# Testing error
# 0.257584529591
# --- Progress: 7.00% --- 21.92 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500318804777
# Testing error
# 0.506698393689
# --- Progress: 7.10% --- 22.28 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499995593261
# Testing error
# 0.506376121433
# --- Progress: 7.20% --- 22.64 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.497857220889
# Testing error
# 0.504649857939
# --- Progress: 7.30% --- 22.99 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.488874191724
# Testing error
# 0.495645810369
# --- Progress: 7.40% --- 23.33 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.46198419637
# Testing error
# 0.468075292105
# --- Progress: 7.50% --- 23.68 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.417114502895
# Testing error
# 0.418136768533
# --- Progress: 7.60% --- 24.04 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.383056377195
# Testing error
# 0.383713957925
# --- Progress: 7.70% --- 24.39 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.345182598781
# Testing error
# 0.348269958005
# --- Progress: 7.80% --- 24.73 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.345138126976
# Testing error
# 0.34786843767
# --- Progress: 7.90% --- 25.08 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.253825867397
# Testing error
# 0.260174197456
# --- Progress: 8.00% --- 25.42 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.50059024472
# Testing error
# 0.506958917479
# --- Progress: 8.10% --- 25.76 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500275311332
# Testing error
# 0.506442000016
# --- Progress: 8.20% --- 26.09 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500037414572
# Testing error
# 0.50619652232
# --- Progress: 8.30% --- 26.42 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.498035689638
# Testing error
# 0.504591640751
# --- Progress: 8.40% --- 26.76 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.49275346487
# Testing error
# 0.498644377522
# --- Progress: 8.50% --- 27.09 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.479897879415
# Testing error
# 0.487269366272
# --- Progress: 8.60% --- 27.44 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.432159877884
# Testing error
# 0.43294175635
# --- Progress: 8.70% --- 27.80 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.400587879393
# Testing error
# 0.401553493336
# --- Progress: 8.80% --- 28.14 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.369895190752
# Testing error
# 0.372076667423
# --- Progress: 8.90% --- 28.50 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.345601459692
# Testing error
# 0.351424187918
# --- Progress: 9.00% --- 28.85 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500724236094
# Testing error
# 0.507488999358
# --- Progress: 9.10% --- 29.21 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500414112626
# Testing error
# 0.507360117297
# --- Progress: 9.20% --- 29.54 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500226495798
# Testing error
# 0.506548764821
# --- Progress: 9.30% --- 29.88 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499873730134
# Testing error
# 0.506629122069
# --- Progress: 9.40% --- 30.23 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.498556251543
# Testing error
# 0.505215310272
# --- Progress: 9.50% --- 30.57 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.491855339547
# Testing error
# 0.498021443885
# --- Progress: 9.60% --- 30.90 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.475506457399
# Testing error
# 0.480257290452
# --- Progress: 9.70% --- 31.25 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.448560282507
# Testing error
# 0.449601501464
# --- Progress: 9.80% --- 31.59 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.392330330674
# Testing error
# 0.392381419812
# --- Progress: 9.90% --- 31.93 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.390356856688
# Testing error
# 0.392479953589
# --- Progress: 10.00% --- 32.28 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.378215531038
# Testing error
# 0.3777397095
# --- Progress: 10.10% --- 32.63 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.351495590085
# Testing error
# 0.351588873958
# --- Progress: 10.20% --- 32.99 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.325186315909
# Testing error
# 0.319513535186
# --- Progress: 10.30% --- 33.34 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.322649639251
# Testing error
# 0.321565098007
# --- Progress: 10.40% --- 33.69 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.343007982552
# Testing error
# 0.357303523179
# --- Progress: 10.50% --- 34.05 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.361146513775
# Testing error
# 0.37685449223
# --- Progress: 10.60% --- 34.40 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.369202965111
# Testing error
# 0.393375696658
# --- Progress: 10.70% --- 34.76 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.359109205527
# Testing error
# 0.384043505176
# --- Progress: 10.80% --- 35.11 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.383119603616
# Testing error
# 0.397775332289
# --- Progress: 10.90% --- 35.45 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.400290367417
# Testing error
# 0.422115271991
# --- Progress: 11.00% --- 35.80 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.352393444825
# Testing error
# 0.351987398471
# --- Progress: 11.10% --- 36.16 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.287031973799
# Testing error
# 0.285867861215
# --- Progress: 11.20% --- 36.52 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.242675750198
# Testing error
# 0.240308310168
# --- Progress: 11.30% --- 36.87 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.23417451388
# Testing error
# 0.233797132984
# --- Progress: 11.40% --- 37.22 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226338684329
# Testing error
# 0.229438847931
# --- Progress: 11.50% --- 37.57 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.229979490512
# Testing error
# 0.23378491008
# --- Progress: 11.60% --- 37.94 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.245979853513
# Testing error
# 0.252032815037
# --- Progress: 11.70% --- 38.30 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.274032826939
# Testing error
# 0.289006543092
# --- Progress: 11.80% --- 38.65 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.319506527013
# Testing error
# 0.330920591712
# --- Progress: 11.90% --- 39.00 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.322710485659
# Testing error
# 0.341448367762
# --- Progress: 12.00% --- 39.36 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.382518852109
# Testing error
# 0.384229636433
# --- Progress: 12.10% --- 39.70 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.317942005041
# Testing error
# 0.31952740629
# --- Progress: 12.20% --- 40.04 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.27166569583
# Testing error
# 0.269097962092
# --- Progress: 12.30% --- 40.41 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.2529512161
# Testing error
# 0.249848127023
# --- Progress: 12.40% --- 40.75 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227464769494
# Testing error
# 0.224484894824
# --- Progress: 12.50% --- 41.09 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.234404958464
# Testing error
# 0.233323734569
# --- Progress: 12.60% --- 41.43 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.214108764359
# Testing error
# 0.215279115496
# --- Progress: 12.70% --- 41.77 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.234939918646
# Testing error
# 0.235614101627
# --- Progress: 12.80% --- 42.12 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.250616249449
# Testing error
# 0.269005944526
# --- Progress: 12.90% --- 42.46 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.235221877433
# Testing error
# 0.237625543646
# --- Progress: 13.00% --- 42.81 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.456227384783
# Testing error
# 0.460161450597
# --- Progress: 13.10% --- 43.15 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.377667846507
# Testing error
# 0.380088578112
# --- Progress: 13.20% --- 43.50 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.326318700508
# Testing error
# 0.32939716762
# --- Progress: 13.30% --- 43.84 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.301996731763
# Testing error
# 0.301416253142
# --- Progress: 13.40% --- 44.18 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.273924601601
# Testing error
# 0.270032453427
# --- Progress: 13.50% --- 44.54 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.228211192312
# Testing error
# 0.226728569745
# --- Progress: 13.60% --- 44.89 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208157736091
# Testing error
# 0.206050845788
# --- Progress: 13.70% --- 45.23 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.220415633989
# Testing error
# 0.223346684752
# --- Progress: 13.80% --- 45.58 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227932485386
# Testing error
# 0.230928325293
# --- Progress: 13.90% --- 45.93 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219248394542
# Testing error
# 0.219957822837
# --- Progress: 14.00% --- 46.27 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.491901680425
# Testing error
# 0.494736198419
# --- Progress: 14.10% --- 46.61 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.433361956725
# Testing error
# 0.436127591394
# --- Progress: 14.20% --- 46.96 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.385769050779
# Testing error
# 0.390010624277
# --- Progress: 14.30% --- 47.48 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.342769846527
# Testing error
# 0.347442563918
# --- Progress: 14.40% --- 47.89 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.302675186448
# Testing error
# 0.302489677151
# --- Progress: 14.50% --- 48.23 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.277342339551
# Testing error
# 0.276686299118
# --- Progress: 14.60% --- 48.57 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.244404963496
# Testing error
# 0.242422862453
# --- Progress: 14.70% --- 48.91 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.250168633283
# Testing error
# 0.247692047159
# --- Progress: 14.80% --- 49.25 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.189094716794
# Testing error
# 0.188727345324
# --- Progress: 14.90% --- 49.59 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.253807243016
# Testing error
# 0.27029416402
# --- Progress: 15.00% --- 49.94 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.501342668908
# Testing error
# 0.504134597459
# --- Progress: 15.10% --- 50.28 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.485106909211
# Testing error
# 0.489064103406
# --- Progress: 15.20% --- 50.62 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.448036433136
# Testing error
# 0.453415272932
# --- Progress: 15.30% --- 50.96 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.391057996841
# Testing error
# 0.39530022334
# --- Progress: 15.40% --- 51.30 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.362449626603
# Testing error
# 0.370685756497
# --- Progress: 15.50% --- 51.64 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.329472040116
# Testing error
# 0.335075010757
# --- Progress: 15.60% --- 51.98 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.287698519834
# Testing error
# 0.288334661821
# --- Progress: 15.70% --- 52.32 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.293011621991
# Testing error
# 0.291646440392
# --- Progress: 15.80% --- 52.66 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.255960440926
# Testing error
# 0.258032319902
# --- Progress: 15.90% --- 53.00 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212013230364
# Testing error
# 0.213043134665
# --- Progress: 16.00% --- 53.35 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502567477538
# Testing error
# 0.5053553489
# --- Progress: 16.10% --- 53.69 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499621633257
# Testing error
# 0.502735374294
# --- Progress: 16.20% --- 54.03 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.484034323645
# Testing error
# 0.48874554516
# --- Progress: 16.30% --- 54.37 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.456089974686
# Testing error
# 0.460391108016
# --- Progress: 16.40% --- 54.71 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.401861212029
# Testing error
# 0.408188802405
# --- Progress: 16.50% --- 55.05 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.368839527162
# Testing error
# 0.375251227886
# --- Progress: 16.60% --- 55.39 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.337933930777
# Testing error
# 0.344651497826
# --- Progress: 16.70% --- 55.73 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.307170203616
# Testing error
# 0.309312802193
# --- Progress: 16.80% --- 56.07 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.281166057029
# Testing error
# 0.282284479391
# --- Progress: 16.90% --- 56.41 minutes ---
# Neurons: 350 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.271936040432
# Testing error
# 0.272249376276
# --- Progress: 17.00% --- 56.75 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502963155151
# Testing error
# 0.505656706395
# --- Progress: 17.10% --- 57.09 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502381795457
# Testing error
# 0.50523450485
# --- Progress: 17.20% --- 57.44 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499491221924
# Testing error
# 0.502468392409
# --- Progress: 17.30% --- 57.78 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.485491765356
# Testing error
# 0.492264129472
# --- Progress: 17.40% --- 58.13 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.463899539567
# Testing error
# 0.469757450869
# --- Progress: 17.50% --- 58.48 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.416335277368
# Testing error
# 0.422538535233
# --- Progress: 17.60% --- 58.82 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.384324937785
# Testing error
# 0.394387815879
# --- Progress: 17.70% --- 59.16 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.344529008586
# Testing error
# 0.352473266378
# --- Progress: 17.80% --- 59.51 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.30310645854
# Testing error
# 0.303421791046
# --- Progress: 17.90% --- 59.86 minutes ---
# Neurons: 350 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.305353162677
# Testing error
# 0.309163485402
# --- Progress: 18.00% --- 60.21 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.50335620425
# Testing error
# 0.506020716386
# --- Progress: 18.10% --- 60.56 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502852315852
# Testing error
# 0.5057175979
# --- Progress: 18.20% --- 60.90 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.50230066052
# Testing error
# 0.505241645831
# --- Progress: 18.30% --- 61.25 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500401453918
# Testing error
# 0.503385609609
# --- Progress: 18.40% --- 61.60 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.487129031608
# Testing error
# 0.491868597814
# --- Progress: 18.50% --- 61.95 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.474636537383
# Testing error
# 0.479669939945
# --- Progress: 18.60% --- 62.30 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.419549489168
# Testing error
# 0.427226861714
# --- Progress: 18.70% --- 62.64 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.375621072417
# Testing error
# 0.3820548548
# --- Progress: 18.80% --- 62.99 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.355946234562
# Testing error
# 0.364731313282
# --- Progress: 18.90% --- 63.34 minutes ---
# Neurons: 350 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.317787607547
# Testing error
# 0.320820072852
# --- Progress: 19.00% --- 63.69 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.503746807393
# Testing error
# 0.506171931652
# --- Progress: 19.10% --- 64.03 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.503354087434
# Testing error
# 0.505552347035
# --- Progress: 19.20% --- 64.38 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502748040112
# Testing error
# 0.505503581193
# --- Progress: 19.30% --- 64.72 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.50245533139
# Testing error
# 0.505403388053
# --- Progress: 19.40% --- 65.07 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499545649718
# Testing error
# 0.503065107641
# --- Progress: 19.50% --- 65.41 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.494993297553
# Testing error
# 0.498488945489
# --- Progress: 19.60% --- 65.76 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.473379787001
# Testing error
# 0.47904292621
# --- Progress: 19.70% --- 66.11 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.435885113077
# Testing error
# 0.443750015277
# --- Progress: 19.80% --- 66.45 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.400784882916
# Testing error
# 0.410428153728
# --- Progress: 19.90% --- 66.80 minutes ---
# Neurons: 350 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.37861426666
# Testing error
# 0.391932753677
# --- Progress: 20.00% --- 67.15 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.381136029282
# Testing error
# 0.393773578519
# --- Progress: 20.10% --- 67.51 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.338272068278
# Testing error
# 0.379485726304
# --- Progress: 20.20% --- 67.87 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.323991155836
# Testing error
# 0.423883228614
# --- Progress: 20.30% --- 68.24 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.343168552725
# Testing error
# 0.389287604269
# --- Progress: 20.40% --- 68.60 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.32026161784
# Testing error
# 0.387710607906
# --- Progress: 20.50% --- 68.96 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.354394934984
# Testing error
# 0.447057038408
# --- Progress: 20.60% --- 69.32 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.353426113892
# Testing error
# 0.416052404301
# --- Progress: 20.70% --- 69.68 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.363593853298
# Testing error
# 0.490893870656
# --- Progress: 20.80% --- 70.06 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.394370931707
# Testing error
# 0.619082712777
# --- Progress: 20.90% --- 70.41 minutes ---
# Neurons: 350 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.410974852396
# Testing error
# 0.475562103538
# --- Progress: 21.00% --- 70.76 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.336209321917
# Testing error
# 0.340249362845
# --- Progress: 21.10% --- 71.12 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.296478408449
# Testing error
# 0.301188595837
# --- Progress: 21.20% --- 71.48 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.256473659844
# Testing error
# 0.264555330301
# --- Progress: 21.30% --- 71.83 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.242581909983
# Testing error
# 0.283320176242
# --- Progress: 21.40% --- 72.15 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.235971315112
# Testing error
# 0.371705017997
# --- Progress: 21.50% --- 72.49 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.239882372082
# Testing error
# 0.455404336341
# --- Progress: 21.60% --- 72.83 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.24992001509
# Testing error
# 0.345070791453
# --- Progress: 21.70% --- 73.16 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.243040061593
# Testing error
# 0.358182012952
# --- Progress: 21.80% --- 73.50 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.286643818108
# Testing error
# 0.338442341522
# --- Progress: 21.90% --- 73.83 minutes ---
# Neurons: 350 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.308437540315
# Testing error
# 0.339487143484
# --- Progress: 22.00% --- 74.17 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.38065560989
# Testing error
# 0.385626349319
# --- Progress: 22.10% --- 74.50 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.31518037367
# Testing error
# 0.317607730585
# --- Progress: 22.20% --- 74.83 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.280936179651
# Testing error
# 0.2824483631
# --- Progress: 22.30% --- 75.16 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.248812950506
# Testing error
# 0.260355430037
# --- Progress: 22.40% --- 75.49 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.243596662787
# Testing error
# 0.250776278873
# --- Progress: 22.50% --- 75.82 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.215369074262
# Testing error
# 0.307197594104
# --- Progress: 22.60% --- 76.15 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.20533442557
# Testing error
# 0.277415821994
# --- Progress: 22.70% --- 76.49 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216845659426
# Testing error
# 0.36231940479
# --- Progress: 22.80% --- 76.83 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.214831340585
# Testing error
# 0.291016873435
# --- Progress: 22.90% --- 77.18 minutes ---
# Neurons: 350 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.241287914627
# Testing error
# 0.302113045261
# --- Progress: 23.00% --- 77.54 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.452076887001
# Testing error
# 0.453947603486
# --- Progress: 23.10% --- 77.89 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.367806595979
# Testing error
# 0.371928072779
# --- Progress: 23.20% --- 78.25 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.331439586902
# Testing error
# 0.334056769961
# --- Progress: 23.30% --- 78.60 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.276781746665
# Testing error
# 0.2769178926
# --- Progress: 23.40% --- 78.95 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.250209870037
# Testing error
# 0.253735822553
# --- Progress: 23.50% --- 79.30 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.236887638016
# Testing error
# 0.255414581816
# --- Progress: 23.60% --- 79.66 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217830523736
# Testing error
# 0.259346245131
# --- Progress: 23.70% --- 80.01 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.195676321881
# Testing error
# 0.27070349263
# --- Progress: 23.80% --- 80.34 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.235553495654
# Testing error
# 0.358091971951
# --- Progress: 23.90% --- 80.67 minutes ---
# Neurons: 350 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219059759204
# Testing error
# 0.352690817019
# --- Progress: 24.00% --- 81.00 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.489063504718
# Testing error
# 0.489858322626
# --- Progress: 24.10% --- 81.33 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.438520756235
# Testing error
# 0.439168827872
# --- Progress: 24.20% --- 81.65 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.386025545987
# Testing error
# 0.388751690634
# --- Progress: 24.30% --- 81.98 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.349131881453
# Testing error
# 0.349439852851
# --- Progress: 24.40% --- 82.31 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.306467277026
# Testing error
# 0.308407052895
# --- Progress: 24.50% --- 82.64 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.262850396801
# Testing error
# 0.265845774926
# --- Progress: 24.60% --- 82.97 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.236632252768
# Testing error
# 0.249809299757
# --- Progress: 24.70% --- 83.30 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.202412047412
# Testing error
# 0.225843007356
# --- Progress: 24.80% --- 83.63 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211375713128
# Testing error
# 0.339616517284
# --- Progress: 24.90% --- 83.97 minutes ---
# Neurons: 350 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.190438554719
# Testing error
# 0.245681117031
# --- Progress: 25.00% --- 84.31 minutes ---
# Neurons: 350 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...

# %%
import pickle
#### Save Data
with open('bigESNaveraged10.p', 'wb') as outputFile:
    pickle.dump(delta_t_error, outputFile)
    pickle.dump(num_neurons, outputFile)
    pickle.dump(delta_t, outputFile)
    pickle.dump(trials, outputFile)
    pickle.dump(l_rate, outputFile)
    pickle.dump(sp_rad, outputFile)
#### Load Data
# with open('bigESN.p', 'rb') as inputFile:
#     delta_t_error = pickle.load(inputFile)
#     num_neurons = pickle.load(inputFile)
#     delta_t = pickle.load(inputFile)
#     trials = pickle.load(inputFile)
#     l_rate = pickle.load(inputFile)
#     sp_rad = pickle.load(inputFile)

# %%
### Plot Errors

from matplotlib import pyplot
# %matplotlib inline
print(delta_t)
xx, yy = np.meshgrid(l_rate, sp_rad)
pyplot.figure(figsize=(12,14))
for p in range(len(delta_t)):
    pyplot.subplot(3,2,p+1)
    pyplot.contourf(xx,
                    yy,delta_t_error[p].reshape(10,10).T)
    pyplot.title("bigESN averaged over 10 trials")
    pyplot.xlabel("Leak-rate")
    pyplot.ylabel("Spectral-radius")
    pyplot.colorbar()

# %%
bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(i))

# Divide in training and test data
traintest_cutoff = int(np.ceil(0.7 * len(bits)))
train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
#     train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]

bigESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=350,  # from 200 onwards test error decreases significantly
                          spectral_radius=0.6,  # high spectral rad is better (high fluctuations 0->1->0)
                          leak_rate= 0.3,   # adjust leak_rate
                          delta_t= 0.1,
                          sparsity=0.95,     # 0.95
                          noise=0.01,      # 0.01
                          input_shift=0,    # 0
                          input_scaling=3,  # 3 seems to be fine. Maybe use lower
                          teacher_forcing=False, # No need for teacher forcing because we have no pattern
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          random_state=rng,
                          silent=False)
bigESN.fit(train_bits, train_target)#, inspect= True)
pred_test = bigESN.predict(test_bits)

predictedTarget = pred_test
print("Testing error")
test_error = np.sqrt(np.mean((predictedTarget - test_target) ** 2))
print(test_error)

# %%
plt.figure(figsize=(12,6))
plt.subplot(111)
print(len(predictedTarget))
# plt.plot(predictedParity[66600:66800])
plt.plot(predictedTarget[6000:8000],"b")
plt.plot(test_target[6000:8000], "r")
plt.show()
