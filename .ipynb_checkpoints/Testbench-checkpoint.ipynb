# %%
import Parity_Data_Generator
import numpy as np
from pyESN import ESN
import time

N = 7000   # number of datapoints
n = 3       # n-parity
rng = np.random.RandomState(42)

# %% [markdown]
# start_time = time.time()
# # produce Data
# bits, parity, target = Parity_Data_Generator.generateParityData(N, n, randomstate=rng)
#
# # Divide in training and test data
# traintest_cutoff = int(np.ceil(0.7 * len(bits)))
# train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
# train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
# train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
#
# print("--- %s seconds ---" % (time.time() - start_time))

# %%
def runSomeConfigs(spectral_rad, leak_r, train_bits, test_bits, train_parity, test_parity):
#     print("Spectral-radius:",spectral_rad, "leak-rate:", leak_r)
    nParityESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=500,  # from 200 onwards test error decreases significantly
                          spectral_radius=spectral_rad,  # high spectral rad is better (high fluctuations 0->1->0)
                          leak_rate= leak_r,   # adjust leak_rate
                          sparsity=0.95,
                          noise=0.001,
                          input_shift=0,
                          input_scaling=3,  # 3 seems to be fine. Maybe use lower
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          out_activation=np.tanh,
                          inverse_out_activation=np.arctanh,
                          random_state=rng,
                          silent=False)
    # print(np.shape(bits),np.shape(parity),np.shape(target))
    nParityESN.fit(train_bits, train_parity)
    pred_test = nParityESN.predict(test_bits)

    #### not rounding
    predictedParity = pred_test # not rounding
    #### Rounding
#     better_pred_test = []           # Maybe don't round and return "true" results from pred_test
#     for x in pred_test:
#         better_pred_test.append(0 if x < 0.5 else 1)
#     predictedParity = np.array(better_pred_test).reshape(-1,1)
#     print(test_parity[40030:40100].reshape(-1))
#     print(predictedParity[40030:40100].reshape(-1))
    
    print("Testing error")
    test_error = np.sqrt(np.mean((predictedParity - test_parity) ** 2))
    print(test_error)
    return test_error

def produceTrainingData(randomState):
    bits, parity, target = Parity_Data_Generator.generateParityData(N, n, randomstate=np.random.RandomState(randomState))

    # Divide in training and test data
    traintest_cutoff = int(np.ceil(0.7 * len(bits)))
    train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
    train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
#     train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
    return train_bits, test_bits, train_parity, test_parity

# %%
trials = 10
# num_neurons = [500, 600, 700, 800, 900, 1000]
# num_neurons = [500]
n = 500
# num_neurons = [100, 200, 300, 400, 500, 600, 700, 800]
l_rate = np.linspace(0.1, 1, num=10)
# l_rate =[0.1]
# l_rate = [0.1,0.2,0.3]
# sp_rad = np.linspace(0.9, 1.0, num=5)
sp_rad = np.linspace(0.1, 1, num=10)
# sp_rad = [0.9,0.92,0.94,0.96,0.98, 1]

run_time = time.time()
iterations, iterationcount = trials*len(sp_rad)*len(l_rate), 0
errors = []
all_errors = [{} for _ in range(trials)] # empty dict
for i in range(trials):
    errors = []
    # produce training and testing data
    train_bits, test_bits, train_parity, test_parity = produceTrainingData(i)
    
    for l in l_rate:
        for s in sp_rad:
            print("Neurons:", n, "Spectral-radius:", s, "Leak-rate:", l)
            errors.append(runSomeConfigs(s,l, train_bits, test_bits, train_parity, test_parity))
            iterationcount = iterationcount + 1
            print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
    ## Save leak-rate,spectral-radius and error in dictionary
    all_errors[i] = errors
            
print("Total time for Testbench:")
print("--- {:.2f} seconds ---".format(time.time() - run_time))
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.16795847495
# Testing error
# 0.737055221884
# --- Progress: 0.10% --- 0.28 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.179196707992
# Testing error
# 0.724590111676
# --- Progress: 0.20% --- 0.52 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.188918441297
# Testing error
# 0.689753618398
# --- Progress: 0.30% --- 0.76 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.19511161275
# Testing error
# 0.799662669771
# --- Progress: 0.40% --- 1.01 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.210272409207
# Testing error
# 0.682305311981
# --- Progress: 0.50% --- 1.25 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.210799464924
# Testing error
# 0.632324415436
# --- Progress: 0.60% --- 1.50 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.222991524009
# Testing error
# 0.615926438976
# --- Progress: 0.70% --- 1.74 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.22780716436
# Testing error
# 0.641423595912
# --- Progress: 0.80% --- 1.99 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.247199415935
# Testing error
# 0.61051050715
# --- Progress: 0.90% --- 2.23 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.250723034047
# Testing error
# 0.61309779074
# --- Progress: 1.00% --- 2.47 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.145313099967
# Testing error
# 0.663172943885
# --- Progress: 1.10% --- 2.72 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.144259871176
# Testing error
# 0.703893941407
# --- Progress: 1.20% --- 2.96 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.144223825694
# Testing error
# 0.681447445107
# --- Progress: 1.30% --- 3.21 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.147431466907
# Testing error
# 0.702165112142
# --- Progress: 1.40% --- 3.45 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.151056078377
# Testing error
# 0.848894074849
# --- Progress: 1.50% --- 3.70 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.154915802312
# Testing error
# 0.823430772293
# --- Progress: 1.60% --- 3.95 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.166350850766
# Testing error
# 0.652103859307
# --- Progress: 1.70% --- 4.19 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.170358839878
# Testing error
# 0.603250994713
# --- Progress: 1.80% --- 4.44 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.177610445386
# Testing error
# 0.621365578638
# --- Progress: 1.90% --- 4.69 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.18372906526
# Testing error
# 0.611585146277
# --- Progress: 2.00% --- 4.93 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.146111608754
# Testing error
# 0.761466136113
# --- Progress: 2.10% --- 5.17 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.145402181106
# Testing error
# 0.868234340334
# --- Progress: 2.20% --- 5.41 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.144286306416
# Testing error
# 0.776612197129
# --- Progress: 2.30% --- 5.66 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.143496030569
# Testing error
# 0.688559230227
# --- Progress: 2.40% --- 5.90 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.143696007723
# Testing error
# 0.729465020591
# --- Progress: 2.50% --- 6.14 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.144376953328
# Testing error
# 0.813161413749
# --- Progress: 2.60% --- 6.39 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.146576675398
# Testing error
# 0.720893961539
# --- Progress: 2.70% --- 6.63 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.148885221418
# Testing error
# 0.638170162349
# --- Progress: 2.80% --- 6.87 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.154110872476
# Testing error
# 0.637438543543
# --- Progress: 2.90% --- 7.12 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.156434313492
# Testing error
# 0.642292899265
# --- Progress: 3.00% --- 7.36 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.146425018211
# Testing error
# 0.622383405239
# --- Progress: 3.10% --- 7.61 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.145926976662
# Testing error
# 0.77634559453
# --- Progress: 3.20% --- 7.84 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.145255955757
# Testing error
# 0.848017651053
# --- Progress: 3.30% --- 8.09 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.144388468384
# Testing error
# 0.7574251879
# --- Progress: 3.40% --- 8.33 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.143570720114
# Testing error
# 0.846401519546
# --- Progress: 3.50% --- 8.57 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.142661741548
# Testing error
# 0.67686072381
# --- Progress: 3.60% --- 8.81 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.143021341682
# Testing error
# 0.658497689554
# --- Progress: 3.70% --- 9.05 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.143989248869
# Testing error
# 0.682321201049
# --- Progress: 3.80% --- 9.30 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.144749857582
# Testing error
# 0.661475126556
# --- Progress: 3.90% --- 9.54 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.146702787118
# Testing error
# 0.657108579416
# --- Progress: 4.00% --- 9.78 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.146694862555
# Testing error
# 0.534195869821
# --- Progress: 4.10% --- 10.02 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.146485755324
# Testing error
# 0.629475074447
# --- Progress: 4.20% --- 10.26 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.145913712062
# Testing error
# 0.779806854464
# --- Progress: 4.30% --- 10.50 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.145090320038
# Testing error
# 0.723621168922
# --- Progress: 4.40% --- 10.75 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.14441281791
# Testing error
# 0.784219206845
# --- Progress: 4.50% --- 10.99 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.142907358428
# Testing error
# 0.691713910676
# --- Progress: 4.60% --- 11.22 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.142206048296
# Testing error
# 0.823114027484
# --- Progress: 4.70% --- 11.47 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.142051733594
# Testing error
# 0.682491467617
# --- Progress: 4.80% --- 11.71 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.14280277579
# Testing error
# 0.64455272383
# --- Progress: 4.90% --- 11.95 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.143025995459
# Testing error
# 0.624478871928
# --- Progress: 5.00% --- 12.19 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.146856471064
# Testing error
# 0.673548296908
# --- Progress: 5.10% --- 12.43 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.14666051324
# Testing error
# 0.594818255868
# --- Progress: 5.20% --- 12.68 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.146444611885
# Testing error
# 0.750630245675
# --- Progress: 5.30% --- 12.92 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.145732435566
# Testing error
# 0.782824322974
# --- Progress: 5.40% --- 13.16 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.144901246927
# Testing error
# 0.799288366824
# --- Progress: 5.50% --- 13.39 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.144274609736
# Testing error
# 0.774517398179
# --- Progress: 5.60% --- 13.64 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.142894450547
# Testing error
# 0.750653854618
# --- Progress: 5.70% --- 13.88 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.141810943468
# Testing error
# 0.7555283341
# --- Progress: 5.80% --- 14.12 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.142023654249
# Testing error
# 0.731523962954
# --- Progress: 5.90% --- 14.36 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.1421422968
# Testing error
# 0.639259533793
# --- Progress: 6.00% --- 14.60 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.147092757247
# Testing error
# 0.56491529254
# --- Progress: 6.10% --- 14.84 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.146889076584
# Testing error
# 0.588399484008
# --- Progress: 6.20% --- 15.08 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.146638885582
# Testing error
# 0.810000330029
# --- Progress: 6.30% --- 15.32 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.146443462114
# Testing error
# 0.684261457848
# --- Progress: 6.40% --- 15.56 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.14553410476
# Testing error
# 0.681717038601
# --- Progress: 6.50% --- 15.80 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.144604074591
# Testing error
# 0.919540454334
# --- Progress: 6.60% --- 16.05 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.143588519987
# Testing error
# 0.891100993988
# --- Progress: 6.70% --- 16.29 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.142911182238
# Testing error
# 0.728071409372
# --- Progress: 6.80% --- 16.53 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.141424616539
# Testing error
# 0.827613686914
# --- Progress: 6.90% --- 16.77 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.140528358541
# Testing error
# 0.697199286052
# --- Progress: 7.00% --- 17.02 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.14718454671
# Testing error
# 0.592555749552
# --- Progress: 7.10% --- 17.26 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.147011549313
# Testing error
# 0.605738334457
# --- Progress: 7.20% --- 17.50 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.14684910361
# Testing error
# 0.60972753327
# --- Progress: 7.30% --- 17.74 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.146657908025
# Testing error
# 0.638371472047
# --- Progress: 7.40% --- 17.98 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.146045957443
# Testing error
# 0.762727020569
# --- Progress: 7.50% --- 18.22 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.1451661984
# Testing error
# 0.693581351058
# --- Progress: 7.60% --- 18.46 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.144199122384
# Testing error
# 0.702236375717
# --- Progress: 7.70% --- 18.70 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.142710688643
# Testing error
# 0.818967634927
# --- Progress: 7.80% --- 18.95 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.141279648018
# Testing error
# 0.806048571692
# --- Progress: 7.90% --- 19.20 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.139924111739
# Testing error
# 0.834363476251
# --- Progress: 8.00% --- 19.46 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.14718960524
# Testing error
# 0.586726364516
# --- Progress: 8.10% --- 19.70 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.147086040788
# Testing error
# 0.593186607533
# --- Progress: 8.20% --- 19.95 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.147062434444
# Testing error
# 0.611336628738
# --- Progress: 8.30% --- 20.20 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.146917662243
# Testing error
# 0.598539416283
# --- Progress: 8.40% --- 20.44 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.146700262987
# Testing error
# 0.894888117335
# --- Progress: 8.50% --- 20.69 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.146004037007
# Testing error
# 0.698528901995
# --- Progress: 8.60% --- 20.94 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.14482836818
# Testing error
# 0.808263171864
# --- Progress: 8.70% --- 21.18 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.142755432971
# Testing error
# 0.737545030718
# --- Progress: 8.80% --- 21.43 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.140480883168
# Testing error
# 0.857301297358
# --- Progress: 8.90% --- 21.67 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.138597716647
# Testing error
# 0.758859866976
# --- Progress: 9.00% --- 21.95 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.147152946759
# Testing error
# 0.58994856646
# --- Progress: 9.10% --- 22.20 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.147167691206
# Testing error
# 0.611057517992
# --- Progress: 9.20% --- 22.45 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.147045057641
# Testing error
# 0.598132461918
# --- Progress: 9.30% --- 22.70 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.147069793527
# Testing error
# 0.628653194295
# --- Progress: 9.40% --- 22.95 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.146923814043
# Testing error
# 0.713446584743
# --- Progress: 9.50% --- 23.19 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.146564396714
# Testing error
# 0.669317998806
# --- Progress: 9.60% --- 23.45 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.14504144067
# Testing error
# 0.789310642681
# --- Progress: 9.70% --- 23.69 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.141831490677
# Testing error
# 0.757999265563
# --- Progress: 9.80% --- 23.93 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.139295323359
# Testing error
# 0.854257053878
# --- Progress: 9.90% --- 24.18 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.138085857384
# Testing error
# 0.743921907558
# --- Progress: 10.00% --- 24.42 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.171952798253
# Testing error
# 0.75065048318
# --- Progress: 10.10% --- 24.70 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.179717344712
# Testing error
# 0.764234862404
# --- Progress: 10.20% --- 24.95 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.184385287647
# Testing error
# 0.864873971049
# --- Progress: 10.30% --- 25.20 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.199091746371
# Testing error
# 0.9143750799
# --- Progress: 10.40% --- 25.45 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205557383079
# Testing error
# 0.682897833221
# --- Progress: 10.50% --- 25.70 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.225224403524
# Testing error
# 0.637452436688
# --- Progress: 10.60% --- 25.94 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.233867688368
# Testing error
# 0.631081079179
# --- Progress: 10.70% --- 26.19 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.225392955713
# Testing error
# 0.606012906251
# --- Progress: 10.80% --- 26.44 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.240176348509
# Testing error
# 0.592243615965
# --- Progress: 10.90% --- 26.69 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.249341680262
# Testing error
# 0.58905672464
# --- Progress: 11.00% --- 26.94 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.144540413821
# Testing error
# 0.787981103951
# --- Progress: 11.10% --- 27.19 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.143517984439
# Testing error
# 0.711364915704
# --- Progress: 11.20% --- 27.43 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.143815345444
# Testing error
# 0.723967400021
# --- Progress: 11.30% --- 27.69 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.145070096572
# Testing error
# 0.832869406239
# --- Progress: 11.40% --- 27.95 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.153227239316
# Testing error
# 0.695345167584
# --- Progress: 11.50% --- 28.20 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.160461405727
# Testing error
# 0.821290756831
# --- Progress: 11.60% --- 28.45 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.166781542144
# Testing error
# 0.621975121246
# --- Progress: 11.70% --- 28.71 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.171937077537
# Testing error
# 0.628339293729
# --- Progress: 11.80% --- 28.96 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.175331715044
# Testing error
# 0.617960098875
# --- Progress: 11.90% --- 29.21 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.186876753361
# Testing error
# 0.583803021496
# --- Progress: 12.00% --- 29.46 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.145185536079
# Testing error
# 0.828599154193
# --- Progress: 12.10% --- 29.71 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.144550907572
# Testing error
# 0.832926067256
# --- Progress: 12.20% --- 29.97 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.143837190244
# Testing error
# 0.67119187433
# --- Progress: 12.30% --- 30.22 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.142736775415
# Testing error
# 0.741400207126
# --- Progress: 12.40% --- 30.47 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.142924392764
# Testing error
# 0.786124747113
# --- Progress: 12.50% --- 30.73 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.144783943878
# Testing error
# 0.72227658248
# --- Progress: 12.60% --- 31.00 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.146759731697
# Testing error
# 0.710621685223
# --- Progress: 12.70% --- 31.25 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.152009790614
# Testing error
# 0.615266564504
# --- Progress: 12.80% --- 31.50 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.155147759359
# Testing error
# 0.598560834423
# --- Progress: 12.90% --- 31.75 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.158669835086
# Testing error
# 0.622447905532
# --- Progress: 13.00% --- 32.00 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.145806424807
# Testing error
# 0.609294551462
# --- Progress: 13.10% --- 32.24 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.14512954379
# Testing error
# 0.834895263185
# --- Progress: 13.20% --- 32.50 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.144503678926
# Testing error
# 0.785149565939
# --- Progress: 13.30% --- 32.75 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.143778823596
# Testing error
# 0.796824539025
# --- Progress: 13.40% --- 33.00 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.143105748764
# Testing error
# 0.87592683316
# --- Progress: 13.50% --- 33.24 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.142552588684
# Testing error
# 0.71538579864
# --- Progress: 13.60% --- 33.49 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.142531538236
# Testing error
# 0.72319088582
# --- Progress: 13.70% --- 33.74 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.144174956346
# Testing error
# 0.635653118775
# --- Progress: 13.80% --- 33.99 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.145278879709
# Testing error
# 0.640056180123
# --- Progress: 13.90% --- 34.25 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.147973512606
# Testing error
# 0.630210297406
# --- Progress: 14.00% --- 34.50 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.146017254541
# Testing error
# 0.582401467978
# --- Progress: 14.10% --- 34.75 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.145763413021
# Testing error
# 0.769240818408
# --- Progress: 14.20% --- 35.01 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.145184042256
# Testing error
# 0.654219950825
# --- Progress: 14.30% --- 35.26 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.144267107922
# Testing error
# 0.721646558264
# --- Progress: 14.40% --- 35.50 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.143603961595
# Testing error
# 0.747730307636
# --- Progress: 14.50% --- 35.75 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.142694615662
# Testing error
# 0.713504594034
# --- Progress: 14.60% --- 35.99 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.141815429228
# Testing error
# 0.670271290845
# --- Progress: 14.70% --- 36.24 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.141941307505
# Testing error
# 0.747061685342
# --- Progress: 14.80% --- 36.49 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.142676173212
# Testing error
# 0.612592854276
# --- Progress: 14.90% --- 36.73 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.143420298285
# Testing error
# 0.597896039643
# --- Progress: 15.00% --- 36.98 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.14616621142
# Testing error
# 0.629259427125
# --- Progress: 15.10% --- 37.23 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.146024717151
# Testing error
# 0.675403793171
# --- Progress: 15.20% --- 37.47 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.145700131411
# Testing error
# 0.647515134774
# --- Progress: 15.30% --- 37.72 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.144957097103
# Testing error
# 0.667245055039
# --- Progress: 15.40% --- 37.97 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.144190851408
# Testing error
# 0.852765407803
# --- Progress: 15.50% --- 38.21 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.143608201139
# Testing error
# 0.920983614402
# --- Progress: 15.60% --- 38.46 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.142428240834
# Testing error
# 0.719581138336
# --- Progress: 15.70% --- 38.70 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.141234166585
# Testing error
# 0.727893834178
# --- Progress: 15.80% --- 38.95 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.141766903919
# Testing error
# 0.666464636099
# --- Progress: 15.90% --- 39.19 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.140704397842
# Testing error
# 0.62561526328
# --- Progress: 16.00% --- 39.44 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.146269165971
# Testing error
# 0.521554207195
# --- Progress: 16.10% --- 39.68 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.146150215148
# Testing error
# 0.588041761729
# --- Progress: 16.20% --- 39.92 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.145929829656
# Testing error
# 0.604942641429
# --- Progress: 16.30% --- 40.16 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.145611626459
# Testing error
# 0.705488576487
# --- Progress: 16.40% --- 40.41 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.144995804744
# Testing error
# 0.676895844413
# --- Progress: 16.50% --- 40.65 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.143815576041
# Testing error
# 0.713284391288
# --- Progress: 16.60% --- 40.89 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.142922066677
# Testing error
# 0.760535215795
# --- Progress: 16.70% --- 41.13 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.142020276064
# Testing error
# 0.768421600534
# --- Progress: 16.80% --- 41.38 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.140682111589
# Testing error
# 0.88325145788
# --- Progress: 16.90% --- 41.62 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.140703700671
# Testing error
# 0.72784064752
# --- Progress: 17.00% --- 41.88 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.146349128335
# Testing error
# 0.606016325804
# --- Progress: 17.10% --- 42.12 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.146224721368
# Testing error
# 0.663349710575
# --- Progress: 17.20% --- 42.36 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.146056912236
# Testing error
# 0.693614169621
# --- Progress: 17.30% --- 42.61 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.145960425578
# Testing error
# 0.736812757414
# --- Progress: 17.40% --- 42.85 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.145574592601
# Testing error
# 0.763140800501
# --- Progress: 17.50% --- 43.09 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.14453173299
# Testing error
# 0.78342794117
# --- Progress: 17.60% --- 43.34 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.143489240933
# Testing error
# 0.738402007874
# --- Progress: 17.70% --- 43.58 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.142234847181
# Testing error
# 0.956097025068
# --- Progress: 17.80% --- 43.83 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.140465157995
# Testing error
# 0.783264903858
# --- Progress: 17.90% --- 44.07 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.13948014802
# Testing error
# 0.727103151722
# --- Progress: 18.00% --- 44.32 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.146385928055
# Testing error
# 0.598656787522
# --- Progress: 18.10% --- 44.56 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.146382152858
# Testing error
# 0.619624281467
# --- Progress: 18.20% --- 44.81 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.146183973029
# Testing error
# 0.642679525581
# --- Progress: 18.30% --- 45.05 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.146202456558
# Testing error
# 0.571076865135
# --- Progress: 18.40% --- 45.29 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.146047663224
# Testing error
# 0.824094639678
# --- Progress: 18.50% --- 45.54 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.145659708659
# Testing error
# 0.73742112121
# --- Progress: 18.60% --- 45.78 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.144419895545
# Testing error
# 0.741746851531
# --- Progress: 18.70% --- 46.02 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.14242076173
# Testing error
# 0.90139674574
# --- Progress: 18.80% --- 46.27 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.13981432117
# Testing error
# 0.78324673788
# --- Progress: 18.90% --- 46.51 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.139176154312
# Testing error
# 0.762054844073
# --- Progress: 19.00% --- 46.75 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.146473713615
# Testing error
# 0.622111408541
# --- Progress: 19.10% --- 46.99 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.146388734068
# Testing error
# 0.619649965701
# --- Progress: 19.20% --- 47.23 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.146357395451
# Testing error
# 0.7933661297
# --- Progress: 19.30% --- 47.47 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.146323981897
# Testing error
# 0.634932013488
# --- Progress: 19.40% --- 47.71 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.146247525307
# Testing error
# 0.669823487033
# --- Progress: 19.50% --- 47.95 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.145983518511
# Testing error
# 0.718887326677
# --- Progress: 19.60% --- 48.19 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.144996039115
# Testing error
# 0.704195912281
# --- Progress: 19.70% --- 48.43 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.141496833779
# Testing error
# 0.917177580339
# --- Progress: 19.80% --- 48.68 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.138802331816
# Testing error
# 0.78152594578
# --- Progress: 19.90% --- 48.92 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.137084610351
# Testing error
# 0.800903593491
# --- Progress: 20.00% --- 49.16 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.17349864478
# Testing error
# 0.717015453021
# --- Progress: 20.10% --- 49.44 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.181460048279
# Testing error
# 0.817185146562
# --- Progress: 20.20% --- 49.68 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.195038895005
# Testing error
# 0.703932857971
# --- Progress: 20.30% --- 49.93 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.195569000548
# Testing error
# 0.701435974346
# --- Progress: 20.40% --- 50.18 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198577130803
# Testing error
# 0.653042859403
# --- Progress: 20.50% --- 50.43 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217242207946
# Testing error
# 0.660129263973
# --- Progress: 20.60% --- 50.68 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.222001746449
# Testing error
# 0.62746597762
# --- Progress: 20.70% --- 50.93 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.239057913237
# Testing error
# 0.592998390506
# --- Progress: 20.80% --- 51.17 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.245697520123
# Testing error
# 0.58367096548
# --- Progress: 20.90% --- 51.42 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.254693433049
# Testing error
# 0.589768814069
# --- Progress: 21.00% --- 51.67 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.143578377436
# Testing error
# 0.708378224035
# --- Progress: 21.10% --- 51.91 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.142506256053
# Testing error
# 0.792073548385
# --- Progress: 21.20% --- 52.16 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.142351491379
# Testing error
# 0.653582240895
# --- Progress: 21.30% --- 52.41 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.144007055144
# Testing error
# 0.777997931271
# --- Progress: 21.40% --- 52.66 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.150154129125
# Testing error
# 0.7723998009
# --- Progress: 21.50% --- 52.91 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.156071414827
# Testing error
# 0.697309099918
# --- Progress: 21.60% --- 53.16 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.163362149043
# Testing error
# 0.648546667187
# --- Progress: 21.70% --- 53.41 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.171804912255
# Testing error
# 0.640254190431
# --- Progress: 21.80% --- 53.66 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.17415789121
# Testing error
# 0.640800270023
# --- Progress: 21.90% --- 53.91 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.181887651842
# Testing error
# 0.625606399291
# --- Progress: 22.00% --- 54.16 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.144305145095
# Testing error
# 0.642089476999
# --- Progress: 22.10% --- 54.41 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.14372375845
# Testing error
# 0.759914515396
# --- Progress: 22.20% --- 54.66 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.142797752729
# Testing error
# 0.933938232173
# --- Progress: 22.30% --- 54.90 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.142029163434
# Testing error
# 0.737592261519
# --- Progress: 22.40% --- 55.15 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.14201559807
# Testing error
# 0.77401450849
# --- Progress: 22.50% --- 55.40 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.142914835233
# Testing error
# 0.715791102841
# --- Progress: 22.60% --- 55.64 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.144303581618
# Testing error
# 0.676900353874
# --- Progress: 22.70% --- 55.89 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.1475645171
# Testing error
# 0.671209150832
# --- Progress: 22.80% --- 56.14 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.15244387481
# Testing error
# 0.62589240975
# --- Progress: 22.90% --- 56.38 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.154760214292
# Testing error
# 0.623539600345
# --- Progress: 23.00% --- 56.63 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.144874397648
# Testing error
# 0.584679306186
# --- Progress: 23.10% --- 56.88 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.144303115272
# Testing error
# 0.909904651802
# --- Progress: 23.20% --- 57.13 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.143666594789
# Testing error
# 0.740782502434
# --- Progress: 23.30% --- 57.37 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.142787053438
# Testing error
# 0.943663888327
# --- Progress: 23.40% --- 57.61 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.141691574642
# Testing error
# 0.753601094977
# --- Progress: 23.50% --- 57.86 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.141096049719
# Testing error
# 0.728505224942
# --- Progress: 23.60% --- 58.11 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.141357574208
# Testing error
# 0.720112905457
# --- Progress: 23.70% --- 58.36 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.142178616387
# Testing error
# 0.642848774649
# --- Progress: 23.80% --- 58.61 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.142751974799
# Testing error
# 0.619808505642
# --- Progress: 23.90% --- 58.85 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.145978588495
# Testing error
# 0.638316137386
# --- Progress: 24.00% --- 59.10 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.145172121055
# Testing error
# 0.734107823909
# --- Progress: 24.10% --- 59.34 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.144943859165
# Testing error
# 0.712813315552
# --- Progress: 24.20% --- 59.60 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.144428610509
# Testing error
# 0.871827884408
# --- Progress: 24.30% --- 59.85 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.14354858333
# Testing error
# 0.839498914275
# --- Progress: 24.40% --- 60.09 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.142702397452
# Testing error
# 0.792891546075
# --- Progress: 24.50% --- 60.34 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.141926294961
# Testing error
# 0.729868071569
# --- Progress: 24.60% --- 60.59 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.140718463335
# Testing error
# 0.704297046384
# --- Progress: 24.70% --- 60.84 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.140649875749
# Testing error
# 0.808968715172
# --- Progress: 24.80% --- 61.09 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.141014695449
# Testing error
# 0.707135080102
# --- Progress: 24.90% --- 61.33 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.142051905134
# Testing error
# 0.63465819654
# --- Progress: 25.00% --- 61.58 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.145352144435
# Testing error
# 0.602351635323
# --- Progress: 25.10% --- 61.83 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.145081355735
# Testing error
# 0.750822650986
# --- Progress: 25.20% --- 62.07 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.144976485845
# Testing error
# 0.699218466075
# --- Progress: 25.30% --- 62.32 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.144172767482
# Testing error
# 0.771492444411
# --- Progress: 25.40% --- 62.56 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.143423120497
# Testing error
# 0.728270513088
# --- Progress: 25.50% --- 62.81 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.142686013208
# Testing error
# 0.704595135011
# --- Progress: 25.60% --- 63.05 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.141585597711
# Testing error
# 0.782379879534
# --- Progress: 25.70% --- 63.30 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.140716749257
# Testing error
# 0.803165592076
# --- Progress: 25.80% --- 63.54 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.139868104095
# Testing error
# 0.847010134292
# --- Progress: 25.90% --- 63.79 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.140323428871
# Testing error
# 0.708572641689
# --- Progress: 26.00% --- 64.04 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.145457889077
# Testing error
# 0.661999488669
# --- Progress: 26.10% --- 64.28 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.145271686404
# Testing error
# 0.660476185124
# --- Progress: 26.20% --- 64.53 minutes ---
# ...
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.147220305384
# Testing error
# 0.728962479331
# --- Progress: 91.50% --- 223.28 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.158022308088
# Testing error
# 0.652014063577
# --- Progress: 91.60% --- 223.52 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.158343760095
# Testing error
# 0.642353117386
# --- Progress: 91.70% --- 223.76 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.166936868883
# Testing error
# 0.628977445976
# --- Progress: 91.80% --- 224.00 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.173077572391
# Testing error
# 0.621758671859
# --- Progress: 91.90% --- 224.24 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.182322528951
# Testing error
# 0.605537563742
# --- Progress: 92.00% --- 224.48 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.142528623213
# Testing error
# 0.618980876155
# --- Progress: 92.10% --- 224.72 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.14189623926
# Testing error
# 0.655885296721
# --- Progress: 92.20% --- 224.96 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.141055560209
# Testing error
# 0.749657273897
# --- Progress: 92.30% --- 225.19 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.140306240613
# Testing error
# 0.775084602476
# --- Progress: 92.40% --- 225.43 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.140395585008
# Testing error
# 0.699798028989
# --- Progress: 92.50% --- 225.67 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.141679819925
# Testing error
# 0.778147137763
# --- Progress: 92.60% --- 225.91 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.144560997132
# Testing error
# 0.676404589326
# --- Progress: 92.70% --- 226.15 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.147032960337
# Testing error
# 0.635359667239
# --- Progress: 92.80% --- 226.39 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.152303759984
# Testing error
# 0.597576466189
# --- Progress: 92.90% --- 226.63 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.155213314477
# Testing error
# 0.620934133611
# --- Progress: 93.00% --- 226.87 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.143210581323
# Testing error
# 0.903104759298
# --- Progress: 93.10% --- 227.12 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.142679366491
# Testing error
# 0.792584890901
# --- Progress: 93.20% --- 227.36 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.141897116425
# Testing error
# 0.938191170397
# --- Progress: 93.30% --- 227.60 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.140956291849
# Testing error
# 0.781622976067
# --- Progress: 93.40% --- 227.84 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.140318365188
# Testing error
# 0.782383660573
# --- Progress: 93.50% --- 228.08 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.140400517261
# Testing error
# 0.646004215602
# --- Progress: 93.60% --- 228.33 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.140075799435
# Testing error
# 0.685417311039
# --- Progress: 93.70% --- 228.57 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.141039995529
# Testing error
# 0.617134066428
# --- Progress: 93.80% --- 228.81 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.143388986785
# Testing error
# 0.641658080765
# --- Progress: 93.90% --- 229.06 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.143894660976
# Testing error
# 0.619040613964
# --- Progress: 94.00% --- 229.31 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.14340896739
# Testing error
# 0.592350138779
# --- Progress: 94.10% --- 229.55 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.143241345827
# Testing error
# 0.6207385007
# --- Progress: 94.20% --- 229.80 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.142632751279
# Testing error
# 0.881433758777
# --- Progress: 94.30% --- 230.04 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.141996395401
# Testing error
# 0.735365699732
# --- Progress: 94.40% --- 230.30 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.141073749689
# Testing error
# 0.841675240103
# --- Progress: 94.50% --- 230.54 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.140152191716
# Testing error
# 0.79685474867
# --- Progress: 94.60% --- 230.78 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.13945643801
# Testing error
# 0.727996407515
# --- Progress: 94.70% --- 231.02 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.139610359664
# Testing error
# 0.717573779986
# --- Progress: 94.80% --- 231.26 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.139460906638
# Testing error
# 0.701041201079
# --- Progress: 94.90% --- 231.51 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.140616958713
# Testing error
# 0.636773506357
# --- Progress: 95.00% --- 231.75 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.14361181872
# Testing error
# 0.544931425883
# --- Progress: 95.10% --- 232.00 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.14338799961
# Testing error
# 0.613476845714
# --- Progress: 95.20% --- 232.24 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.143246199405
# Testing error
# 0.67415028876
# --- Progress: 95.30% --- 232.48 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.142472330345
# Testing error
# 0.804247469805
# --- Progress: 95.40% --- 232.71 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.141786569005
# Testing error
# 0.715396861457
# --- Progress: 95.50% --- 232.95 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.141070029548
# Testing error
# 0.846839972586
# --- Progress: 95.60% --- 233.20 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.140427190631
# Testing error
# 0.740130653164
# --- Progress: 95.70% --- 233.44 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.13896589956
# Testing error
# 0.860739445008
# --- Progress: 95.80% --- 233.69 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.138459313742
# Testing error
# 0.689068669265
# --- Progress: 95.90% --- 233.93 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.139576327591
# Testing error
# 0.616846895539
# --- Progress: 96.00% --- 234.17 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.14372982031
# Testing error
# 0.570991348713
# --- Progress: 96.10% --- 234.41 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.143581276882
# Testing error
# 0.615409584844
# --- Progress: 96.20% --- 234.65 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.143431805255
# Testing error
# 0.577091509134
# --- Progress: 96.30% --- 234.89 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.143160450718
# Testing error
# 0.715358900783
# --- Progress: 96.40% --- 235.13 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.142491889012
# Testing error
# 0.88689827861
# --- Progress: 96.50% --- 235.36 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.141408448609
# Testing error
# 0.761777012646
# --- Progress: 96.60% --- 235.60 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.14078368773
# Testing error
# 0.773777487086
# --- Progress: 96.70% --- 235.84 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.139703982862
# Testing error
# 0.744874832298
# --- Progress: 96.80% --- 236.08 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.138005877286
# Testing error
# 0.800325748691
# --- Progress: 96.90% --- 236.32 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.138122019242
# Testing error
# 0.730915091383
# --- Progress: 97.00% --- 236.56 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.143728080173
# Testing error
# 0.567300267487
# --- Progress: 97.10% --- 236.80 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.143718759577
# Testing error
# 0.597353848349
# --- Progress: 97.20% --- 237.04 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.143572406719
# Testing error
# 0.609403893856
# --- Progress: 97.30% --- 237.27 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.143446168072
# Testing error
# 0.697276511723
# --- Progress: 97.40% --- 237.52 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.143090339422
# Testing error
# 0.785066780284
# --- Progress: 97.50% --- 237.75 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.142102693892
# Testing error
# 0.748292226771
# --- Progress: 97.60% --- 238.00 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.141096765146
# Testing error
# 0.796162545024
# --- Progress: 97.70% --- 238.24 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.139988287515
# Testing error
# 0.83625938617
# --- Progress: 97.80% --- 238.48 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.138820265984
# Testing error
# 0.762816516907
# --- Progress: 97.90% --- 238.73 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.137584172696
# Testing error
# 0.781111518949
# --- Progress: 98.00% --- 238.97 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.143806843128
# Testing error
# 0.568646678369
# --- Progress: 98.10% --- 239.21 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.143802498995
# Testing error
# 0.614290698874
# --- Progress: 98.20% --- 239.46 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.143693576383
# Testing error
# 0.662565641749
# --- Progress: 98.30% --- 239.70 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.143624532834
# Testing error
# 0.612418567773
# --- Progress: 98.40% --- 239.94 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.143522070632
# Testing error
# 0.699368476744
# --- Progress: 98.50% --- 240.18 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.143094417377
# Testing error
# 0.715427727212
# --- Progress: 98.60% --- 240.42 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.14188750684
# Testing error
# 0.70274774303
# --- Progress: 98.70% --- 240.66 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.139594187897
# Testing error
# 0.790284092653
# --- Progress: 98.80% --- 240.90 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.137723586943
# Testing error
# 0.727632063056
# --- Progress: 98.90% --- 241.14 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.13678746774
# Testing error
# 0.812733399821
# --- Progress: 99.00% --- 241.38 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.143826192772
# Testing error
# 0.570905742005
# --- Progress: 99.10% --- 241.62 minutes ---
# Neurons: 500 Spectral-radius: 0.2 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.14377104187
# Testing error
# 0.634196849222
# --- Progress: 99.20% --- 241.86 minutes ---
# Neurons: 500 Spectral-radius: 0.3 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.143721543768
# Testing error
# 0.624316228003
# --- Progress: 99.30% --- 242.10 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.143729641657
# Testing error
# 0.684844034675
# --- Progress: 99.40% --- 242.34 minutes ---
# Neurons: 500 Spectral-radius: 0.5 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.143626490969
# Testing error
# 0.64952452396
# --- Progress: 99.50% --- 242.59 minutes ---
# Neurons: 500 Spectral-radius: 0.6 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.143515924089
# Testing error
# 0.699270588317
# --- Progress: 99.60% --- 242.82 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.141880234776
# Testing error
# 0.758511857961
# --- Progress: 99.70% --- 243.07 minutes ---
# Neurons: 500 Spectral-radius: 0.8 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.138907967912
# Testing error
# 0.773483093803
# --- Progress: 99.80% --- 243.31 minutes ---
# Neurons: 500 Spectral-radius: 0.9 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.136189026272
# Testing error
# 0.756622583475
# --- Progress: 99.90% --- 243.55 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.135373438271
# Testing error
# 0.771746719921
# --- Progress: 100.00% --- 243.79 minutes ---
# Total time for Testbench:
# --- 14627.26 seconds ---
# --- 243.79 minutes ---

# %%
import pickle
#### Save Data
# with open('datasaveAverageSlow.p', 'wb') as outputFile:
#     pickle.dump(all_errors, outputFile)
# #     pickle.dump(num_neurons, outputFile)
#     pickle.dump(trials, outputFile)
#     pickle.dump(l_rate, outputFile)
#     pickle.dump(sp_rad, outputFile)
#### Load Data
# with open('datasaveAverageSlow.p', 'rb') as inputFile:
#     all_errors = pickle.load(inputFile)
# #     num_neurons = pickle.load(inputFile)
#     trials = pickle.load(inputfile)
#     l_rate = pickle.load(inputFile)
#     sp_rad = pickle.load(inputFile)

# %%
### Average errors
errorLists = np.zeros(100)
for i in range(len(all_errors)):
    e = all_errors[i]
    errorLists = np.add(errorLists, np.array(e))

errorLists = np.divide(errorLists, trials)
# Out:
# <class 'numpy.ndarray'>
# [ 0.71054866  0.75445873  0.77638588  0.77169606  0.74329063  0.6451233
#   0.6148545   0.60735191  0.59799724  0.59724528  0.76716284  0.76257741
#   0.73333803  0.7184355   0.76732732  0.70620888  0.64675575  0.63293593
#   0.61942795  0.60861806  0.72013618  0.73551312  0.75757475  0.7927151
#   0.74394836  0.71981378  0.68513855  0.65741974  0.62319707  0.61920016
#   0.67844134  0.82538287  0.8249066   0.80035524  0.76823529  0.74350792
#   0.69194268  0.65481667  0.63558957  0.63082156  0.64916848  0.69363213
#   0.75005076  0.75129194  0.80522983  0.77942714  0.73492391  0.7370404
#   0.67258286  0.63282603  0.59159617  0.65406085  0.67403915  0.75081341
#   0.78238317  0.79162624  0.75806848  0.79439447  0.71263107  0.65390656
#   0.58365066  0.60866335  0.67210219  0.69190112  0.73892493  0.75719139
#   0.79784216  0.76814262  0.81568367  0.72726477  0.57378332  0.6142376
#   0.63597697  0.68672908  0.72857736  0.75873651  0.73118368  0.80708434
#   0.80577061  0.78564418  0.59265485  0.60375696  0.63283019  0.62023101
#   0.7059647   0.7062004   0.77228766  0.78887182  0.81402082  0.79008504
#   0.63351367  0.63451781  0.65261541  0.66799884  0.68470337  0.72181207
#   0.76070437  0.80841952  0.81041019  0.75285136]
# ErrorLists-Shape: (100,)
# errorLists[0]-Shape: (1, 1)
# [2 4 6]

# %%
import plotly.plotly as py
import plotly.graph_objs as go
py.sign_in('HansBambel', 'T0F76G8esWCDFNmIVEUv')

# c= ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, len(all_errors))]
# c= ["blue", "orange", "green", "cyan", "yellow", "magenta", "red", "black"]

# x, y, z = all_errors[0]
x = l_rate
y = sp_rad
z = errorLists
trace1 = go.Scatter3d(
    x=x,
    y=y,
    z=z,
    name=("Averaged over", len(trials) ,"Trials"),
    mode='markers',
    marker=dict(
        size=7,
#             color=c[i],                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    )
)

data = [trace1]
layout = go.Layout(
#     margin=dict(
#         l=0,
#         r=0,
#         b=0,
#         t=0
#     ),
#     go.zaxis=dict(
#         range=[0, 0.8]
#     ),
    scene=go.Scene(
        xaxis=go.XAxis(title='x = Leak-Rate'),
        yaxis=go.YAxis(title='y = Spectral Radius'),
        zaxis=go.ZAxis(title='z = Error')
        )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='3d-scatter-errors for different Reservoirsizes')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HansBambel/6.embed" height="525px" width="100%"></iframe>

# %%
data = [
     go.Contour(
        z=errorLists.reshape(10,10),
        x=l_rate,
        y=sp_rad,
        colorscale='Jet',
    )]
py.iplot(data)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HansBambel/14.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go
py.sign_in('HansBambel', 'T0F76G8esWCDFNmIVEUv')

# c= ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, len(all_errors))]
# c= ["blue", "orange", "green", "cyan", "yellow", "magenta", "red", "black"]
data = []
for i, n in enumerate(all_errors):

    x, y, z = all_errors[i]

    trace = go.Scatter3d(
        x=x,
        y=y,
        z=z,
        name=(str(num_neurons[i])+" Neurons"),
        mode='markers',
        marker=dict(
            size=7,
#             color=c[i],                # set color to an array/list of desired values
            colorscale='Viridis',   # choose a colorscale
            opacity=0.8
        )
    )
    data.append(trace)

# data = [trace1]
layout = go.Layout(
#     margin=dict(
#         l=0,
#         r=0,
#         b=0,
#         t=0
#     ),
#     go.zaxis=dict(
#         range=[0, 0.8]
#     ),
    scene=go.Scene(
        xaxis=go.XAxis(title='x = Leak-Rate'),
        yaxis=go.YAxis(title='y = Spectral Radius'),
        zaxis=go.ZAxis(title='z = Error')
        )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='3d-scatter-errors for different Reservoirsizes')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-c6a4570c7f5f> in <module>()
# ----> 1 import plotly.plotly as py
#       2 import plotly.graph_objs as go
#       3 py.sign_in('HansBambel', 'T0F76G8esWCDFNmIVEUv')
#       4
#       5 # c= ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, len(all_errors))]
#
# C:\Program Files\Anaconda3\lib\site-packages\plotly\__init__.py in <module>()
#      29 from __future__ import absolute_import
#      30
# ---> 31 from plotly import (plotly, graph_objs, grid_objs, tools, utils, session,
#      32                     offline, colors)
#      33 from plotly.version import __version__
#
# C:\Program Files\Anaconda3\lib\site-packages\plotly\plotly\__init__.py in <module>()
#       8
#       9 """
# ---> 10 from . plotly import (
#      11     sign_in,
#      12     update_plot_options,
#
# C:\Program Files\Anaconda3\lib\site-packages\plotly\plotly\plotly.py in <module>()
#      29 from requests.auth import HTTPBasicAuth
#      30
# ---> 31 from plotly import exceptions, tools, utils, version, files
#      32 from plotly.plotly import chunked_requests
#      33 from plotly.session import (sign_in, update_session_plot_options,
#
# C:\Program Files\Anaconda3\lib\site-packages\plotly\tools.py in <module>()
#      19 from plotly import utils
#      20 from plotly import exceptions
# ---> 21 from plotly import graph_reference
#      22 from plotly import session
#      23 from plotly.files import (CONFIG_FILE, CREDENTIALS_FILE, FILE_CONTENT,
#
# C:\Program Files\Anaconda3\lib\site-packages\plotly\graph_reference.py in <module>()
#     516
#     517 # The ordering here is important.
# --> 518 GRAPH_REFERENCE = get_graph_reference()
#     519
#     520 # See http://blog.labix.org/2008/06/27/watch-out-for-listdictkeys-in-python-3
#
# C:\Program Files\Anaconda3\lib\site-packages\plotly\graph_reference.py in get_graph_reference()
#      91     try:
#      92         response = requests.get(graph_reference_url,
# ---> 93                                 timeout=GRAPH_REFERENCE_DOWNLOAD_TIMEOUT)
#      94         response.raise_for_status()
#      95     except requests.exceptions.RequestException:
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     592                                                   timeout=timeout_obj,
#     593                                                   body=body, headers=headers,
# --> 594                                                   chunked=chunked)
#     595
#     596             # If we're going to release the connection in ``finally:``, then
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     348         # Trigger any extra validation we need to do.
#     349         try:
# --> 350             self._validate_conn(conn)
#     351         except (SocketTimeout, BaseSSLError) as e:
#     352             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     833         # Force connect early to allow us to validate the connection.
#     834         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 835             conn.connect()
#     836
#     837         if not conn.is_verified:
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     279     def connect(self):
#     280         # Add certificate verification
# --> 281         conn = self._new_conn()
#     282
#     283         hostname = self.host
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     136         try:
#     137             conn = connection.create_connection(
# --> 138                 (self.host, self.port), self.timeout, **extra_kw)
#     139
#     140         except SocketTimeout as e:
#
# C:\Program Files\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73     family = allowed_gai_family()
#      74
# ---> 75     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      76         af, socktype, proto, canonname, sa = res
#      77         sock = None
#
# C:\Program Files\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     730     # and socket type values to enum constants.
#     731     addrlist = []
# --> 732     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     733         af, socktype, proto, canonname, sa = res
#     734         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:

# %%
nParityESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=500,  # from 200 onwards test error decreases significantly
                          spectral_radius=0.95,  # high spectral rad is better (high fluctuations 0->1->0)
                          leak_rate= 0.1,   # adjust leak_rate
                          sparsity=0.95,     # 0.95
                          noise=0.01,      # 0.001
                          input_shift=-0.5,    # 0
                          input_scaling=3,  # 3 seems to be fine. Maybe use lower
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          out_activation=np.tanh,
                          inverse_out_activation=np.arctanh,
                          random_state=rng,
                          silent=False)
nParityESN.fit(train_bits, train_parity)
# Out:
# harvesting states...
# fitting...
# training error:
# 0.22566015585
# array([[ 0.63391576],
#        [-0.14456233],
#        [-0.15365048],
#        ...,
#        [ 0.88192822],
#        [ 0.88365077],
#        [ 0.86273787]])

# %%
##### Create Training Data for fastESN with output from slowESN
start_time = time.time()

new_rng = np.random.RandomState(1337)
new_N, new_n = 5000, 3
new_bits, new_parity, new_target = Parity_Data_Generator.generateParityData(new_N, new_n, randomstate=new_rng)

# Divide in training and test data
traintest_cutoff = int(np.ceil(0.7 * len(bits)))
new_train_bits, new_test_bits = new_bits[:traintest_cutoff], new_bits[traintest_cutoff:]
# new_train_parity, new_test_parity = new_parity[:traintest_cutoff], new_parity[traintest_cutoff:]
new_train_targets, new_test_targets = new_target[:traintest_cutoff], new_target[traintest_cutoff:]

train_predicted_parity = nParityESN.predict(new_train_bits)
test_predicted_parity = nParityESN.predict(new_test_bits)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 9.439780473709106 seconds ---

# %%
#### FastESN ####
def runSomeFastConfigs(spectral_rad, leak_r,num_neurons=100):
    outputESN = ESN(n_inputs=1,
                              n_outputs=1,
                              n_reservoir=num_neurons,  
                              spectral_radius=spectral_rad,  # high spectral rad is better (high fluctuations 0->1->0)
                              leak_rate= leak_r,   # adjust leak_rate
                              sparsity=0.95,
                              noise=0.001,
                              input_shift=0,
                              input_scaling=3,  # 3 seems to be fine. Maybe use lower
                              teacher_scaling=1.12,
                              teacher_shift=-0.4,
                              out_activation=np.tanh,
                              inverse_out_activation=np.arctanh,
                              random_state=new_rng,
                              silent=False)
        # print(np.shape(bits),np.shape(parity),np.shape(target))
    outputESN.fit(train_predicted_parity, new_train_targets)
    pred_test = outputESN.predict(test_predicted_parity)
        
    print("Testing error")
    test_error = np.sqrt(np.mean((pred_test - new_test_targets) ** 2))
    print(test_error)
    return test_error

# %%
num_neurons_fast = [100]
# l_rate_fast = np.linspace(0.4, 1, num=7)
l_rate_fast = np.linspace(0.1, 1, num=10)
# l_rate_fast = [0.6]
# sp_rad_fast = np.linspace(0.8, 1, num=3)
sp_rad_fast = np.linspace(0.1, 1, num=10)
# sp_rad_fast = [0.95]

run_time = time.time()
iterations, iterationcount = len(num_neurons_fast)*len(sp_rad_fast)*len(l_rate_fast), 0
leak_rate_list = []
spectral_radius_list = []
errors = []
all_errors_fast = [{} for _ in range(len(num_neurons_fast))]
for i,n in enumerate(num_neurons_fast):
    leak_rate_list = []
    spectral_radius_list = []
    errors = []
    for l in l_rate_fast:
        for s in sp_rad_fast:
            print("Neurons:", n, "Spectral-radius:", s, "Leak-rate:", l)
            leak_rate_list.append(l)
            spectral_radius_list.append(s)
            errors.append(runSomeFastConfigs(s,l,n))
            iterationcount = iterationcount + 1
            print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
    ## Save leak-rate,spectral-radius and error in dictionary
    all_errors_fast[i] = leak_rate_list, spectral_radius_list, errors
            
print("Total time for Testbench:")
print("--- {:.2f} seconds ---".format(time.time() - run_time))
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 100 Spectral-radius: 0.1 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.101186828
# Testing error
# 0.12524643894
# --- Progress: 1.00% --- 0.06 minutes ---
# Neurons: 100 Spectral-radius: 0.2 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.103869287379
# Testing error
# 0.125047991269
# --- Progress: 2.00% --- 0.12 minutes ---
# Neurons: 100 Spectral-radius: 0.3 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.107079482285
# Testing error
# 0.125719654047
# --- Progress: 3.00% --- 0.18 minutes ---
# Neurons: 100 Spectral-radius: 0.4 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.109504150843
# Testing error
# 0.125833776198
# --- Progress: 4.00% --- 0.24 minutes ---
# Neurons: 100 Spectral-radius: 0.5 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.10798566413
# Testing error
# 0.125259035503
# --- Progress: 5.00% --- 0.30 minutes ---
# Neurons: 100 Spectral-radius: 0.6 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.112165686669
# Testing error
# 0.125285102961
# --- Progress: 6.00% --- 0.37 minutes ---
# Neurons: 100 Spectral-radius: 0.7 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.115036878972
# Testing error
# 0.125920945134
# --- Progress: 7.00% --- 0.43 minutes ---
# Neurons: 100 Spectral-radius: 0.8 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.122756062231
# Testing error
# 0.125007313651
# --- Progress: 8.00% --- 0.49 minutes ---
# Neurons: 100 Spectral-radius: 0.9 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.114620145839
# Testing error
# 0.125638575055
# --- Progress: 9.00% --- 0.56 minutes ---
# Neurons: 100 Spectral-radius: 1.0 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.121197586421
# Testing error
# 0.128325942873
# --- Progress: 10.00% --- 0.64 minutes ---
# Neurons: 100 Spectral-radius: 0.1 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.0988403076612
# Testing error
# 0.12519011447
# --- Progress: 11.00% --- 0.71 minutes ---
# Neurons: 100 Spectral-radius: 0.2 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.099437816382
# Testing error
# 0.12610775493
# --- Progress: 12.00% --- 0.79 minutes ---
# Neurons: 100 Spectral-radius: 0.3 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.0986935735676
# Testing error
# 0.125517236571
# --- Progress: 13.00% --- 0.84 minutes ---
# Neurons: 100 Spectral-radius: 0.4 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.100490400483
# Testing error
# 0.12531530633
# --- Progress: 14.00% --- 0.89 minutes ---
# Neurons: 100 Spectral-radius: 0.5 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.0985065989961
# Testing error
# 0.12537622253
# --- Progress: 15.00% --- 0.95 minutes ---
# Neurons: 100 Spectral-radius: 0.6 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.103944852697
# Testing error
# 0.125395518853
# --- Progress: 16.00% --- 1.01 minutes ---
# Neurons: 100 Spectral-radius: 0.7 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.102040320191
# Testing error
# 0.125681925836
# --- Progress: 17.00% --- 1.07 minutes ---
# Neurons: 100 Spectral-radius: 0.8 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.112586429959
# Testing error
# 0.125133319949
# --- Progress: 18.00% --- 1.13 minutes ---
# Neurons: 100 Spectral-radius: 0.9 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.115605463994
# Testing error
# 0.125749158823
# --- Progress: 19.00% --- 1.19 minutes ---
# Neurons: 100 Spectral-radius: 1.0 Leak-rate: 0.2
# harvesting states...
# fitting...
# training error:
# 0.116602607012
# Testing error
# 0.126260116444
# --- Progress: 20.00% --- 1.25 minutes ---
# Neurons: 100 Spectral-radius: 0.1 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.0917003893672
# Testing error
# 0.125721990688
# --- Progress: 21.00% --- 1.31 minutes ---
# Neurons: 100 Spectral-radius: 0.2 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.0846641577752
# Testing error
# 0.127362671874
# --- Progress: 22.00% --- 1.37 minutes ---
# Neurons: 100 Spectral-radius: 0.3 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.0801978002764
# Testing error
# 0.125361387557
# --- Progress: 23.00% --- 1.43 minutes ---
# Neurons: 100 Spectral-radius: 0.4 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.0773772292627
# Testing error
# 0.127607542924
# --- Progress: 24.00% --- 1.49 minutes ---
# Neurons: 100 Spectral-radius: 0.5 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.0876174764389
# Testing error
# 0.125551073444
# --- Progress: 25.00% --- 1.55 minutes ---
# Neurons: 100 Spectral-radius: 0.6 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.0969838593975
# Testing error
# 0.125427220549
# --- Progress: 26.00% --- 1.60 minutes ---
# Neurons: 100 Spectral-radius: 0.7 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.0947438019729
# Testing error
# 0.126093813478
# --- Progress: 27.00% --- 1.66 minutes ---
# Neurons: 100 Spectral-radius: 0.8 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.093951785204
# Testing error
# 0.127439159136
# --- Progress: 28.00% --- 1.71 minutes ---
# Neurons: 100 Spectral-radius: 0.9 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.0994240548432
# Testing error
# 0.127278628761
# --- Progress: 29.00% --- 1.77 minutes ---
# Neurons: 100 Spectral-radius: 1.0 Leak-rate: 0.3
# harvesting states...
# fitting...
# training error:
# 0.113048366093
# Testing error
# 0.14179570079
# --- Progress: 30.00% --- 1.84 minutes ---
# Neurons: 100 Spectral-radius: 0.1 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.0683613828723
# Testing error
# 0.125604922777
# --- Progress: 31.00% --- 1.90 minutes ---
# Neurons: 100 Spectral-radius: 0.2 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.065915258295
# Testing error
# 0.125718080705
# --- Progress: 32.00% --- 1.96 minutes ---
# Neurons: 100 Spectral-radius: 0.3 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.0635001102228
# Testing error
# 0.129232401033
# --- Progress: 33.00% --- 2.02 minutes ---
# Neurons: 100 Spectral-radius: 0.4 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.0680688563785
# Testing error
# 0.127055611933
# --- Progress: 34.00% --- 2.08 minutes ---
# Neurons: 100 Spectral-radius: 0.5 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.0679589537952
# Testing error
# 0.127668043368
# --- Progress: 35.00% --- 2.13 minutes ---
# Neurons: 100 Spectral-radius: 0.6 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.074446052887
# Testing error
# 0.128519538534
# --- Progress: 36.00% --- 2.19 minutes ---
# Neurons: 100 Spectral-radius: 0.7 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.0788877369713
# Testing error
# 0.130049883405
# --- Progress: 37.00% --- 2.25 minutes ---
# Neurons: 100 Spectral-radius: 0.8 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.0876289882068
# Testing error
# 0.1298074545
# --- Progress: 38.00% --- 2.31 minutes ---
# Neurons: 100 Spectral-radius: 0.9 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.0824203135621
# Testing error
# 0.12995907867
# --- Progress: 39.00% --- 2.37 minutes ---
# Neurons: 100 Spectral-radius: 1.0 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.0696902319522
# Testing error
# 0.135573638041
# --- Progress: 40.00% --- 2.43 minutes ---
# Neurons: 100 Spectral-radius: 0.1 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.0582948477451
# Testing error
# 0.130937173103
# --- Progress: 41.00% --- 2.49 minutes ---
# Neurons: 100 Spectral-radius: 0.2 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.052337598909
# Testing error
# 0.136914546071
# --- Progress: 42.00% --- 2.54 minutes ---
# Neurons: 100 Spectral-radius: 0.3 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.0529526298196
# Testing error
# 0.126480287211
# --- Progress: 43.00% --- 2.60 minutes ---
# Neurons: 100 Spectral-radius: 0.4 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.0530675059089
# Testing error
# 0.126555971438
# --- Progress: 44.00% --- 2.66 minutes ---
# Neurons: 100 Spectral-radius: 0.5 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.063995538681
# Testing error
# 0.129838986343
# --- Progress: 45.00% --- 2.72 minutes ---
# Neurons: 100 Spectral-radius: 0.6 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.0554991323044
# Testing error
# 0.135242462008
# --- Progress: 46.00% --- 2.78 minutes ---
# Neurons: 100 Spectral-radius: 0.7 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.06694033949
# Testing error
# 0.123472814753
# --- Progress: 47.00% --- 2.84 minutes ---
# Neurons: 100 Spectral-radius: 0.8 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.0550507971073
# Testing error
# 0.132837403992
# --- Progress: 48.00% --- 2.90 minutes ---
# Neurons: 100 Spectral-radius: 0.9 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.0802361358319
# Testing error
# 0.134214659366
# --- Progress: 49.00% --- 2.95 minutes ---
# Neurons: 100 Spectral-radius: 1.0 Leak-rate: 0.5
# harvesting states...
# fitting...
# training error:
# 0.0848194296213
# Testing error
# 0.138936632143
# --- Progress: 50.00% --- 3.01 minutes ---
# Neurons: 100 Spectral-radius: 0.1 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.0511364862183
# Testing error
# 0.13128280487
# --- Progress: 51.00% --- 3.06 minutes ---
# Neurons: 100 Spectral-radius: 0.2 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.0484588999662
# Testing error
# 0.12201440918
# --- Progress: 52.00% --- 3.12 minutes ---
# Neurons: 100 Spectral-radius: 0.3 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.0477461789599
# Testing error
# 0.127606310178
# --- Progress: 53.00% --- 3.18 minutes ---
# Neurons: 100 Spectral-radius: 0.4 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.0490781455523
# Testing error
# 0.137936514168
# --- Progress: 54.00% --- 3.24 minutes ---
# Neurons: 100 Spectral-radius: 0.5 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.047004857438
# Testing error
# 0.13800168913
# --- Progress: 55.00% --- 3.29 minutes ---
# Neurons: 100 Spectral-radius: 0.6 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.0547265514412
# Testing error
# 0.137321444022
# --- Progress: 56.00% --- 3.34 minutes ---
# Neurons: 100 Spectral-radius: 0.7 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.0512183962416
# Testing error
# 0.126333721709
# --- Progress: 57.00% --- 3.39 minutes ---
# Neurons: 100 Spectral-radius: 0.8 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.0506849964076
# Testing error
# 0.13678017581
# --- Progress: 58.00% --- 3.44 minutes ---
# Neurons: 100 Spectral-radius: 0.9 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.054172863356
# Testing error
# 0.137203585543
# --- Progress: 59.00% --- 3.49 minutes ---
# Neurons: 100 Spectral-radius: 1.0 Leak-rate: 0.6
# harvesting states...
# fitting...
# training error:
# 0.0587414100506
# Testing error
# 0.128790607708
# --- Progress: 60.00% --- 3.54 minutes ---
# Neurons: 100 Spectral-radius: 0.1 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.0464222174232
# Testing error
# 0.12823140643
# --- Progress: 61.00% --- 3.59 minutes ---
# Neurons: 100 Spectral-radius: 0.2 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.045434334648
# Testing error
# 0.149614374658
# --- Progress: 62.00% --- 3.64 minutes ---
# Neurons: 100 Spectral-radius: 0.3 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.0431796688277
# Testing error
# 0.151955683794
# --- Progress: 63.00% --- 3.69 minutes ---
# Neurons: 100 Spectral-radius: 0.4 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.043741518684
# Testing error
# 0.133445473383
# --- Progress: 64.00% --- 3.74 minutes ---
# Neurons: 100 Spectral-radius: 0.5 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.0442888049969
# Testing error
# 0.145658065473
# --- Progress: 65.00% --- 3.79 minutes ---
# Neurons: 100 Spectral-radius: 0.6 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.0441081408906
# Testing error
# 0.138746688302
# --- Progress: 66.00% --- 3.84 minutes ---
# Neurons: 100 Spectral-radius: 0.7 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.0462464339715
# Testing error
# 0.137414052344
# --- Progress: 67.00% --- 3.89 minutes ---
# Neurons: 100 Spectral-radius: 0.8 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.0449925774775
# Testing error
# 0.138644720899
# --- Progress: 68.00% --- 3.94 minutes ---
# Neurons: 100 Spectral-radius: 0.9 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.0487111680734
# Testing error
# 0.14335082595
# --- Progress: 69.00% --- 3.99 minutes ---
# Neurons: 100 Spectral-radius: 1.0 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.049254184238
# Testing error
# 0.145534386866
# --- Progress: 70.00% --- 4.04 minutes ---
# Neurons: 100 Spectral-radius: 0.1 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.0466647875763
# Testing error
# 0.152269976553
# --- Progress: 71.00% --- 4.09 minutes ---
# Neurons: 100 Spectral-radius: 0.2 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.0440376399984
# Testing error
# 0.135340568098
# --- Progress: 72.00% --- 4.14 minutes ---
# Neurons: 100 Spectral-radius: 0.3 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.0430537073845
# Testing error
# 0.143125584027
# --- Progress: 73.00% --- 4.19 minutes ---
# Neurons: 100 Spectral-radius: 0.4 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.0435652653756
# Testing error
# 0.131469780494
# --- Progress: 74.00% --- 4.24 minutes ---
# Neurons: 100 Spectral-radius: 0.5 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.0438345615837
# Testing error
# 0.1315102892
# --- Progress: 75.00% --- 4.28 minutes ---
# Neurons: 100 Spectral-radius: 0.6 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.0430171158373
# Testing error
# 0.164648942705
# --- Progress: 76.00% --- 4.33 minutes ---
# Neurons: 100 Spectral-radius: 0.7 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.0428962622362
# Testing error
# 0.141099634153
# --- Progress: 77.00% --- 4.38 minutes ---
# Neurons: 100 Spectral-radius: 0.8 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.0431463665424
# Testing error
# 0.148533102363
# --- Progress: 78.00% --- 4.43 minutes ---
# Neurons: 100 Spectral-radius: 0.9 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.044235091468
# Testing error
# 0.130189466376
# --- Progress: 79.00% --- 4.48 minutes ---
# Neurons: 100 Spectral-radius: 1.0 Leak-rate: 0.8
# harvesting states...
# fitting...
# training error:
# 0.0534081928981
# Testing error
# 0.139374183891
# --- Progress: 80.00% --- 4.53 minutes ---
# Neurons: 100 Spectral-radius: 0.1 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.044390760126
# Testing error
# 0.160062785013
# --- Progress: 81.00% --- 4.58 minutes ---
# Neurons: 100 Spectral-radius: 0.2 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.0433994677588
# Testing error
# 0.155123657085
# --- Progress: 82.00% --- 4.63 minutes ---
# Neurons: 100 Spectral-radius: 0.3 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.0429725629533
# Testing error
# 0.147682020028
# --- Progress: 83.00% --- 4.67 minutes ---
# Neurons: 100 Spectral-radius: 0.4 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.0427253607872
# Testing error
# 0.16000899201
# --- Progress: 84.00% --- 4.72 minutes ---
# Neurons: 100 Spectral-radius: 0.5 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.0423157506901
# Testing error
# 0.145959566325
# --- Progress: 85.00% --- 4.77 minutes ---
# Neurons: 100 Spectral-radius: 0.6 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.0426724736218
# Testing error
# 0.147638533855
# --- Progress: 86.00% --- 4.82 minutes ---
# Neurons: 100 Spectral-radius: 0.7 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.0437890213085
# Testing error
# 0.11805482373
# --- Progress: 87.00% --- 4.87 minutes ---
# Neurons: 100 Spectral-radius: 0.8 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.043013694665
# Testing error
# 0.129790042512
# --- Progress: 88.00% --- 4.92 minutes ---
# Neurons: 100 Spectral-radius: 0.9 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.043120599347
# Testing error
# 0.181503334772
# --- Progress: 89.00% --- 4.97 minutes ---
# Neurons: 100 Spectral-radius: 1.0 Leak-rate: 0.9
# harvesting states...
# fitting...
# training error:
# 0.0461771759617
# Testing error
# 0.142239359624
# --- Progress: 90.00% --- 5.02 minutes ---
# Neurons: 100 Spectral-radius: 0.1 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.0462866106992
# Testing error
# 0.146046044615
# --- Progress: 91.00% --- 5.07 minutes ---
# Neurons: 100 Spectral-radius: 0.2 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.0434586185566
# Testing error
# 0.149172895245
# --- Progress: 92.00% --- 5.12 minutes ---
# Neurons: 100 Spectral-radius: 0.3 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.0429214170721
# Testing error
# 0.137662021585
# --- Progress: 93.00% --- 5.17 minutes ---
# Neurons: 100 Spectral-radius: 0.4 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.0431003433443
# Testing error
# 0.147880140535
# --- Progress: 94.00% --- 5.22 minutes ---
# Neurons: 100 Spectral-radius: 0.5 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.042580345809
# Testing error
# 0.150506484981
# --- Progress: 95.00% --- 5.27 minutes ---
# Neurons: 100 Spectral-radius: 0.6 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.0423193881589
# Testing error
# 0.153446847525
# --- Progress: 96.00% --- 5.32 minutes ---
# Neurons: 100 Spectral-radius: 0.7 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.0426619608031
# Testing error
# 0.17197846284
# --- Progress: 97.00% --- 5.37 minutes ---
# Neurons: 100 Spectral-radius: 0.8 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.0431715369176
# Testing error
# 0.108909674167
# --- Progress: 98.00% --- 5.42 minutes ---
# Neurons: 100 Spectral-radius: 0.9 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.043037413233
# Testing error
# 0.167115522939
# --- Progress: 99.00% --- 5.47 minutes ---
# Neurons: 100 Spectral-radius: 1.0 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.0448011148414
# Testing error
# 0.119727619895
# --- Progress: 100.00% --- 5.52 minutes ---
# Total time for Testbench:
# --- 330.93 seconds ---
# --- 5.52 minutes ---

# %%
import pickle
#### Save Data
with open('datasaveFast.p', 'wb') as outputFile:
    pickle.dump(all_errors_fast, outputFile)
    pickle.dump(num_neurons_fast, outputFile)
    pickle.dump(l_rate_fast, outputFile)
    pickle.dump(sp_rad_fast, outputFile)
#### Load Data
# with open('datasaveFast.p', 'rb') as inputFile:
#     all_errors_fast = pickle.load(inputFile)
#     num_neurons_fast = pickle.load(inputFile)
#     l_rate_fast = pickle.load(inputFile)
#     sp_rad_fast = pickle.load(inputFile)

# %%
import plotly.plotly as py
import plotly.graph_objs as go
py.sign_in('HansBambel', 'T0F76G8esWCDFNmIVEUv')

# c= ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, len(all_errors_fast))]
c= ["blue", "orange", "green", "cyan", "yellow", "magenta", "red", "black"]
data = []
for i, n in enumerate(all_errors_fast):

    x, y, z = all_errors_fast[i]

    trace = go.Scatter3d(
        x=x,
        y=y,
        z=z,
        name=(str(num_neurons_fast[i])+" Neurons"),
        mode='markers',
        marker=dict(
            size=7,
#             color=c[i],                # set color to an array/list of desired values
            colorscale='Viridis',   # choose a colorscale
            opacity=0.8
        )
    )
    data.append(trace)

# data = [trace1]
layout = go.Layout(
#     margin=dict(
#         l=0,
#         r=0,
#         b=0,
#         t=0
#     ),
#     go.zaxis=dict(
#         range=[0, 0.8]
#     ),
    scene=go.Scene(
        xaxis=go.XAxis(title='x = Leak-Rate'),
        yaxis=go.YAxis(title='y = Spectral Radius'),
        zaxis=go.ZAxis(title='z = Error')
        )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='3d-scatter-errors for different Reservoirsizes')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HansBambel/6.embed" height="525px" width="100%"></iframe>
