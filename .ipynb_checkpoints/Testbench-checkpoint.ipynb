# %%
import Parity_Data_Generator
import numpy as np
from pyESN import ESN
import time

N = 4000   # number of datapoints
n = 3       # n-parity
timescale = 50
rng = np.random.RandomState(42)

# %%
def runSomeConfigs(spectral_rad, leak_r, d_t, train_b, test_b, train_p, test_p, n_neurons):
#     print("Spectral-radius:",spectral_rad, "leak-rate:", leak_r)
    nParityESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=n_neurons,  # from 200 onwards test error decreases significantly
                          spectral_radius=spectral_rad,  # high spectral rad is better (high fluctuations 0->1->0)
                          leak_rate= leak_r,   # adjust leak_rate
                          delta_t= d_t,
                          sparsity=0.95,
                          noise=0.01,
                          input_shift=0,
                          input_scaling=3,  # 3 seems to be fine. Maybe use lower
                          teacher_forcing=False,
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          random_state=rng,
                          silent=False)
    # print(np.shape(bits),np.shape(parity),np.shape(target))
    nParityESN.fit(train_b, train_p)
    pred_test = nParityESN.predict(test_b)

    predictedParity = pred_test 
    
    print("Testing error")
    test_error = np.sqrt(np.mean((predictedParity - test_p) ** 2))
    print(test_error)
    return test_error

# %%
def produceTrainingData(i):
    bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(i))

    # Divide in training and test data
    traintest_cutoff = int(np.ceil(0.7 * len(bits)))
    train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
    train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
#     train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
    return train_bits, test_bits, train_parity, test_parity

# %%
trials = 1
# n_neurons_slow = [200,300,400,500]
n_neurons_slow = [300]

delta_t = [0.1]

l_rate = np.linspace(0.1, 1, num=10)
# l_rate =[0.2]
# l_rate = [0.1,0.2,0.3]

# sp_rad = np.linspace(0.9, 1.0, num=5)
sp_rad = np.linspace(0.1, 1, num=10)
# sp_rad = [0.8]


run_time = time.time()
iterations, iterationcount = trials*len(n_neurons_slow)*len(sp_rad)*len(l_rate)*len(delta_t), 0

delta_t_error = []
for dt in delta_t:
    neurons_slow_error = []
    for current_slow_neurons in n_neurons_slow:
        all_errors = [{} for _ in range(trials)] # empty dict
        for i in range(trials):
            errors = []
            # produce training and testing data
            train_bits, test_bits, train_parity, test_parity = produceTrainingData(i)
            for l in l_rate:
                for s in sp_rad:
                    print("Neurons:", current_slow_neurons,"Leak-rate:",l,"Spectral-radius:",s,"Delta_t:",dt)
                    errors.append(runSomeConfigs(s,l,dt, train_bits, test_bits, train_parity, test_parity, current_slow_neurons))
                    iterationcount = iterationcount + 1
                    print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
            ## Save leak-rate,spectral-radius and error in dictionary
            all_errors[i] = errors

        ### Average errors
        errors_averaged_over_trials = np.zeros(100)
        for i in range(len(all_errors)):
            e = all_errors[i]
            errors_averaged_over_trials = np.add(errors_averaged_over_trials, np.array(e))
        errors_averaged_over_trials = np.divide(errors_averaged_over_trials, trials)

        neurons_slow_error.append(errors_averaged_over_trials)
    
    delta_t_error.append(neurons_slow_error)
            
print("Total time for Testbench:")
print("--- {:.2f} seconds ---".format(time.time() - run_time))
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.406920521606
# Testing error
# 0.410502982999
# --- Progress: 1.00% --- 0.26 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.361992145243
# Testing error
# 0.371205273344
# --- Progress: 2.00% --- 0.50 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.346306003571
# Testing error
# 0.365338812763
# --- Progress: 3.00% --- 0.74 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.323285627726
# Testing error
# 0.359762581885
# --- Progress: 4.00% --- 0.98 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.337697502747
# Testing error
# 0.381530946512
# --- Progress: 5.00% --- 1.24 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.351760452376
# Testing error
# 0.397983517972
# --- Progress: 6.00% --- 1.49 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.348469077543
# Testing error
# 0.373291979876
# --- Progress: 7.00% --- 1.74 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.385480165189
# Testing error
# 0.426310738684
# --- Progress: 8.00% --- 1.98 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.396070531764
# Testing error
# 0.43601981583
# --- Progress: 9.00% --- 2.22 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.407840191821
# Testing error
# 0.473610323142
# --- Progress: 10.00% --- 2.47 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.359763004055
# Testing error
# 0.358824826368
# --- Progress: 11.00% --- 2.72 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.287847167276
# Testing error
# 0.287921681962
# --- Progress: 12.00% --- 2.98 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.264572988322
# Testing error
# 0.269151519581
# --- Progress: 13.00% --- 3.23 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.253329743
# Testing error
# 0.260718157566
# --- Progress: 14.00% --- 3.48 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.239605083103
# Testing error
# 0.254975435466
# --- Progress: 15.00% --- 3.73 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.244119833592
# Testing error
# 0.291235652235
# --- Progress: 16.00% --- 3.98 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.25655087383
# Testing error
# 0.313481856137
# --- Progress: 17.00% --- 4.25 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.261759447589
# Testing error
# 0.306447307023
# --- Progress: 18.00% --- 4.50 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.277139625556
# Testing error
# 0.329688801545
# --- Progress: 19.00% --- 4.74 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.300370965096
# Testing error
# 0.341786339033
# --- Progress: 20.00% --- 4.99 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.378573410418
# Testing error
# 0.37657883728
# --- Progress: 21.00% --- 5.24 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.333666672269
# Testing error
# 0.335740461695
# --- Progress: 22.00% --- 5.49 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.294715185275
# Testing error
# 0.296457230427
# --- Progress: 23.00% --- 5.74 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.251919872239
# Testing error
# 0.255723070013
# --- Progress: 24.00% --- 6.01 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.248895204648
# Testing error
# 0.274004220293
# --- Progress: 25.00% --- 6.28 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.239091096977
# Testing error
# 0.265870835707
# --- Progress: 26.00% --- 6.55 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.239471019583
# Testing error
# 0.285159243443
# --- Progress: 27.00% --- 6.83 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227939363414
# Testing error
# 0.264352643702
# --- Progress: 28.00% --- 7.09 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.245054920206
# Testing error
# 0.268299916058
# --- Progress: 29.00% --- 7.36 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.238694321513
# Testing error
# 0.288036179852
# --- Progress: 30.00% --- 7.62 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.4527023057
# Testing error
# 0.458375762256
# --- Progress: 31.00% --- 7.88 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.381362920481
# Testing error
# 0.380916546021
# --- Progress: 32.00% --- 8.13 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.331303149433
# Testing error
# 0.332807660179
# --- Progress: 33.00% --- 8.38 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.281675848587
# Testing error
# 0.282269526128
# --- Progress: 34.00% --- 8.63 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.24294362317
# Testing error
# 0.245718469067
# --- Progress: 35.00% --- 8.88 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.224709760112
# Testing error
# 0.229646882368
# --- Progress: 36.00% --- 9.13 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.244801607947
# Testing error
# 0.254153352256
# --- Progress: 37.00% --- 9.39 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216291145731
# Testing error
# 0.278435627719
# --- Progress: 38.00% --- 9.67 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216594556652
# Testing error
# 0.305247518806
# --- Progress: 39.00% --- 9.97 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.23132806914
# Testing error
# 0.255725587145
# --- Progress: 40.00% --- 10.26 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.489382259463
# Testing error
# 0.496383855656
# --- Progress: 41.00% --- 10.54 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.439043716611
# Testing error
# 0.44731395082
# --- Progress: 42.00% --- 10.82 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.382732661169
# Testing error
# 0.3823385724
# --- Progress: 43.00% --- 11.08 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.346000465493
# Testing error
# 0.347608121763
# --- Progress: 44.00% --- 11.34 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.318065796763
# Testing error
# 0.319298914082
# --- Progress: 45.00% --- 11.61 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.2799179295
# Testing error
# 0.281522320698
# --- Progress: 46.00% --- 11.87 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.266213343334
# Testing error
# 0.269996823149
# --- Progress: 47.00% --- 12.13 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.23051865524
# Testing error
# 0.23437767649
# --- Progress: 48.00% --- 12.39 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201065540233
# Testing error
# 0.209019685335
# --- Progress: 49.00% --- 12.66 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.203163612906
# Testing error
# 0.260489941764
# --- Progress: 50.00% --- 12.92 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499152838182
# Testing error
# 0.505589500022
# --- Progress: 51.00% --- 13.20 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.486629365779
# Testing error
# 0.492855745757
# --- Progress: 52.00% --- 13.48 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.452749076634
# Testing error
# 0.460702691592
# --- Progress: 53.00% --- 13.74 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.404780902417
# Testing error
# 0.40458974581
# --- Progress: 54.00% --- 14.00 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.361256866552
# Testing error
# 0.363335617276
# --- Progress: 55.00% --- 14.25 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.314216802417
# Testing error
# 0.316748560035
# --- Progress: 56.00% --- 14.51 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.310918851668
# Testing error
# 0.313407211327
# --- Progress: 57.00% --- 14.76 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226942653669
# Testing error
# 0.231298603281
# --- Progress: 58.00% --- 15.02 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.253965427072
# Testing error
# 0.259349431116
# --- Progress: 59.00% --- 15.28 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.251740601921
# Testing error
# 0.268818388314
# --- Progress: 60.00% --- 15.55 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.50016387491
# Testing error
# 0.506439741211
# --- Progress: 61.00% --- 15.79 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.498417853899
# Testing error
# 0.504606557135
# --- Progress: 62.00% --- 16.05 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.487138300638
# Testing error
# 0.49406065629
# --- Progress: 63.00% --- 16.31 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.463279479217
# Testing error
# 0.470088350769
# --- Progress: 64.00% --- 16.56 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.412028112539
# Testing error
# 0.414444941181
# --- Progress: 65.00% --- 16.82 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.383468873771
# Testing error
# 0.384616453761
# --- Progress: 66.00% --- 17.08 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.344925672048
# Testing error
# 0.347278675625
# --- Progress: 67.00% --- 17.34 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.328350779907
# Testing error
# 0.331124167497
# --- Progress: 68.00% --- 17.59 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.290548173859
# Testing error
# 0.296492056043
# --- Progress: 69.00% --- 17.85 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.266360566744
# Testing error
# 0.276236002526
# --- Progress: 70.00% --- 18.10 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500439281923
# Testing error
# 0.506395063462
# --- Progress: 71.00% --- 18.35 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500073499737
# Testing error
# 0.505993532786
# --- Progress: 72.00% --- 18.62 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.498367365694
# Testing error
# 0.504553876537
# --- Progress: 73.00% --- 18.89 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.488351624818
# Testing error
# 0.494415755163
# --- Progress: 74.00% --- 19.15 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.45837820683
# Testing error
# 0.462586899939
# --- Progress: 75.00% --- 19.41 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.453812145896
# Testing error
# 0.457688154271
# --- Progress: 76.00% --- 19.68 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.3883335711
# Testing error
# 0.38820394779
# --- Progress: 77.00% --- 19.93 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.352024374529
# Testing error
# 0.354387285889
# --- Progress: 78.00% --- 20.17 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.3398157112
# Testing error
# 0.343328176254
# --- Progress: 79.00% --- 20.43 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.333200696315
# Testing error
# 0.335964236985
# --- Progress: 80.00% --- 20.68 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500629090882
# Testing error
# 0.506998011275
# --- Progress: 81.00% --- 20.93 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.50033767931
# Testing error
# 0.506645508095
# --- Progress: 82.00% --- 21.17 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500079301961
# Testing error
# 0.506319534469
# --- Progress: 83.00% --- 21.41 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.49879385799
# Testing error
# 0.504932047027
# --- Progress: 84.00% --- 21.66 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.490581861259
# Testing error
# 0.497222308149
# --- Progress: 85.00% --- 21.91 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.473817500086
# Testing error
# 0.479179028907
# --- Progress: 86.00% --- 22.16 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.442647790241
# Testing error
# 0.44392180306
# --- Progress: 87.00% --- 22.41 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.421420546927
# Testing error
# 0.422763651588
# --- Progress: 88.00% --- 22.66 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.383807458178
# Testing error
# 0.385940710487
# --- Progress: 89.00% --- 22.92 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.360832817036
# Testing error
# 0.362748034269
# --- Progress: 90.00% --- 23.17 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.50113368949
# Testing error
# 0.507241087257
# --- Progress: 91.00% --- 23.41 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500620580346
# Testing error
# 0.506846398472
# --- Progress: 92.00% --- 23.67 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500311064705
# Testing error
# 0.50642285936
# --- Progress: 93.00% --- 23.92 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500003735707
# Testing error
# 0.50652224296
# --- Progress: 94.00% --- 24.16 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499137923484
# Testing error
# 0.505512804396
# --- Progress: 95.00% --- 24.42 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.493447468908
# Testing error
# 0.499980217242
# --- Progress: 96.00% --- 24.67 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.479895691196
# Testing error
# 0.48578436586
# --- Progress: 97.00% --- 24.92 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.445171107654
# Testing error
# 0.446417879028
# --- Progress: 98.00% --- 25.18 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.40146285316
# Testing error
# 0.398948458541
# --- Progress: 99.00% --- 25.45 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.392659431201
# Testing error
# 0.393331196504
# --- Progress: 100.00% --- 25.70 minutes ---
# Total time for Testbench:
# --- 1541.91 seconds ---
# --- 25.70 minutes ---

# %%
import pickle
#### Save Data
with open('dataTimescale50sameDelta_T.p', 'wb') as outputFile:
    pickle.dump(delta_t_error, outputFile)
    pickle.dump(neurons_slow_error, outputFile)
    pickle.dump(n_neurons_slow, outputFile)
    pickle.dump(delta_t, outputFile)
    pickle.dump(trials, outputFile)
    pickle.dump(l_rate, outputFile)
    pickle.dump(sp_rad, outputFile)
#### Load Data
# with open('dataTimescale50sameDelta_T.p', 'rb') as inputFile:
#     delta_t_error = pickle.load(inputFile)
#     neurons_slow_error = pickle.load(inputFile)
#     n_neurons_slow = pickle.load(inputFile)
#     delta_t = pickle.load(inputFile)
#     trials = pickle.load(inputFile)
#     l_rate = pickle.load(inputFile)
#     sp_rad = pickle.load(inputFile)

# %% [markdown]
# import plotly.plotly as py
# import plotly.graph_objs as go
#
# # c= ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, len(all_errors))]
# # c= ["blue", "orange", "green", "cyan", "yellow", "magenta", "red", "black"]
#
# x = np.repeat(l_rate,len(l_rate))
# y = np.tile(sp_rad, len(sp_rad))
# z = neurons_slow_error[0]
# trace1 = go.Scatter3d(
#     x=x,
#     y=y,
#     z=z,
#     name=("Averaged over", trials ,"Trials"),
#     mode='markers',
#     marker=dict(
#         size=7,
#         color=z,                # set color to an array/list of desired values
#         colorscale='Viridis',   # choose a colorscale
#         opacity=0.8
#     )
# )
#
# data = [trace1]
# layout = go.Layout(
# #     margin=dict(
# #         l=0,
# #         r=0,
# #         b=0,
# #         t=0
# #     ),
# #     go.zaxis=dict(
# #         range=[0, 0.8]
# #     ),
#     scene=go.Scene(
#         xaxis=go.XAxis(title='x = Leak-Rate'),
#         yaxis=go.YAxis(title='y = Spectral Radius'),
#         zaxis=go.ZAxis(title='z = Error')
#         )
# )
# fig = go.Figure(data=data, layout=layout)
# py.iplot(fig, filename='SlowESN average Error')

# %% [markdown]
# data = [
#      go.Contour(
#         z=errors_averaged_over_trials.reshape(10,10).T,
#         x=l_rate,
#         y=sp_rad,
#         colorscale='Jet',
#     )]
# py.iplot(data)

# %%
### Different delta_t

from matplotlib import pyplot
# %matplotlib inline
print(delta_t)
xx, yy = np.meshgrid(l_rate, sp_rad)
pyplot.figure(figsize=(12,14))
for p in range(len(delta_t)):
    pyplot.subplot(3,2,p+1)
    pyplot.contourf(xx,
                    yy,delta_t_error[p][0].reshape(10,10).T)
    pyplot.title(("delta_t", delta_t[p]))
    pyplot.xlabel("Leak-rate")
    pyplot.ylabel("Spectral-radius")
    pyplot.colorbar()
# Out:
# [0.1]

# %% [markdown]
# ### Different Neuronsizes
#
# from matplotlib import pyplot
# %matplotlib inline
# print(n_neurons_slow)
# xx, yy = np.meshgrid(l_rate, sp_rad)
# pyplot.figure(figsize=(12,9))
# for p in range(len(n_neurons_slow)):
#     pyplot.subplot(2,2,p+1)
#     pyplot.contourf(xx,
#                     yy,neurons_slow_error[p].reshape(10,10).T)
#     pyplot.title((n_neurons_slow[p],"Neurons"))
#     pyplot.xlabel("Leak-rate")
#     pyplot.ylabel("Spectral-radius")
#     pyplot.colorbar()

# %%
#### Get Parameters from a good performing slowESN

nParityESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=300,  
                          spectral_radius=0.9, 
                          leak_rate= 0.5,   # adjust leak_rate
                          sparsity=0.95,     # 0.95
                          delta_t= 0.1,
                          noise=0.01,      # 0.001
                          input_shift=-0.5,    # 0
                          input_scaling=3,  
                          teacher_forcing=False,
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          random_state=rng,
                          silent=False)
train_bits, test_bits, train_parity, test_parity = produceTrainingData(42)
nParityESN.fit(train_bits, train_parity)
# Out:
# harvesting states...
# fitting...
# training error:
# 0.22831074156
# array([[ 0.61965653],
#        [ 0.54446706],
#        [ 0.47938446],
#        ...,
#        [ 0.95819811],
#        [ 0.98921538],
#        [ 0.96436811]])

# %%
##### Create Training Data for fastESN with output from slowESN
start_time = time.time()

new_rng = np.random.RandomState(1337)
new_N, new_n = 1500, 3
# new_bits, new_parity, new_target = Parity_Data_Generator.generateParityData(new_N, new_n, 
#                                                                             timescale=timescale,randomstate=new_rng)

# # Divide in training and test data
# traintest_cutoff = int(np.ceil(0.7 * len(bits)))
# new_train_bits, new_test_bits = new_bits[:traintest_cutoff], new_bits[traintest_cutoff:]
# # new_train_parity, new_test_parity = new_parity[:traintest_cutoff], new_parity[traintest_cutoff:]
# new_train_targets, new_test_targets = new_target[:traintest_cutoff], new_target[traintest_cutoff:]

# train_predicted_parity = nParityESN.predict(new_train_bits)
# test_predicted_parity = nParityESN.predict(new_test_bits)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0 seconds ---

# %%
#### FastESN ####
def runSomeFastConfigs(spectral_rad, leak_r, d_t, train_parity, test_parity, 
                       train_targets, test_targets, num_neurons=100):
    outputESN = ESN(n_inputs=1,
                              n_outputs=1,
                              n_reservoir=num_neurons,  
                              spectral_radius=spectral_rad,  # high spectral rad is better (high fluctuations 0->1->0)
                              leak_rate= leak_r,   # adjust leak_rate
                              delta_t= d_t,
                              sparsity=0.95,
                              noise=0.01,
                              input_shift=0,
                              input_scaling=3,  # 3 seems to be fine. Maybe use lower
                              teacher_forcing=False,
                              teacher_scaling=1.12,
                              teacher_shift=-0.4,
                              random_state=new_rng,
                              silent=False)
        # print(np.shape(bits),np.shape(parity),np.shape(target))
    outputESN.fit(train_parity, train_targets)
    pred_test = outputESN.predict(test_parity)
        
    print("Testing error")
    test_error = np.sqrt(np.mean((pred_test - test_targets) ** 2))
    print(test_error)
    return test_error

def produceFastTrainingData(randomState):
    bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(randomState))

    # Divide in training and test data
    traintest_cutoff = int(np.ceil(0.7 * len(bits)))
    train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
    train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
    
    train_predicted_parity = nParityESN.predict(train_bits)
    test_predicted_parity = nParityESN.predict(test_bits)
    
    return train_predicted_parity, test_predicted_parity, train_targets, test_targets

# %%
new_trials = 1
n_neurons_fast = 50
# num_neurons_fast = [100]
delta_t_fast = [0.1]
# l_rate_fast = np.linspace(0.4, 1, num=7)
l_rate_fast = np.linspace(0.1, 1, num=10)
# l_rate_fast = [0.6]
# sp_rad_fast = np.linspace(0.8, 1, num=3)
sp_rad_fast = np.linspace(0.1, 1, num=10)
# sp_rad_fast = [0.95]

run_time = time.time()
iterations, iterationcount = new_trials*len(sp_rad_fast)*len(l_rate_fast)*len(delta_t_fast), 0

delta_t_errors_fast = []
for dt_fast in delta_t_fast:
    all_errors_fast = [{} for _ in range(new_trials)]
    for i in range(new_trials):
        errors = []

        new_train_parity, new_test_parity, new_train_targets, new_test_targets = produceFastTrainingData(i)

        for l in l_rate_fast:
            for s in sp_rad_fast:
                print("Neurons:", n_neurons_fast, "Leak-rate:", l, "Spectral-radius:", s,"Delta_t:",dt_fast)
                errors.append(runSomeFastConfigs(s,l,dt_fast,new_train_parity, new_test_parity, new_train_targets, new_test_targets,n_neurons_fast))
                iterationcount = iterationcount + 1
                print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
        ## Save leak-rate,spectral-radius and error in dictionary
        all_errors_fast[i] = errors

    ### Average errors
    fast_errors_averaged_over_trials = np.zeros(100)
    for i in range(len(all_errors_fast)):
        e = all_errors_fast[i]
        fast_errors_averaged_over_trials = np.add(fast_errors_averaged_over_trials, np.array(e))

    fast_errors_averaged_over_trials = np.divide(fast_errors_averaged_over_trials, new_trials)
    
    delta_t_errors_fast.append(fast_errors_averaged_over_trials)
            
print("Total time for Testbench:")
print("--- {:.2f} seconds ---".format(time.time() - run_time))
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.231024349884
# Testing error
# 0.244978047434
# --- Progress: 1.00% --- 0.25 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.230724076289
# Testing error
# 0.243219158427
# --- Progress: 2.00% --- 0.32 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.231032026524
# Testing error
# 0.245599909159
# --- Progress: 3.00% --- 0.40 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.229583352324
# Testing error
# 0.242056643091
# --- Progress: 4.00% --- 0.48 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.228955719791
# Testing error
# 0.24405474861
# --- Progress: 5.00% --- 0.55 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.230407161635
# Testing error
# 0.245794943782
# --- Progress: 6.00% --- 0.63 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.229156068971
# Testing error
# 0.246852176672
# --- Progress: 7.00% --- 0.71 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227998083455
# Testing error
# 0.244298761535
# --- Progress: 8.00% --- 0.78 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.228107198255
# Testing error
# 0.263541897181
# --- Progress: 9.00% --- 0.86 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.2277492615
# Testing error
# 0.242281805264
# --- Progress: 10.00% --- 0.94 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.228107504267
# Testing error
# 0.237451440426
# --- Progress: 11.00% --- 1.01 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226382727453
# Testing error
# 0.234574330189
# --- Progress: 12.00% --- 1.09 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227291619748
# Testing error
# 0.237488643358
# --- Progress: 13.00% --- 1.17 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.223742976986
# Testing error
# 0.237790032415
# --- Progress: 14.00% --- 1.24 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.223289656912
# Testing error
# 0.234227761867
# --- Progress: 15.00% --- 1.32 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226442724386
# Testing error
# 0.235372074426
# --- Progress: 16.00% --- 1.40 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.223341382569
# Testing error
# 0.234703732823
# --- Progress: 17.00% --- 1.47 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.225063526171
# Testing error
# 0.23528238091
# --- Progress: 18.00% --- 1.55 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.2270272169
# Testing error
# 0.242137540913
# --- Progress: 19.00% --- 1.63 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221215120681
# Testing error
# 0.232394664618
# --- Progress: 20.00% --- 1.70 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226551381366
# Testing error
# 0.233642119936
# --- Progress: 21.00% --- 1.78 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226243681146
# Testing error
# 0.236202407487
# --- Progress: 22.00% --- 1.85 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218730747211
# Testing error
# 0.226010273691
# --- Progress: 23.00% --- 1.93 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217824151978
# Testing error
# 0.223525410053
# --- Progress: 24.00% --- 2.01 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221414951042
# Testing error
# 0.229625046029
# --- Progress: 25.00% --- 2.09 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217370913121
# Testing error
# 0.225331969976
# --- Progress: 26.00% --- 2.17 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212478975678
# Testing error
# 0.220912216857
# --- Progress: 27.00% --- 2.24 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218921344906
# Testing error
# 0.22516182063
# --- Progress: 28.00% --- 2.32 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219231202124
# Testing error
# 0.227950726353
# --- Progress: 29.00% --- 2.40 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216820770957
# Testing error
# 0.226738709141
# --- Progress: 30.00% --- 2.48 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.230098715477
# Testing error
# 0.236025178908
# --- Progress: 31.00% --- 2.56 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217760632219
# Testing error
# 0.223436564075
# --- Progress: 32.00% --- 2.63 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212941884549
# Testing error
# 0.220728423379
# --- Progress: 33.00% --- 2.71 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211536988105
# Testing error
# 0.217511614393
# --- Progress: 34.00% --- 2.78 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.210636075495
# Testing error
# 0.218284306254
# --- Progress: 35.00% --- 2.86 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207907220218
# Testing error
# 0.222539571583
# --- Progress: 36.00% --- 2.94 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212138182046
# Testing error
# 0.218570259765
# --- Progress: 37.00% --- 3.01 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218504309858
# Testing error
# 0.226493217155
# --- Progress: 38.00% --- 3.09 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207916955854
# Testing error
# 0.218996602818
# --- Progress: 39.00% --- 3.16 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207407287926
# Testing error
# 0.216292401138
# --- Progress: 40.00% --- 3.24 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.230115827309
# Testing error
# 0.237240692785
# --- Progress: 41.00% --- 3.32 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218600366646
# Testing error
# 0.225026232055
# --- Progress: 42.00% --- 3.39 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.214239618913
# Testing error
# 0.221521908189
# --- Progress: 43.00% --- 3.47 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208615042752
# Testing error
# 0.215685201557
# --- Progress: 44.00% --- 3.55 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.21490211256
# Testing error
# 0.221935158499
# --- Progress: 45.00% --- 3.63 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.2065247246
# Testing error
# 0.213741230129
# --- Progress: 46.00% --- 3.70 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.209860964061
# Testing error
# 0.216780675462
# --- Progress: 47.00% --- 3.78 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.210096684105
# Testing error
# 0.217231157389
# --- Progress: 48.00% --- 3.86 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.203965839079
# Testing error
# 0.213241291806
# --- Progress: 49.00% --- 3.94 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.21299908038
# Testing error
# 0.222133412003
# --- Progress: 50.00% --- 4.01 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.236696262269
# Testing error
# 0.245456333188
# --- Progress: 51.00% --- 4.09 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.228703463276
# Testing error
# 0.235823760258
# --- Progress: 52.00% --- 4.16 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216865354036
# Testing error
# 0.222884200239
# --- Progress: 53.00% --- 4.24 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.20924913154
# Testing error
# 0.217509232917
# --- Progress: 54.00% --- 4.31 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.21655902149
# Testing error
# 0.221960961111
# --- Progress: 55.00% --- 4.39 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207105463286
# Testing error
# 0.216043904474
# --- Progress: 56.00% --- 4.47 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206578118632
# Testing error
# 0.214031283104
# --- Progress: 57.00% --- 4.54 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.204883130264
# Testing error
# 0.21307897768
# --- Progress: 58.00% --- 4.62 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198156344519
# Testing error
# 0.208134291027
# --- Progress: 59.00% --- 4.69 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211560700926
# Testing error
# 0.220107619623
# --- Progress: 60.00% --- 4.77 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.244015019651
# Testing error
# 0.254120879743
# --- Progress: 61.00% --- 4.84 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.228315151466
# Testing error
# 0.241308343349
# --- Progress: 62.00% --- 4.92 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.225310553827
# Testing error
# 0.233709826788
# --- Progress: 63.00% --- 4.99 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.215979931182
# Testing error
# 0.227398492792
# --- Progress: 64.00% --- 5.07 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211490986905
# Testing error
# 0.221105076542
# --- Progress: 65.00% --- 5.14 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201377242483
# Testing error
# 0.212065363013
# --- Progress: 66.00% --- 5.22 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198651912901
# Testing error
# 0.207057313494
# --- Progress: 67.00% --- 5.29 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.194336930207
# Testing error
# 0.205583042839
# --- Progress: 68.00% --- 5.37 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.203056736822
# Testing error
# 0.210747595412
# --- Progress: 69.00% --- 5.45 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201120900794
# Testing error
# 0.214334842821
# --- Progress: 70.00% --- 5.52 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.24312739798
# Testing error
# 0.25356318307
# --- Progress: 71.00% --- 5.60 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.233981545464
# Testing error
# 0.251483479675
# --- Progress: 72.00% --- 5.67 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.229792348451
# Testing error
# 0.24073948566
# --- Progress: 73.00% --- 5.75 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221098452811
# Testing error
# 0.232394853622
# --- Progress: 74.00% --- 5.82 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205692666645
# Testing error
# 0.215981059258
# --- Progress: 75.00% --- 5.90 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212773628626
# Testing error
# 0.222269508992
# --- Progress: 76.00% --- 5.98 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205961864271
# Testing error
# 0.216295635432
# --- Progress: 77.00% --- 6.06 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.199071036129
# Testing error
# 0.208115030413
# --- Progress: 78.00% --- 6.14 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.197542739811
# Testing error
# 0.20738229096
# --- Progress: 79.00% --- 6.22 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198345758582
# Testing error
# 0.209358519232
# --- Progress: 80.00% --- 6.29 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.25160462799
# Testing error
# 0.263184362535
# --- Progress: 81.00% --- 6.38 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.236206482619
# Testing error
# 0.247432981805
# --- Progress: 82.00% --- 6.46 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.236883950048
# Testing error
# 0.248836511734
# --- Progress: 83.00% --- 6.53 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221111743107
# Testing error
# 0.232013394445
# --- Progress: 84.00% --- 6.61 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216248865337
# Testing error
# 0.228011936143
# --- Progress: 85.00% --- 6.68 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.21055989658
# Testing error
# 0.219773106256
# --- Progress: 86.00% --- 6.76 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.204895304315
# Testing error
# 0.215084521469
# --- Progress: 87.00% --- 6.83 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201393530319
# Testing error
# 0.211034780153
# --- Progress: 88.00% --- 6.91 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.203898791251
# Testing error
# 0.212608402672
# --- Progress: 89.00% --- 6.99 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.197844688669
# Testing error
# 0.206784726215
# --- Progress: 90.00% --- 7.07 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.254650019955
# Testing error
# 0.26842833004
# --- Progress: 91.00% --- 7.14 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.239052395161
# Testing error
# 0.252013101384
# --- Progress: 92.00% --- 7.22 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.23440080008
# Testing error
# 0.248848111545
# --- Progress: 93.00% --- 7.29 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.234185026466
# Testing error
# 0.246331176338
# --- Progress: 94.00% --- 7.37 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.222350070704
# Testing error
# 0.237255625733
# --- Progress: 95.00% --- 7.44 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221042297954
# Testing error
# 0.235750668633
# --- Progress: 96.00% --- 7.52 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212587745868
# Testing error
# 0.222877298744
# --- Progress: 97.00% --- 7.59 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206068057449
# Testing error
# 0.217560442693
# --- Progress: 98.00% --- 7.67 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208479488101
# Testing error
# 0.219080895369
# --- Progress: 99.00% --- 7.74 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.194954476696
# Testing error
# 0.205342714438
# --- Progress: 100.00% --- 7.82 minutes ---
# Total time for Testbench:
# --- 469.18 seconds ---
# --- 7.82 minutes ---

# %%
import pickle
#### Save Data
with open('dataFastDelta_t01Errors.p','wb') as outputFile:
    pickle.dump(delta_t_errors_fast,outputFile)
    pickle.dump(fast_errors_averaged_over_trials, outputFile)
    pickle.dump(n_neurons_fast, outputFile)
    pickle.dump(delta_t_fast, outputFile)
    pickle.dump(new_trials, outputFile)
    pickle.dump(l_rate_fast, outputFile)
    pickle.dump(sp_rad_fast, outputFile)
#### Load Data
# with open('dataFastDelta_tErrors.p', 'rb') as inputFile:
#     delta_t_errors_fast = pickle.load(inputFile)
#     fast_errors_averaged_over_trials = pickle.load(inputFile)
#     n_neurons_fast = pickle.load(inputFile)
#     delta_t_fast = pickle.load(inputFile)
#     new_trials = pickle.load(inputFile)
#     l_rate_fast = pickle.load(inputFile)
#     sp_rad_fast = pickle.load(inputFile)

# %% [markdown]
# data = [
#      go.Contour(
#         z=fast_errors_averaged_over_trials.reshape(10,10).T,
#         x=l_rate_fast,
#         y=sp_rad_fast,
#         colorscale='Jet',
#     )]
# py.iplot(data)

# %%
### Different delta_t

from matplotlib import pyplot
# %matplotlib inline
print(delta_t_fast)
xx, yy = np.meshgrid(l_rate_fast, sp_rad_fast)
pyplot.figure(figsize=(12,14))
for p in range(len(delta_t_fast)):
    pyplot.subplot(3,2,p+1)
    pyplot.contourf(xx,
                    yy,delta_t_errors_fast[p].reshape(10,10).T)
    pyplot.title("Fast ESN trained using best slow ESN")
    pyplot.xlabel("Leak-rate")
    pyplot.ylabel("Spectral-radius")
    pyplot.colorbar()
# Out:
# [0.1]

# %% [markdown]
# import plotly.plotly as py
# import plotly.graph_objs as go
#
# # c= ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, len(all_errors_fast))]
# c= ["blue", "orange", "green", "cyan", "yellow", "magenta", "red", "black"]
# data = []
#
#
# x = np.repeat(l_rate_fast,len(l_rate_fast))
# y = np.tile(sp_rad_fast,len(sp_rad_fast))
# z = fast_errors_averaged_over_trials
#
# trace1 = go.Scatter3d(
#     x=x,
#     y=y,
#     z=z,
#     name=("Fast network averaged over",new_trials,"Trials"),
#     mode='markers',
#     marker=dict(
#         size=7,
#         color=z,                # set color to an array/list of desired values
#         colorscale='Viridis',   # choose a colorscale
#         opacity=0.8
#     )
# )
#
#
# data = [trace1]
# layout = go.Layout(
# #     margin=dict(
# #         l=0,
# #         r=0,
# #         b=0,
# #         t=0
# #     ),
# #     go.zaxis=dict(
# #         range=[0, 0.8]
# #     ),
#     scene=go.Scene(
#         xaxis=go.XAxis(title='x = Leak-Rate'),
#         yaxis=go.YAxis(title='y = Spectral Radius'),
#         zaxis=go.ZAxis(title='z = Error')
#         )
# )
# fig = go.Figure(data=data, layout=layout)
# py.iplot(fig, filename='Fast Network Averaged')
