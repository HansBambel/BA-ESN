# %%
import Parity_Data_Generator
import numpy as np
from pyESN import ESN
import time

N = 5000   # number of datapoints
n = 3       # n-parity
timescale = 50
rng = np.random.RandomState(42)

# %% [markdown]
# start_time = time.time()
# # produce Data
# bits, parity, target = Parity_Data_Generator.generateParityData(N, n, randomstate=rng)
#
# # Divide in training and test data
# traintest_cutoff = int(np.ceil(0.7 * len(bits)))
# train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
# train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
# train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
#
# print("--- %s seconds ---" % (time.time() - start_time))

# %%
def runSomeConfigs(spectral_rad, leak_r, train_b, test_b, train_p, test_p, n_neurons):
#     print("Spectral-radius:",spectral_rad, "leak-rate:", leak_r)
    nParityESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=n_neurons,  # from 200 onwards test error decreases significantly
                          spectral_radius=spectral_rad,  # high spectral rad is better (high fluctuations 0->1->0)
                          leak_rate= leak_r,   # adjust leak_rate
                          sparsity=0.95,
                          noise=0.01,
                          input_shift=0,
                          input_scaling=3,  # 3 seems to be fine. Maybe use lower
                          teacher_forcing=False,
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          random_state=rng,
                          silent=False)
    # print(np.shape(bits),np.shape(parity),np.shape(target))
    nParityESN.fit(train_b, train_p)
    pred_test = nParityESN.predict(test_b)

    #### not rounding
    predictedParity = pred_test # not rounding
    #### Rounding
#     better_pred_test = []           # Maybe don't round and return "true" results from pred_test
#     for x in pred_test:
#         better_pred_test.append(0 if x < 0.5 else 1)
#     predictedParity = np.array(better_pred_test).reshape(-1,1)
#     print(test_parity[40030:40100].reshape(-1))
#     print(predictedParity[40030:40100].reshape(-1))
    
    print("Testing error")
    test_error = np.sqrt(np.mean((predictedParity - test_p) ** 2))
    print(test_error)
    return test_error

# %%
def produceTrainingData(i):
    bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(i))

    # Divide in training and test data
    traintest_cutoff = int(np.ceil(0.7 * len(bits)))
    train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
    train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
#     train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
    return train_bits, test_bits, train_parity, test_parity

# %%
trials = 1
n_neurons_slow = [200,300,400,500]
# n_neurons_slow = [200]

l_rate = np.linspace(0.1, 1, num=10)
# l_rate =[0.2]
# l_rate = [0.1,0.2,0.3]

# sp_rad = np.linspace(0.9, 1.0, num=5)
sp_rad = np.linspace(0.1, 1, num=10)
# sp_rad = [0.8]

run_time = time.time()
iterations, iterationcount = trials*len(n_neurons_slow)*len(sp_rad)*len(l_rate), 0

neurons_slow_error = []
for current_slow_neurons in n_neurons_slow:
    all_errors = [{} for _ in range(trials)] # empty dict
    for i in range(trials):
        errors = []
        # produce training and testing data
        train_bits, test_bits, train_parity, test_parity = produceTrainingData(i)
        for l in l_rate:
            for s in sp_rad:
                print("Neurons:", current_slow_neurons,"Leak-rate:",l,"Spectral-radius:",s)
                errors.append(runSomeConfigs(s,l, train_bits, test_bits, train_parity, test_parity, current_slow_neurons))
                iterationcount = iterationcount + 1
                print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
        ## Save leak-rate,spectral-radius and error in dictionary
        all_errors[i] = errors

    ### Average errors
    errors_averaged_over_trials = np.zeros(100)
    for i in range(len(all_errors)):
        e = all_errors[i]
        errors_averaged_over_trials = np.add(errors_averaged_over_trials, np.array(e))
    errors_averaged_over_trials = np.divide(errors_averaged_over_trials, trials)
    
    neurons_slow_error.append(errors_averaged_over_trials)
            
print("Total time for Testbench:")
print("--- {:.2f} seconds ---".format(time.time() - run_time))
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 200 Leak-rate: 0.1 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.462324337399
# Testing error
# 0.458679504403
# --- Progress: 1.00% --- 0.22 minutes ---
# Neurons: 200 Leak-rate: 0.1 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.447148930255
# Testing error
# 0.444430091021
# --- Progress: 2.00% --- 0.45 minutes ---
# Neurons: 200 Leak-rate: 0.1 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.420897106747
# Testing error
# 0.421535127694
# --- Progress: 3.00% --- 0.67 minutes ---
# Neurons: 200 Leak-rate: 0.1 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.45356030541
# Testing error
# 0.458051524725
# --- Progress: 4.00% --- 0.91 minutes ---
# Neurons: 200 Leak-rate: 0.1 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.41918670501
# Testing error
# 0.428997388981
# --- Progress: 5.00% --- 1.13 minutes ---
# Neurons: 200 Leak-rate: 0.1 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.408446973322
# Testing error
# 0.428945639238
# --- Progress: 6.00% --- 1.35 minutes ---
# Neurons: 200 Leak-rate: 0.1 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.431350714227
# Testing error
# 0.441163482534
# --- Progress: 7.00% --- 1.58 minutes ---
# Neurons: 200 Leak-rate: 0.1 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.443899787234
# Testing error
# 0.449551287997
# --- Progress: 8.00% --- 1.81 minutes ---
# Neurons: 200 Leak-rate: 0.1 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.428213490059
# Testing error
# 0.436427782175
# --- Progress: 9.00% --- 2.03 minutes ---
# Neurons: 200 Leak-rate: 0.1 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.419462013853
# Testing error
# 0.432079430685
# --- Progress: 10.00% --- 2.26 minutes ---
# Neurons: 200 Leak-rate: 0.2 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502914687541
# Testing error
# 0.50521894832
# --- Progress: 11.00% --- 2.50 minutes ---
# Neurons: 200 Leak-rate: 0.2 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.471329959157
# Testing error
# 0.467672385725
# --- Progress: 12.00% --- 2.72 minutes ---
# Neurons: 200 Leak-rate: 0.2 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.461930490125
# Testing error
# 0.458040036266
# --- Progress: 13.00% --- 2.94 minutes ---
# Neurons: 200 Leak-rate: 0.2 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.461428361057
# Testing error
# 0.457155025755
# --- Progress: 14.00% --- 3.16 minutes ---
# Neurons: 200 Leak-rate: 0.2 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.464423070979
# Testing error
# 0.463549154118
# --- Progress: 15.00% --- 3.38 minutes ---
# Neurons: 200 Leak-rate: 0.2 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.467784645638
# Testing error
# 0.466501778774
# --- Progress: 16.00% --- 3.61 minutes ---
# Neurons: 200 Leak-rate: 0.2 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.466816550287
# Testing error
# 0.469810971148
# --- Progress: 17.00% --- 3.83 minutes ---
# Neurons: 200 Leak-rate: 0.2 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.473790062274
# Testing error
# 0.474784186571
# --- Progress: 18.00% --- 4.07 minutes ---
# Neurons: 200 Leak-rate: 0.2 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.491351787371
# Testing error
# 0.4983784996
# --- Progress: 19.00% --- 4.29 minutes ---
# Neurons: 200 Leak-rate: 0.2 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.476756640445
# Testing error
# 0.48522375707
# --- Progress: 20.00% --- 4.52 minutes ---
# Neurons: 200 Leak-rate: 0.3 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.505055861033
# Testing error
# 0.506391078733
# --- Progress: 21.00% --- 4.74 minutes ---
# Neurons: 200 Leak-rate: 0.3 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.503069772068
# Testing error
# 0.505430574216
# --- Progress: 22.00% --- 4.96 minutes ---
# Neurons: 200 Leak-rate: 0.3 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.486520923565
# Testing error
# 0.485641502052
# --- Progress: 23.00% --- 5.19 minutes ---
# Neurons: 200 Leak-rate: 0.3 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.469997816266
# Testing error
# 0.465966521219
# --- Progress: 24.00% --- 5.41 minutes ---
# Neurons: 200 Leak-rate: 0.3 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.462558937278
# Testing error
# 0.458749936286
# --- Progress: 25.00% --- 5.63 minutes ---
# Neurons: 200 Leak-rate: 0.3 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.477664315376
# Testing error
# 0.47697535183
# --- Progress: 26.00% --- 5.85 minutes ---
# Neurons: 200 Leak-rate: 0.3 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.467642467023
# Testing error
# 0.464080221294
# --- Progress: 27.00% --- 6.07 minutes ---
# Neurons: 200 Leak-rate: 0.3 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.477944546263
# Testing error
# 0.482412875465
# --- Progress: 28.00% --- 6.29 minutes ---
# Neurons: 200 Leak-rate: 0.3 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.484915668639
# Testing error
# 0.489721740657
# --- Progress: 29.00% --- 6.51 minutes ---
# Neurons: 200 Leak-rate: 0.3 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.477937059987
# Testing error
# 0.478426642748
# --- Progress: 30.00% --- 6.74 minutes ---
# Neurons: 200 Leak-rate: 0.4 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.506184834873
# Testing error
# 0.506774948431
# --- Progress: 31.00% --- 6.95 minutes ---
# Neurons: 200 Leak-rate: 0.4 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.505398159343
# Testing error
# 0.506568909979
# --- Progress: 32.00% --- 7.17 minutes ---
# Neurons: 200 Leak-rate: 0.4 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.503647363186
# Testing error
# 0.50572088276
# --- Progress: 33.00% --- 7.39 minutes ---
# Neurons: 200 Leak-rate: 0.4 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.499252918357
# Testing error
# 0.501382063073
# --- Progress: 34.00% --- 7.60 minutes ---
# Neurons: 200 Leak-rate: 0.4 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.477539173964
# Testing error
# 0.474528608648
# --- Progress: 35.00% --- 7.82 minutes ---
# Neurons: 200 Leak-rate: 0.4 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.48897691538
# Testing error
# 0.489601537374
# --- Progress: 36.00% --- 8.04 minutes ---
# Neurons: 200 Leak-rate: 0.4 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.463381222229
# Testing error
# 0.459640355711
# --- Progress: 37.00% --- 8.26 minutes ---
# Neurons: 200 Leak-rate: 0.4 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.467462591007
# Testing error
# 0.464162033162
# --- Progress: 38.00% --- 8.48 minutes ---
# Neurons: 200 Leak-rate: 0.4 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.480208767755
# Testing error
# 0.483239591463
# --- Progress: 39.00% --- 8.70 minutes ---
# Neurons: 200 Leak-rate: 0.4 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.474601051217
# Testing error
# 0.471249960975
# --- Progress: 40.00% --- 8.92 minutes ---
# Neurons: 200 Leak-rate: 0.5 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.506700800508
# Testing error
# 0.507146296776
# --- Progress: 41.00% --- 9.14 minutes ---
# Neurons: 200 Leak-rate: 0.5 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.506128991615
# Testing error
# 0.507108079836
# --- Progress: 42.00% --- 9.35 minutes ---
# Neurons: 200 Leak-rate: 0.5 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.505275564398
# Testing error
# 0.506508154395
# --- Progress: 43.00% --- 9.57 minutes ---
# Neurons: 200 Leak-rate: 0.5 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.504360694804
# Testing error
# 0.506333453293
# --- Progress: 44.00% --- 9.79 minutes ---
# Neurons: 200 Leak-rate: 0.5 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.501883036713
# Testing error
# 0.503729201078
# --- Progress: 45.00% --- 10.02 minutes ---
# Neurons: 200 Leak-rate: 0.5 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.486904850073
# Testing error
# 0.48628677956
# --- Progress: 46.00% --- 10.24 minutes ---
# Neurons: 200 Leak-rate: 0.5 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.474298156055
# Testing error
# 0.469367810931
# --- Progress: 47.00% --- 10.45 minutes ---
# Neurons: 200 Leak-rate: 0.5 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.474787260342
# Testing error
# 0.47094231844
# --- Progress: 48.00% --- 10.67 minutes ---
# Neurons: 200 Leak-rate: 0.5 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.473347742414
# Testing error
# 0.470098805345
# --- Progress: 49.00% --- 10.89 minutes ---
# Neurons: 200 Leak-rate: 0.5 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.48784661497
# Testing error
# 0.489380886401
# --- Progress: 50.00% --- 11.11 minutes ---
# Neurons: 200 Leak-rate: 0.6 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.507077340568
# Testing error
# 0.507325785044
# --- Progress: 51.00% --- 11.33 minutes ---
# Neurons: 200 Leak-rate: 0.6 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.50675015918
# Testing error
# 0.507169508889
# --- Progress: 52.00% --- 11.55 minutes ---
# Neurons: 200 Leak-rate: 0.6 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.506354430183
# Testing error
# 0.50687450265
# --- Progress: 53.00% --- 11.76 minutes ---
# Neurons: 200 Leak-rate: 0.6 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.505599449477
# Testing error
# 0.506905846057
# --- Progress: 54.00% --- 11.98 minutes ---
# Neurons: 200 Leak-rate: 0.6 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.503810551388
# Testing error
# 0.506020168937
# --- Progress: 55.00% --- 12.19 minutes ---
# Neurons: 200 Leak-rate: 0.6 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.502786925109
# Testing error
# 0.504895804939
# --- Progress: 56.00% --- 12.41 minutes ---
# Neurons: 200 Leak-rate: 0.6 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.499122623611
# Testing error
# 0.501871980807
# --- Progress: 57.00% --- 12.63 minutes ---
# Neurons: 200 Leak-rate: 0.6 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.472509708825
# Testing error
# 0.469781123901
# --- Progress: 58.00% --- 12.84 minutes ---
# Neurons: 200 Leak-rate: 0.6 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.499266982672
# Testing error
# 0.500459535467
# --- Progress: 59.00% --- 13.06 minutes ---
# Neurons: 200 Leak-rate: 0.6 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.476237306562
# Testing error
# 0.474128264261
# --- Progress: 60.00% --- 13.28 minutes ---
# Neurons: 200 Leak-rate: 0.7 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.507325490793
# Testing error
# 0.507497753343
# --- Progress: 61.00% --- 13.50 minutes ---
# Neurons: 200 Leak-rate: 0.7 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.507046798256
# Testing error
# 0.507181622197
# --- Progress: 62.00% --- 13.72 minutes ---
# Neurons: 200 Leak-rate: 0.7 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.506803547594
# Testing error
# 0.507200639318
# --- Progress: 63.00% --- 13.93 minutes ---
# Neurons: 200 Leak-rate: 0.7 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.506432912045
# Testing error
# 0.506992241597
# --- Progress: 64.00% --- 14.15 minutes ---
# Neurons: 200 Leak-rate: 0.7 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.50568364818
# Testing error
# 0.50666048599
# --- Progress: 65.00% --- 14.36 minutes ---
# Neurons: 200 Leak-rate: 0.7 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.504296923839
# Testing error
# 0.505805441719
# --- Progress: 66.00% --- 14.58 minutes ---
# Neurons: 200 Leak-rate: 0.7 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.50211310641
# Testing error
# 0.504592559752
# --- Progress: 67.00% --- 14.80 minutes ---
# Neurons: 200 Leak-rate: 0.7 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.478067541689
# Testing error
# 0.476376419582
# --- Progress: 68.00% --- 15.01 minutes ---
# Neurons: 200 Leak-rate: 0.7 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.499212029438
# Testing error
# 0.501244999258
# --- Progress: 69.00% --- 15.23 minutes ---
# Neurons: 200 Leak-rate: 0.7 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.472531137731
# Testing error
# 0.469054202664
# --- Progress: 70.00% --- 15.45 minutes ---
# Neurons: 200 Leak-rate: 0.8 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.507435061054
# Testing error
# 0.507387680382
# --- Progress: 71.00% --- 15.66 minutes ---
# Neurons: 200 Leak-rate: 0.8 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.507294356529
# Testing error
# 0.507414924789
# --- Progress: 72.00% --- 15.88 minutes ---
# Neurons: 200 Leak-rate: 0.8 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.507074387403
# Testing error
# 0.507341436681
# --- Progress: 73.00% --- 16.10 minutes ---
# Neurons: 200 Leak-rate: 0.8 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.506833155717
# Testing error
# 0.507138494526
# --- Progress: 74.00% --- 16.31 minutes ---
# Neurons: 200 Leak-rate: 0.8 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.506430432068
# Testing error
# 0.506982754337
# --- Progress: 75.00% --- 16.53 minutes ---
# Neurons: 200 Leak-rate: 0.8 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.505991419312
# Testing error
# 0.506646508638
# --- Progress: 76.00% --- 16.74 minutes ---
# Neurons: 200 Leak-rate: 0.8 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.504949478881
# Testing error
# 0.506061307934
# --- Progress: 77.00% --- 16.96 minutes ---
# Neurons: 200 Leak-rate: 0.8 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.503217555956
# Testing error
# 0.505795461099
# --- Progress: 78.00% --- 17.17 minutes ---
# Neurons: 200 Leak-rate: 0.8 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.491299708869
# Testing error
# 0.491399292556
# --- Progress: 79.00% --- 17.39 minutes ---
# Neurons: 200 Leak-rate: 0.8 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.487896249179
# Testing error
# 0.48576221428
# --- Progress: 80.00% --- 17.61 minutes ---
# Neurons: 200 Leak-rate: 0.9 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.507581583731
# Testing error
# 0.507582873445
# --- Progress: 81.00% --- 17.82 minutes ---
# Neurons: 200 Leak-rate: 0.9 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.507393622429
# Testing error
# 0.507633486803
# --- Progress: 82.00% --- 18.04 minutes ---
# Neurons: 200 Leak-rate: 0.9 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.507254819796
# Testing error
# 0.5073562736
# --- Progress: 83.00% --- 18.25 minutes ---
# Neurons: 200 Leak-rate: 0.9 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.507162944109
# Testing error
# 0.50725562708
# --- Progress: 84.00% --- 18.47 minutes ---
# Neurons: 200 Leak-rate: 0.9 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.507005176787
# Testing error
# 0.507232924985
# --- Progress: 85.00% --- 18.68 minutes ---
# Neurons: 200 Leak-rate: 0.9 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.506539270479
# Testing error
# 0.507019323256
# --- Progress: 86.00% --- 18.90 minutes ---
# Neurons: 200 Leak-rate: 0.9 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.506571227078
# Testing error
# 0.506896388826
# --- Progress: 87.00% --- 19.11 minutes ---
# Neurons: 200 Leak-rate: 0.9 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.504661443043
# Testing error
# 0.506308210851
# --- Progress: 88.00% --- 19.33 minutes ---
# Neurons: 200 Leak-rate: 0.9 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.50413487357
# Testing error
# 0.505986124836
# --- Progress: 89.00% --- 19.54 minutes ---
# Neurons: 200 Leak-rate: 0.9 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.494260582945
# Testing error
# 0.495336484343
# --- Progress: 90.00% --- 19.76 minutes ---
# Neurons: 200 Leak-rate: 1.0 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.507614145509
# Testing error
# 0.507556039553
# --- Progress: 91.00% --- 19.98 minutes ---
# Neurons: 200 Leak-rate: 1.0 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.507553467828
# Testing error
# 0.507567209015
# --- Progress: 92.00% --- 20.19 minutes ---
# Neurons: 200 Leak-rate: 1.0 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.507440200995
# Testing error
# 0.507479124057
# --- Progress: 93.00% --- 20.41 minutes ---
# Neurons: 200 Leak-rate: 1.0 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.507242913689
# Testing error
# 0.507441177238
# --- Progress: 94.00% --- 20.62 minutes ---
# Neurons: 200 Leak-rate: 1.0 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.507261432154
# Testing error
# 0.507444480141
# --- Progress: 95.00% --- 20.84 minutes ---
# Neurons: 200 Leak-rate: 1.0 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.506892223533
# Testing error
# 0.50723127016
# --- Progress: 96.00% --- 21.05 minutes ---
# Neurons: 200 Leak-rate: 1.0 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.506679226559
# Testing error
# 0.507196981208
# --- Progress: 97.00% --- 21.27 minutes ---
# Neurons: 200 Leak-rate: 1.0 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.50633535033
# Testing error
# 0.507188976941
# --- Progress: 98.00% --- 21.48 minutes ---
# Neurons: 200 Leak-rate: 1.0 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.504426455203
# Testing error
# 0.506133632041
# --- Progress: 99.00% --- 21.70 minutes ---
# Neurons: 200 Leak-rate: 1.0 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.502546621786
# Testing error
# 0.504585236945
# --- Progress: 100.00% --- 21.92 minutes ---
# Total time for Testbench:
# --- 1314.93 seconds ---
# --- 21.92 minutes ---

# %%
import pickle
#### Save Data
with open('datasaveAverageSlowDifferentNeuronSizes.p', 'wb') as outputFile:
    pickle.dump(neurons_slow_error, outputfile)
    pickle.dump(n_neurons_slow, outputFile)
    pickle.dump(trials, outputFile)
    pickle.dump(l_rate, outputFile)
    pickle.dump(sp_rad, outputFile)
#### Load Data
# with open('datasaveAverageSlowDifferentNeuronSizes.p', 'rb') as inputFile:
#     neurons_slow_error = pickle.load(inputFile)
#     n_neurons_slow = pickle.load(inputFile)
#     trials = pickle.load(inputFile)
#     l_rate = pickle.load(inputFile)
#     sp_rad = pickle.load(inputFile)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# c= ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, len(all_errors))]
# c= ["blue", "orange", "green", "cyan", "yellow", "magenta", "red", "black"]

x = np.repeat(l_rate,len(l_rate))
y = np.tile(sp_rad, len(sp_rad))
z = neurons_slow_error[0]
trace1 = go.Scatter3d(
    x=x,
    y=y,
    z=z,
    name=("Averaged over", trials ,"Trials"),
    mode='markers',
    marker=dict(
        size=7,
        color=z,                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    )
)

data = [trace1]
layout = go.Layout(
#     margin=dict(
#         l=0,
#         r=0,
#         b=0,
#         t=0
#     ),
#     go.zaxis=dict(
#         range=[0, 0.8]
#     ),
    scene=go.Scene(
        xaxis=go.XAxis(title='x = Leak-Rate'),
        yaxis=go.YAxis(title='y = Spectral Radius'),
        zaxis=go.ZAxis(title='z = Error')
        )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='SlowESN average Error')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HansBambel/16.embed" height="525px" width="100%"></iframe>

# %%
data = [
     go.Contour(
        z=errors_averaged_over_trials.reshape(10,10).T,
        x=l_rate,
        y=sp_rad,
        colorscale='Jet',
    )]
py.iplot(data)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HansBambel/68.embed" height="525px" width="100%"></iframe>

# %%
from matplotlib import pyplot
# %matplotlib inline
for p in range(len(n_neurons_slow)):
    pyplot.figure(figsize=(12,6))
    pyplot.subplot(p+1,1,len(n_neurons_slow))
    pyplot.contourf(np.repeat(l_rate,len(l_rate)).reshape(10,10),
                    np.tile(sp_rad, len(sp_rad)).reshape(10,10),neurons_slow_error[p].reshape(10,10))
    pyplot.title((n_neurons_slow[p],"Neurons"))
    pyplot.xlabel("Leak-rate")
    pyplot.ylabel("Spectral-radius")
    pyplot.colorbar()

# %%
#### Get Parameters from a good performing slowESN

nParityESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=250,  # from 200 onwards test error decreases significantly
                          spectral_radius=0.8,  # high spectral rad is better (high fluctuations 0->1->0)
                          leak_rate= 0.1,   # adjust leak_rate
                          sparsity=0.95,     # 0.95
                          noise=0.01,      # 0.001
                          input_shift=-0.5,    # 0
                          input_scaling=3,  # 3 seems to be fine. Maybe use lower
                          teacher_forcing=False,
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          random_state=rng,
                          silent=False)
nParityESN.fit(train_bits, train_parity)
# Out:
# harvesting states...
# fitting...
# training error:
# 0.367890732891
# array([[ 0.63820067],
#        [ 0.60948108],
#        [ 0.6336934 ],
#        ...,
#        [ 0.49179118],
#        [ 0.30924047],
#        [ 0.19430355]])

# %%
##### Create Training Data for fastESN with output from slowESN
start_time = time.time()

new_rng = np.random.RandomState(1337)
new_N, new_n = 1500, 3
# new_bits, new_parity, new_target = Parity_Data_Generator.generateParityData(new_N, new_n, 
#                                                                             timescale=timescale,randomstate=new_rng)

# # Divide in training and test data
# traintest_cutoff = int(np.ceil(0.7 * len(bits)))
# new_train_bits, new_test_bits = new_bits[:traintest_cutoff], new_bits[traintest_cutoff:]
# # new_train_parity, new_test_parity = new_parity[:traintest_cutoff], new_parity[traintest_cutoff:]
# new_train_targets, new_test_targets = new_target[:traintest_cutoff], new_target[traintest_cutoff:]

# train_predicted_parity = nParityESN.predict(new_train_bits)
# test_predicted_parity = nParityESN.predict(new_test_bits)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.000499725341796875 seconds ---

# %%
#### FastESN ####
def runSomeFastConfigs(spectral_rad, leak_r, train_parity, test_parity, 
                       train_targets, test_targets, num_neurons=100):
    outputESN = ESN(n_inputs=1,
                              n_outputs=1,
                              n_reservoir=num_neurons,  
                              spectral_radius=spectral_rad,  # high spectral rad is better (high fluctuations 0->1->0)
                              leak_rate= leak_r,   # adjust leak_rate
                              sparsity=0.95,
                              noise=0.01,
                              input_shift=0,
                              input_scaling=3,  # 3 seems to be fine. Maybe use lower
                              teacher_forcing=False,
                              teacher_scaling=1.12,
                              teacher_shift=-0.4,
                              random_state=new_rng,
                              silent=False)
        # print(np.shape(bits),np.shape(parity),np.shape(target))
    outputESN.fit(train_parity, train_targets)
    pred_test = outputESN.predict(test_parity)
        
    print("Testing error")
    test_error = np.sqrt(np.mean((pred_test - test_targets) ** 2))
    print(test_error)
    return test_error

def produceFastTrainingData(randomState):
    bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(randomState))

    # Divide in training and test data
    traintest_cutoff = int(np.ceil(0.7 * len(bits)))
    train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
    train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
    
    train_predicted_parity = nParityESN.predict(train_bits)
    test_predicted_parity = nParityESN.predict(test_bits)
    
    return train_predicted_parity, test_predicted_parity, train_targets, test_targets

# %%
new_trials = 1
n_neurons_fast = 100
# num_neurons_fast = [100]
# l_rate_fast = np.linspace(0.4, 1, num=7)
l_rate_fast = np.linspace(0.1, 1, num=10)
# l_rate_fast = [0.6]
# sp_rad_fast = np.linspace(0.8, 1, num=3)
sp_rad_fast = np.linspace(0.1, 1, num=10)
# sp_rad_fast = [0.95]

run_time = time.time()
iterations, iterationcount = new_trials*len(sp_rad_fast)*len(l_rate_fast), 0
errors = []
all_errors_fast = [{} for _ in range(new_trials)]
for i in range(new_trials):
    errors = []
    
    new_train_parity, new_test_parity, new_train_targets, new_test_targets = produceFastTrainingData(i)
    
    for l in l_rate_fast:
        for s in sp_rad_fast:
            print("Neurons:", n_neurons_fast, "Leak-rate:", l, "Spectral-radius:", s)
            errors.append(runSomeFastConfigs(s,l,new_train_parity, new_test_parity, new_train_targets, new_test_targets,n_neurons_fast))
            iterationcount = iterationcount + 1
            print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
    ## Save leak-rate,spectral-radius and error in dictionary
    all_errors_fast[i] = errors

### Average errors
fast_errors_averaged_over_trials = np.zeros(100)
for i in range(len(all_errors_fast)):
    e = all_errors_fast[i]
    fast_errors_averaged_over_trials = np.add(fast_errors_averaged_over_trials, np.array(e))

fast_errors_averaged_over_trials = np.divide(fast_errors_averaged_over_trials, new_trials)
            
print("Total time for Testbench:")
print("--- {:.2f} seconds ---".format(time.time() - run_time))
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 100 Leak-rate: 0.1 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.336859820139
# Testing error
# 0.332536453934
# --- Progress: 1.00% --- 0.13 minutes ---
# Neurons: 100 Leak-rate: 0.1 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.333995790112
# Testing error
# 0.329217496275
# --- Progress: 2.00% --- 0.19 minutes ---
# Neurons: 100 Leak-rate: 0.1 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.333493939928
# Testing error
# 0.327177572672
# --- Progress: 3.00% --- 0.24 minutes ---
# Neurons: 100 Leak-rate: 0.1 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.335562948489
# Testing error
# 0.33252345549
# --- Progress: 4.00% --- 0.30 minutes ---
# Neurons: 100 Leak-rate: 0.1 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.332512897013
# Testing error
# 0.328077463853
# --- Progress: 5.00% --- 0.35 minutes ---
# Neurons: 100 Leak-rate: 0.1 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.338760105553
# Testing error
# 0.337763187573
# --- Progress: 6.00% --- 0.41 minutes ---
# Neurons: 100 Leak-rate: 0.1 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.332471054012
# Testing error
# 0.32673532538
# --- Progress: 7.00% --- 0.47 minutes ---
# Neurons: 100 Leak-rate: 0.1 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.330243374461
# Testing error
# 0.32402418949
# --- Progress: 8.00% --- 0.52 minutes ---
# Neurons: 100 Leak-rate: 0.1 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.334797718148
# Testing error
# 0.330145720215
# --- Progress: 9.00% --- 0.58 minutes ---
# Neurons: 100 Leak-rate: 0.1 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.333462922868
# Testing error
# 0.330911877018
# --- Progress: 10.00% --- 0.63 minutes ---
# Neurons: 100 Leak-rate: 0.2 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.340912908921
# Testing error
# 0.335890738497
# --- Progress: 11.00% --- 0.69 minutes ---
# Neurons: 100 Leak-rate: 0.2 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.340209257369
# Testing error
# 0.334804324103
# --- Progress: 12.00% --- 0.74 minutes ---
# Neurons: 100 Leak-rate: 0.2 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.334586747127
# Testing error
# 0.32855815961
# --- Progress: 13.00% --- 0.80 minutes ---
# Neurons: 100 Leak-rate: 0.2 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.334652174393
# Testing error
# 0.327103128489
# --- Progress: 14.00% --- 0.85 minutes ---
# Neurons: 100 Leak-rate: 0.2 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.334261979853
# Testing error
# 0.329778782934
# --- Progress: 15.00% --- 0.91 minutes ---
# Neurons: 100 Leak-rate: 0.2 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.333759857785
# Testing error
# 0.327006613125
# --- Progress: 16.00% --- 0.96 minutes ---
# Neurons: 100 Leak-rate: 0.2 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.331568202042
# Testing error
# 0.32550325909
# --- Progress: 17.00% --- 1.02 minutes ---
# Neurons: 100 Leak-rate: 0.2 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.337931281129
# Testing error
# 0.33319849877
# --- Progress: 18.00% --- 1.07 minutes ---
# Neurons: 100 Leak-rate: 0.2 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.339638787916
# Testing error
# 0.335956423542
# --- Progress: 19.00% --- 1.13 minutes ---
# Neurons: 100 Leak-rate: 0.2 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.337509189151
# Testing error
# 0.332575942173
# --- Progress: 20.00% --- 1.18 minutes ---
# Neurons: 100 Leak-rate: 0.3 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.350766860625
# Testing error
# 0.346864602478
# --- Progress: 21.00% --- 1.24 minutes ---
# Neurons: 100 Leak-rate: 0.3 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.344554963376
# Testing error
# 0.339383949239
# --- Progress: 22.00% --- 1.30 minutes ---
# Neurons: 100 Leak-rate: 0.3 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.343480483038
# Testing error
# 0.338498502925
# --- Progress: 23.00% --- 1.35 minutes ---
# Neurons: 100 Leak-rate: 0.3 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.3390893749
# Testing error
# 0.333338434295
# --- Progress: 24.00% --- 1.41 minutes ---
# Neurons: 100 Leak-rate: 0.3 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.337094295471
# Testing error
# 0.332820130897
# --- Progress: 25.00% --- 1.46 minutes ---
# Neurons: 100 Leak-rate: 0.3 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.336553112239
# Testing error
# 0.329327128446
# --- Progress: 26.00% --- 1.52 minutes ---
# Neurons: 100 Leak-rate: 0.3 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.337532014359
# Testing error
# 0.330249328478
# --- Progress: 27.00% --- 1.58 minutes ---
# Neurons: 100 Leak-rate: 0.3 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.338373460128
# Testing error
# 0.332757101947
# --- Progress: 28.00% --- 1.63 minutes ---
# Neurons: 100 Leak-rate: 0.3 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.336768788186
# Testing error
# 0.333526240725
# --- Progress: 29.00% --- 1.69 minutes ---
# Neurons: 100 Leak-rate: 0.3 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.33657936873
# Testing error
# 0.330605342944
# --- Progress: 30.00% --- 1.74 minutes ---
# Neurons: 100 Leak-rate: 0.4 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.355773276145
# Testing error
# 0.352605091645
# --- Progress: 31.00% --- 1.80 minutes ---
# Neurons: 100 Leak-rate: 0.4 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.352017042976
# Testing error
# 0.348703933971
# --- Progress: 32.00% --- 1.85 minutes ---
# Neurons: 100 Leak-rate: 0.4 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.344657314475
# Testing error
# 0.339656626668
# --- Progress: 33.00% --- 1.91 minutes ---
# Neurons: 100 Leak-rate: 0.4 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.342905504534
# Testing error
# 0.336976228688
# --- Progress: 34.00% --- 1.96 minutes ---
# Neurons: 100 Leak-rate: 0.4 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.339297328913
# Testing error
# 0.332173505141
# --- Progress: 35.00% --- 2.02 minutes ---
# Neurons: 100 Leak-rate: 0.4 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.345427180346
# Testing error
# 0.341797904445
# --- Progress: 36.00% --- 2.07 minutes ---
# Neurons: 100 Leak-rate: 0.4 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.340653302627
# Testing error
# 0.335005173904
# --- Progress: 37.00% --- 2.13 minutes ---
# Neurons: 100 Leak-rate: 0.4 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.338253181606
# Testing error
# 0.330607985048
# --- Progress: 38.00% --- 2.18 minutes ---
# Neurons: 100 Leak-rate: 0.4 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.34127252151
# Testing error
# 0.337910460116
# --- Progress: 39.00% --- 2.24 minutes ---
# Neurons: 100 Leak-rate: 0.4 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.339790920727
# Testing error
# 0.333236693168
# --- Progress: 40.00% --- 2.29 minutes ---
# Neurons: 100 Leak-rate: 0.5 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.360891926012
# Testing error
# 0.35893228857
# --- Progress: 41.00% --- 2.35 minutes ---
# Neurons: 100 Leak-rate: 0.5 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.356879030247
# Testing error
# 0.354062949768
# --- Progress: 42.00% --- 2.40 minutes ---
# Neurons: 100 Leak-rate: 0.5 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.353472068246
# Testing error
# 0.34957428244
# --- Progress: 43.00% --- 2.46 minutes ---
# Neurons: 100 Leak-rate: 0.5 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.351308739286
# Testing error
# 0.346947817241
# --- Progress: 44.00% --- 2.51 minutes ---
# Neurons: 100 Leak-rate: 0.5 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.3488783479
# Testing error
# 0.343639416072
# --- Progress: 45.00% --- 2.57 minutes ---
# Neurons: 100 Leak-rate: 0.5 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.343199192962
# Testing error
# 0.338475056464
# --- Progress: 46.00% --- 2.62 minutes ---
# Neurons: 100 Leak-rate: 0.5 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.345163389102
# Testing error
# 0.338733770845
# --- Progress: 47.00% --- 2.68 minutes ---
# Neurons: 100 Leak-rate: 0.5 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.345472109601
# Testing error
# 0.341272978309
# --- Progress: 48.00% --- 2.73 minutes ---
# Neurons: 100 Leak-rate: 0.5 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.342654140458
# Testing error
# 0.336782885903
# --- Progress: 49.00% --- 2.79 minutes ---
# Neurons: 100 Leak-rate: 0.5 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.342244132529
# Testing error
# 0.337285584628
# --- Progress: 50.00% --- 2.84 minutes ---
# Neurons: 100 Leak-rate: 0.6 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.365323797251
# Testing error
# 0.363899010279
# --- Progress: 51.00% --- 2.90 minutes ---
# Neurons: 100 Leak-rate: 0.6 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.362267965183
# Testing error
# 0.36084471751
# --- Progress: 52.00% --- 2.95 minutes ---
# Neurons: 100 Leak-rate: 0.6 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.358500047223
# Testing error
# 0.356004993904
# --- Progress: 53.00% --- 3.01 minutes ---
# Neurons: 100 Leak-rate: 0.6 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.353058811963
# Testing error
# 0.350164509677
# --- Progress: 54.00% --- 3.06 minutes ---
# Neurons: 100 Leak-rate: 0.6 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.350745369427
# Testing error
# 0.347084422125
# --- Progress: 55.00% --- 3.12 minutes ---
# Neurons: 100 Leak-rate: 0.6 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.349460825277
# Testing error
# 0.345581846787
# --- Progress: 56.00% --- 3.17 minutes ---
# Neurons: 100 Leak-rate: 0.6 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.351159361786
# Testing error
# 0.348280746559
# --- Progress: 57.00% --- 3.23 minutes ---
# Neurons: 100 Leak-rate: 0.6 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.351608638144
# Testing error
# 0.348091065012
# --- Progress: 58.00% --- 3.28 minutes ---
# Neurons: 100 Leak-rate: 0.6 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.34339402129
# Testing error
# 0.337952929965
# --- Progress: 59.00% --- 3.34 minutes ---
# Neurons: 100 Leak-rate: 0.6 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.338738270664
# Testing error
# 0.333391615775
# --- Progress: 60.00% --- 3.39 minutes ---
# Neurons: 100 Leak-rate: 0.7 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.368581070034
# Testing error
# 0.36739906136
# --- Progress: 61.00% --- 3.45 minutes ---
# Neurons: 100 Leak-rate: 0.7 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.364291696474
# Testing error
# 0.363076831698
# --- Progress: 62.00% --- 3.50 minutes ---
# Neurons: 100 Leak-rate: 0.7 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.362626173795
# Testing error
# 0.360754266056
# --- Progress: 63.00% --- 3.56 minutes ---
# Neurons: 100 Leak-rate: 0.7 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.357927871316
# Testing error
# 0.355588659047
# --- Progress: 64.00% --- 3.61 minutes ---
# Neurons: 100 Leak-rate: 0.7 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.356252670335
# Testing error
# 0.353603633923
# --- Progress: 65.00% --- 3.67 minutes ---
# Neurons: 100 Leak-rate: 0.7 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.35155571662
# Testing error
# 0.348547949808
# --- Progress: 66.00% --- 3.72 minutes ---
# Neurons: 100 Leak-rate: 0.7 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.352009760196
# Testing error
# 0.347966787666
# --- Progress: 67.00% --- 3.77 minutes ---
# Neurons: 100 Leak-rate: 0.7 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.351566075477
# Testing error
# 0.34729815905
# --- Progress: 68.00% --- 3.83 minutes ---
# Neurons: 100 Leak-rate: 0.7 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.349100576805
# Testing error
# 0.344053183191
# --- Progress: 69.00% --- 3.88 minutes ---
# Neurons: 100 Leak-rate: 0.7 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.350459934859
# Testing error
# 0.345638111576
# --- Progress: 70.00% --- 3.94 minutes ---
# Neurons: 100 Leak-rate: 0.8 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.371157111288
# Testing error
# 0.370536697154
# --- Progress: 71.00% --- 4.00 minutes ---
# Neurons: 100 Leak-rate: 0.8 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.367356232613
# Testing error
# 0.366958073405
# --- Progress: 72.00% --- 4.06 minutes ---
# Neurons: 100 Leak-rate: 0.8 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.365263046674
# Testing error
# 0.363632151535
# --- Progress: 73.00% --- 4.11 minutes ---
# Neurons: 100 Leak-rate: 0.8 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.361567828841
# Testing error
# 0.359919325786
# --- Progress: 74.00% --- 4.17 minutes ---
# Neurons: 100 Leak-rate: 0.8 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.361680504321
# Testing error
# 0.360770947492
# --- Progress: 75.00% --- 4.22 minutes ---
# Neurons: 100 Leak-rate: 0.8 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.36135664645
# Testing error
# 0.359821338235
# --- Progress: 76.00% --- 4.28 minutes ---
# Neurons: 100 Leak-rate: 0.8 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.355648344327
# Testing error
# 0.353092632675
# --- Progress: 77.00% --- 4.33 minutes ---
# Neurons: 100 Leak-rate: 0.8 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.356059795171
# Testing error
# 0.352311557563
# --- Progress: 78.00% --- 4.39 minutes ---
# Neurons: 100 Leak-rate: 0.8 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.355854873115
# Testing error
# 0.352339002989
# --- Progress: 79.00% --- 4.44 minutes ---
# Neurons: 100 Leak-rate: 0.8 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.355420744982
# Testing error
# 0.352701968327
# --- Progress: 80.00% --- 4.50 minutes ---
# Neurons: 100 Leak-rate: 0.9 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.373497461331
# Testing error
# 0.372974414527
# --- Progress: 81.00% --- 4.55 minutes ---
# Neurons: 100 Leak-rate: 0.9 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.370694718659
# Testing error
# 0.369788467581
# --- Progress: 82.00% --- 4.61 minutes ---
# Neurons: 100 Leak-rate: 0.9 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.368697289738
# Testing error
# 0.368027637698
# --- Progress: 83.00% --- 4.66 minutes ---
# Neurons: 100 Leak-rate: 0.9 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.365164361943
# Testing error
# 0.363487276663
# --- Progress: 84.00% --- 4.72 minutes ---
# Neurons: 100 Leak-rate: 0.9 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.364822686553
# Testing error
# 0.363657297322
# --- Progress: 85.00% --- 4.77 minutes ---
# Neurons: 100 Leak-rate: 0.9 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.36275976893
# Testing error
# 0.361454895963
# --- Progress: 86.00% --- 4.83 minutes ---
# Neurons: 100 Leak-rate: 0.9 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.358791208329
# Testing error
# 0.356652884335
# --- Progress: 87.00% --- 4.88 minutes ---
# Neurons: 100 Leak-rate: 0.9 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.357840041281
# Testing error
# 0.355771007691
# --- Progress: 88.00% --- 4.94 minutes ---
# Neurons: 100 Leak-rate: 0.9 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.357147151863
# Testing error
# 0.355230506941
# --- Progress: 89.00% --- 4.99 minutes ---
# Neurons: 100 Leak-rate: 0.9 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.356479729641
# Testing error
# 0.353665659478
# --- Progress: 90.00% --- 5.04 minutes ---
# Neurons: 100 Leak-rate: 1.0 Spectral-radius: 0.1
# harvesting states...
# fitting...
# training error:
# 0.375452209684
# Testing error
# 0.375218670935
# --- Progress: 91.00% --- 5.10 minutes ---
# Neurons: 100 Leak-rate: 1.0 Spectral-radius: 0.2
# harvesting states...
# fitting...
# training error:
# 0.373234208873
# Testing error
# 0.373151512235
# --- Progress: 92.00% --- 5.15 minutes ---
# Neurons: 100 Leak-rate: 1.0 Spectral-radius: 0.3
# harvesting states...
# fitting...
# training error:
# 0.371629066843
# Testing error
# 0.371198205021
# --- Progress: 93.00% --- 5.21 minutes ---
# Neurons: 100 Leak-rate: 1.0 Spectral-radius: 0.4
# harvesting states...
# fitting...
# training error:
# 0.36942661217
# Testing error
# 0.368392303928
# --- Progress: 94.00% --- 5.26 minutes ---
# Neurons: 100 Leak-rate: 1.0 Spectral-radius: 0.5
# harvesting states...
# fitting...
# training error:
# 0.367319409258
# Testing error
# 0.366581995276
# --- Progress: 95.00% --- 5.31 minutes ---
# Neurons: 100 Leak-rate: 1.0 Spectral-radius: 0.6
# harvesting states...
# fitting...
# training error:
# 0.364573450228
# Testing error
# 0.364100583255
# --- Progress: 96.00% --- 5.37 minutes ---
# Neurons: 100 Leak-rate: 1.0 Spectral-radius: 0.7
# harvesting states...
# fitting...
# training error:
# 0.362820666266
# Testing error
# 0.361483913861
# --- Progress: 97.00% --- 5.42 minutes ---
# Neurons: 100 Leak-rate: 1.0 Spectral-radius: 0.8
# harvesting states...
# fitting...
# training error:
# 0.360165057157
# Testing error
# 0.357997718328
# --- Progress: 98.00% --- 5.47 minutes ---
# Neurons: 100 Leak-rate: 1.0 Spectral-radius: 0.9
# harvesting states...
# fitting...
# training error:
# 0.358022904662
# Testing error
# 0.355592219344
# --- Progress: 99.00% --- 5.53 minutes ---
# Neurons: 100 Leak-rate: 1.0 Spectral-radius: 1.0
# harvesting states...
# fitting...
# training error:
# 0.35337321506
# Testing error
# 0.349744383272
# --- Progress: 100.00% --- 5.58 minutes ---
# Total time for Testbench:
# --- 334.90 seconds ---
# --- 5.58 minutes ---

# %%
import pickle
#### Save Data
with open('datasaveFastAverage.p', 'wb') as outputFile:
    pickle.dump(fast_errors_averaged_over_trials, outputFile)
    pickle.dump(n_neurons_fast, outputFile)
    pickle.dump(new_trials, outputFile)
    pickle.dump(l_rate_fast, outputFile)
    pickle.dump(sp_rad_fast, outputFile)
#### Load Data
# with open('datasaveFastAverage.p', 'rb') as inputFile:
#     fast_errors_averaged_over_trials = pickle.load(inputFile)
#      n_neurons_fast = pickle.load(inputFile)
#     new_trials = pickle.load(inputFile)
#     l_rate_fast = pickle.load(inputFile)
#     sp_rad_fast = pickle.load(inputFile)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# c= ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, len(all_errors_fast))]
c= ["blue", "orange", "green", "cyan", "yellow", "magenta", "red", "black"]
data = []


x = np.repeat(l_rate_fast,len(l_rate_fast))
y = np.tile(sp_rad_fast,len(sp_rad_fast))
z = fast_errors_averaged_over_trials

trace1 = go.Scatter3d(
    x=x,
    y=y,
    z=z,
    name=("Fast network averaged over",trials,"Trials"),
    mode='markers',
    marker=dict(
        size=7,
        color=z,                # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    )
)


data = [trace1]
layout = go.Layout(
#     margin=dict(
#         l=0,
#         r=0,
#         b=0,
#         t=0
#     ),
#     go.zaxis=dict(
#         range=[0, 0.8]
#     ),
    scene=go.Scene(
        xaxis=go.XAxis(title='x = Leak-Rate'),
        yaxis=go.YAxis(title='y = Spectral Radius'),
        zaxis=go.ZAxis(title='z = Error')
        )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Fast Network Averaged')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HansBambel/20.embed" height="525px" width="100%"></iframe>

# %%
data = [
     go.Contour(
        z=fast_errors_averaged_over_trials.reshape(10,10).T,
        x=l_rate_fast,
        y=sp_rad_fast,
        colorscale='Jet',
    )]
py.iplot(data)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~HansBambel/66.embed" height="525px" width="100%"></iframe>

# %%
from matplotlib import pyplot
# %matplotlib inline
pyplot.contourf(np.repeat(l_rate_fast,len(l_rate_fast)).reshape(10,10),
                np.tile(sp_rad_fast, len(sp_rad_fast)).reshape(10,10),fast_errors_averaged_over_trials.reshape(10,10))
pyplot.xlabel("Leak-rate")
pyplot.ylabel("Spectral-radius")
pyplot.colorbar()
