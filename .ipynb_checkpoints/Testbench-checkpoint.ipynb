# %%
import Parity_Data_Generator
import numpy as np
from pyESN import ESN
import time

N = 4000   # number of datapoints
n = 3       # n-parity
timescale = 50
rng = np.random.RandomState(42)

# %%
def runSomeConfigs(spectral_rad, leak_r, d_t, train_b, test_b, train_p, test_p, n_neurons):
#     print("Spectral-radius:",spectral_rad, "leak-rate:", leak_r)
    nParityESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=n_neurons,  # from 200 onwards test error decreases significantly
                          spectral_radius=spectral_rad,  # high spectral rad is better (high fluctuations 0->1->0)
                          leak_rate= leak_r,   # adjust leak_rate
                          delta_t= d_t,
                          sparsity=0.95,
                          noise=0.01,
                          input_shift=0,
                          input_scaling=3,  # 3 seems to be fine. Maybe use lower
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          random_state=rng,
                          silent=False)
    nParityESN.fit(train_b, train_p)
    pred_test = nParityESN.predict(test_b)

    predictedParity = pred_test 
    
    print("Testing error")
    test_error = np.sqrt(np.mean((predictedParity - test_p) ** 2))
    print(test_error)
    return test_error

# %%
def produceTrainingData(i):
    bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(i))

    # Divide in training and test data
    traintest_cutoff = int(np.ceil(0.7 * len(bits)))
    train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
    train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
#     train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
    return train_bits, test_bits, train_parity, test_parity

# %%
trials = 10
# n_neurons_slow = [200,300,400,500]
n_neurons_slow = [300]

delta_t = [0.1]

l_rate = np.linspace(0.1, 1, num=10)
# l_rate =[0.2]
# l_rate = [0.1,0.2,0.3]

# sp_rad = np.linspace(0.9, 1.0, num=5)
sp_rad = np.linspace(0.1, 1, num=10)
# sp_rad = [0.8]


run_time = time.time()
iterations, iterationcount = trials*len(n_neurons_slow)*len(sp_rad)*len(l_rate)*len(delta_t), 0

delta_t_error = []
for dt in delta_t:
    neurons_slow_error = []
    for current_slow_neurons in n_neurons_slow:
        all_errors = [{} for _ in range(trials)] # empty dict
        for trial in range(trials):
            errors = []
            # produce training and testing data
            train_bits, test_bits, train_parity, test_parity = produceTrainingData(iterationcount)
            for l in l_rate:
                for s in sp_rad:
                    print("Neurons:", current_slow_neurons,"Leak-rate:",l,"Spectral-radius:",s,"Delta_t:",dt)
                    errors.append(runSomeConfigs(s,l,dt, train_bits, test_bits, train_parity, test_parity, current_slow_neurons))
                    iterationcount = iterationcount + 1
                    print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
            ## Save leak-rate,spectral-radius and error in dictionary
            all_errors[trial] = errors

        ### Average errors
        errors_averaged_over_trials = np.zeros(100)
        for i in range(len(all_errors)):
            e = all_errors[i]
            errors_averaged_over_trials = np.add(errors_averaged_over_trials, np.array(e))
        errors_averaged_over_trials = np.divide(errors_averaged_over_trials, trials)

        neurons_slow_error.append(errors_averaged_over_trials)
    
    delta_t_error.append(neurons_slow_error)
            
print("Total time for Testbench:")
print("--- {:.2f} seconds ---".format(time.time() - run_time))
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.406920521606
# Testing error
# 0.410502982999
# --- Progress: 0.10% --- 0.26 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.361992145243
# Testing error
# 0.371205273344
# --- Progress: 0.20% --- 0.50 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.346306003571
# Testing error
# 0.365338812763
# --- Progress: 0.30% --- 0.75 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.323285627726
# Testing error
# 0.359762581885
# --- Progress: 0.40% --- 0.99 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.337697502747
# Testing error
# 0.381530946512
# --- Progress: 0.50% --- 1.24 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.351760452376
# Testing error
# 0.397983517972
# --- Progress: 0.60% --- 1.49 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.348469077543
# Testing error
# 0.373291979876
# --- Progress: 0.70% --- 1.73 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.385480165189
# Testing error
# 0.426310738684
# --- Progress: 0.80% --- 1.97 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.39300345742
# Testing error
# 0.434137049946
# --- Progress: 0.90% --- 2.22 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.408754142519
# Testing error
# 0.469117213068
# --- Progress: 1.00% --- 2.46 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.359763004055
# Testing error
# 0.358824826368
# --- Progress: 1.10% --- 2.71 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.287847167276
# Testing error
# 0.287921681962
# --- Progress: 1.20% --- 2.95 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.264572988322
# Testing error
# 0.269151519581
# --- Progress: 1.30% --- 3.19 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.253329743
# Testing error
# 0.260718157566
# --- Progress: 1.40% --- 3.43 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.239605083103
# Testing error
# 0.254975435466
# --- Progress: 1.50% --- 3.67 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.244119833592
# Testing error
# 0.291235652235
# --- Progress: 1.60% --- 3.92 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.25655087383
# Testing error
# 0.313481856137
# --- Progress: 1.70% --- 4.16 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.261759447589
# Testing error
# 0.306447307023
# --- Progress: 1.80% --- 4.40 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.277139625556
# Testing error
# 0.329688801545
# --- Progress: 1.90% --- 4.64 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.300370965096
# Testing error
# 0.341786339033
# --- Progress: 2.00% --- 4.89 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.378573410418
# Testing error
# 0.37657883728
# --- Progress: 2.10% --- 5.13 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.333666672269
# Testing error
# 0.335740461695
# --- Progress: 2.20% --- 5.37 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.294715185275
# Testing error
# 0.296457230427
# --- Progress: 2.30% --- 5.61 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.251919872239
# Testing error
# 0.255723070013
# --- Progress: 2.40% --- 5.85 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.248895204648
# Testing error
# 0.274004220293
# --- Progress: 2.50% --- 6.09 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.239091096977
# Testing error
# 0.265870835707
# --- Progress: 2.60% --- 6.34 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.239471019583
# Testing error
# 0.285159243443
# --- Progress: 2.70% --- 6.59 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227939363414
# Testing error
# 0.264352643702
# --- Progress: 2.80% --- 6.84 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.245054920206
# Testing error
# 0.268299916058
# --- Progress: 2.90% --- 7.08 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.238694321513
# Testing error
# 0.288036179852
# --- Progress: 3.00% --- 7.32 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.4527023057
# Testing error
# 0.458375762256
# --- Progress: 3.10% --- 7.58 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.381362920481
# Testing error
# 0.380916546021
# --- Progress: 3.20% --- 7.82 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.331303149433
# Testing error
# 0.332807660179
# --- Progress: 3.30% --- 8.06 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.281675848587
# Testing error
# 0.282269526128
# --- Progress: 3.40% --- 8.31 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.24294362317
# Testing error
# 0.245718469067
# --- Progress: 3.50% --- 8.54 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.224709760112
# Testing error
# 0.229646882368
# --- Progress: 3.60% --- 8.79 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.244801607947
# Testing error
# 0.254153352256
# --- Progress: 3.70% --- 9.03 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216291145731
# Testing error
# 0.278435627719
# --- Progress: 3.80% --- 9.27 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216594556652
# Testing error
# 0.305247518806
# --- Progress: 3.90% --- 9.51 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.23132806914
# Testing error
# 0.255725587145
# --- Progress: 4.00% --- 9.75 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.489382259463
# Testing error
# 0.496383855656
# --- Progress: 4.10% --- 9.98 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.439043716611
# Testing error
# 0.44731395082
# --- Progress: 4.20% --- 10.22 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.382732661169
# Testing error
# 0.3823385724
# --- Progress: 4.30% --- 10.46 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.346000465493
# Testing error
# 0.347608121763
# --- Progress: 4.40% --- 10.70 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.318065796763
# Testing error
# 0.319298914082
# --- Progress: 4.50% --- 10.94 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.2799179295
# Testing error
# 0.281522320698
# --- Progress: 4.60% --- 11.18 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.266213343334
# Testing error
# 0.269996823149
# --- Progress: 4.70% --- 11.42 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.23051865524
# Testing error
# 0.23437767649
# --- Progress: 4.80% --- 11.66 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201065540233
# Testing error
# 0.209019685335
# --- Progress: 4.90% --- 11.90 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.203163612906
# Testing error
# 0.260489941764
# --- Progress: 5.00% --- 12.14 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499152838182
# Testing error
# 0.505589500022
# --- Progress: 5.10% --- 12.38 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.486629365779
# Testing error
# 0.492855745757
# --- Progress: 5.20% --- 12.62 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.452749076634
# Testing error
# 0.460702691592
# --- Progress: 5.30% --- 12.86 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.404780902417
# Testing error
# 0.40458974581
# --- Progress: 5.40% --- 13.10 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.361256866552
# Testing error
# 0.363335617276
# --- Progress: 5.50% --- 13.34 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.314216802417
# Testing error
# 0.316748560035
# --- Progress: 5.60% --- 13.57 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.310918851668
# Testing error
# 0.313407211327
# --- Progress: 5.70% --- 13.81 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226942653669
# Testing error
# 0.231298603281
# --- Progress: 5.80% --- 14.05 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.253965427072
# Testing error
# 0.259349431116
# --- Progress: 5.90% --- 14.29 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.251740601921
# Testing error
# 0.268818388314
# --- Progress: 6.00% --- 14.54 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.50016387491
# Testing error
# 0.506439741211
# --- Progress: 6.10% --- 14.77 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.498417853899
# Testing error
# 0.504606557135
# --- Progress: 6.20% --- 15.01 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.487138300638
# Testing error
# 0.49406065629
# --- Progress: 6.30% --- 15.25 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.463279479217
# Testing error
# 0.470088350769
# --- Progress: 6.40% --- 15.50 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.412028112539
# Testing error
# 0.414444941181
# --- Progress: 6.50% --- 15.75 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.383468873771
# Testing error
# 0.384616453761
# --- Progress: 6.60% --- 16.01 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.344925672048
# Testing error
# 0.347278675625
# --- Progress: 6.70% --- 16.26 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.328350779907
# Testing error
# 0.331124167497
# --- Progress: 6.80% --- 16.51 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.290548173859
# Testing error
# 0.296492056043
# --- Progress: 6.90% --- 16.76 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.266360566744
# Testing error
# 0.276236002526
# --- Progress: 7.00% --- 17.02 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500439281923
# Testing error
# 0.506395063462
# --- Progress: 7.10% --- 17.26 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500073499737
# Testing error
# 0.505993532786
# --- Progress: 7.20% --- 17.51 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.498367365694
# Testing error
# 0.504553876537
# --- Progress: 7.30% --- 17.76 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.488351624818
# Testing error
# 0.494415755163
# --- Progress: 7.40% --- 18.01 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.45837820683
# Testing error
# 0.462586899939
# --- Progress: 7.50% --- 18.26 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.453812145896
# Testing error
# 0.457688154271
# --- Progress: 7.60% --- 18.51 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.3883335711
# Testing error
# 0.38820394779
# --- Progress: 7.70% --- 18.76 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.352024374529
# Testing error
# 0.354387285889
# --- Progress: 7.80% --- 19.02 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.3398157112
# Testing error
# 0.343328176254
# --- Progress: 7.90% --- 19.26 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.333200696315
# Testing error
# 0.335964236985
# --- Progress: 8.00% --- 19.51 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500629090882
# Testing error
# 0.506998011275
# --- Progress: 8.10% --- 19.76 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.50033767931
# Testing error
# 0.506645508095
# --- Progress: 8.20% --- 20.01 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500079301961
# Testing error
# 0.506319534469
# --- Progress: 8.30% --- 20.26 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.49879385799
# Testing error
# 0.504932047027
# --- Progress: 8.40% --- 20.50 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.490581861259
# Testing error
# 0.497222308149
# --- Progress: 8.50% --- 20.75 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.473817500086
# Testing error
# 0.479179028907
# --- Progress: 8.60% --- 21.00 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.442647790241
# Testing error
# 0.44392180306
# --- Progress: 8.70% --- 21.25 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.421420546927
# Testing error
# 0.422763651588
# --- Progress: 8.80% --- 21.49 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.383807458178
# Testing error
# 0.385940710487
# --- Progress: 8.90% --- 21.74 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.360832817036
# Testing error
# 0.362748034269
# --- Progress: 9.00% --- 21.99 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.50113368949
# Testing error
# 0.507241087257
# --- Progress: 9.10% --- 22.24 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500620580346
# Testing error
# 0.506846398472
# --- Progress: 9.20% --- 22.49 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500311064705
# Testing error
# 0.50642285936
# --- Progress: 9.30% --- 22.75 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500003735707
# Testing error
# 0.50652224296
# --- Progress: 9.40% --- 23.00 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499137923484
# Testing error
# 0.505512804396
# --- Progress: 9.50% --- 23.25 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.493447468908
# Testing error
# 0.499980217242
# --- Progress: 9.60% --- 23.50 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.479895691196
# Testing error
# 0.48578436586
# --- Progress: 9.70% --- 23.74 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.445171107654
# Testing error
# 0.446417879028
# --- Progress: 9.80% --- 23.99 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.40146285316
# Testing error
# 0.398948458541
# --- Progress: 9.90% --- 24.24 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.392659431201
# Testing error
# 0.393331196504
# --- Progress: 10.00% --- 24.49 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.381450082332
# Testing error
# 0.380019354994
# --- Progress: 10.10% --- 24.75 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.341332857197
# Testing error
# 0.342193428129
# --- Progress: 10.20% --- 25.01 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.322234893885
# Testing error
# 0.324871421404
# --- Progress: 10.30% --- 25.26 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.352483291573
# Testing error
# 0.356418671136
# --- Progress: 10.40% --- 25.52 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.342780509579
# Testing error
# 0.343614740656
# --- Progress: 10.50% --- 25.77 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.34062494233
# Testing error
# 0.34777609538
# --- Progress: 10.60% --- 26.03 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.364705204561
# Testing error
# 0.374440812589
# --- Progress: 10.70% --- 26.30 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.360516460688
# Testing error
# 0.376971167932
# --- Progress: 10.80% --- 26.56 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.380894723474
# Testing error
# 0.395173368289
# --- Progress: 10.90% --- 26.82 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.394125903492
# Testing error
# 0.41667798688
# --- Progress: 11.00% --- 27.08 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.35133317675
# Testing error
# 0.351188696943
# --- Progress: 11.10% --- 27.33 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.320503909657
# Testing error
# 0.320382963318
# --- Progress: 11.20% --- 27.59 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.25624074454
# Testing error
# 0.255561876721
# --- Progress: 11.30% --- 27.84 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.242339248123
# Testing error
# 0.240389248462
# --- Progress: 11.40% --- 28.09 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.251624171912
# Testing error
# 0.252598600225
# --- Progress: 11.50% --- 28.35 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.239860309515
# Testing error
# 0.239566983814
# --- Progress: 11.60% --- 28.61 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.276069623129
# Testing error
# 0.285280087901
# --- Progress: 11.70% --- 28.87 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.270615904841
# Testing error
# 0.278364174534
# --- Progress: 11.80% --- 29.13 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.263464576339
# Testing error
# 0.271261727098
# --- Progress: 11.90% --- 29.39 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.30287006377
# Testing error
# 0.305249390687
# --- Progress: 12.00% --- 29.64 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.372944158234
# Testing error
# 0.374106902585
# --- Progress: 12.10% --- 29.90 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.325166340901
# Testing error
# 0.325840686662
# --- Progress: 12.20% --- 30.15 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.274327830583
# Testing error
# 0.27303929607
# --- Progress: 12.30% --- 30.40 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.258241430783
# Testing error
# 0.255248866452
# --- Progress: 12.40% --- 30.66 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.236013815872
# Testing error
# 0.232383684233
# --- Progress: 12.50% --- 30.91 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211465498443
# Testing error
# 0.208934458538
# --- Progress: 12.60% --- 31.17 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.234417240177
# Testing error
# 0.231055155386
# --- Progress: 12.70% --- 31.43 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.2512473933
# Testing error
# 0.256543191232
# --- Progress: 12.80% --- 31.68 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.251660622406
# Testing error
# 0.251523839072
# --- Progress: 12.90% --- 31.94 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.256997457884
# Testing error
# 0.266804668087
# --- Progress: 13.00% --- 32.19 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.446767162141
# Testing error
# 0.45006675286
# --- Progress: 13.10% --- 32.44 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.378527575922
# Testing error
# 0.382030745148
# --- Progress: 13.20% --- 32.69 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.339920315682
# Testing error
# 0.340132166898
# --- Progress: 13.30% --- 32.94 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.29009923788
# Testing error
# 0.288257294199
# --- Progress: 13.40% --- 33.19 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.271257495158
# Testing error
# 0.270196047024
# --- Progress: 13.50% --- 33.45 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.242884181408
# Testing error
# 0.239370404374
# --- Progress: 13.60% --- 33.71 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216112767607
# Testing error
# 0.213481624392
# --- Progress: 13.70% --- 33.96 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.23340529295
# Testing error
# 0.239990539014
# --- Progress: 13.80% --- 34.22 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.231191108165
# Testing error
# 0.240766944078
# --- Progress: 13.90% --- 34.47 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.27145699977
# Testing error
# 0.279990997192
# --- Progress: 14.00% --- 34.72 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.490489863559
# Testing error
# 0.494900982968
# --- Progress: 14.10% --- 34.98 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.440492106662
# Testing error
# 0.443349751479
# --- Progress: 14.20% --- 35.24 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.374188267452
# Testing error
# 0.377355791677
# --- Progress: 14.30% --- 35.49 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.33518785651
# Testing error
# 0.338144995926
# --- Progress: 14.40% --- 35.73 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.326960874468
# Testing error
# 0.331085926015
# --- Progress: 14.50% --- 35.99 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.284412951917
# Testing error
# 0.284787887676
# --- Progress: 14.60% --- 36.23 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.243577746556
# Testing error
# 0.238127247163
# --- Progress: 14.70% --- 36.48 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221679272687
# Testing error
# 0.216984689375
# --- Progress: 14.80% --- 36.74 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205695959954
# Testing error
# 0.203347350101
# --- Progress: 14.90% --- 36.99 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.225120860163
# Testing error
# 0.230544305298
# --- Progress: 15.00% --- 37.25 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.501322866002
# Testing error
# 0.504005564326
# --- Progress: 15.10% --- 37.50 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.488747640569
# Testing error
# 0.492458219674
# --- Progress: 15.20% --- 37.75 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.451031314109
# Testing error
# 0.455433738613
# --- Progress: 15.30% --- 38.00 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.406939294811
# Testing error
# 0.412035010231
# --- Progress: 15.40% --- 38.25 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.361524059959
# Testing error
# 0.367417262432
# --- Progress: 15.50% --- 38.50 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.322355763487
# Testing error
# 0.325038012401
# --- Progress: 15.60% --- 38.75 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.29805725292
# Testing error
# 0.298520228452
# --- Progress: 15.70% --- 39.00 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.254574095376
# Testing error
# 0.25437684366
# --- Progress: 15.80% --- 39.25 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.272636143486
# Testing error
# 0.270300347263
# --- Progress: 15.90% --- 39.51 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.243539880742
# Testing error
# 0.242130491789
# --- Progress: 16.00% --- 39.76 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502627966042
# Testing error
# 0.504989508796
# --- Progress: 16.10% --- 40.01 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500369586846
# Testing error
# 0.503423809811
# --- Progress: 16.20% --- 40.26 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.484930889095
# Testing error
# 0.489453229708
# --- Progress: 16.30% --- 40.51 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.461449166829
# Testing error
# 0.46694521443
# --- Progress: 16.40% --- 40.76 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.405662953696
# Testing error
# 0.412342419432
# --- Progress: 16.50% --- 41.01 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.360830438317
# Testing error
# 0.368902610813
# --- Progress: 16.60% --- 41.26 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.346891947852
# Testing error
# 0.354746274203
# --- Progress: 16.70% --- 41.51 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.322202161107
# Testing error
# 0.327084657245
# --- Progress: 16.80% --- 41.76 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.272731772484
# Testing error
# 0.271455441629
# --- Progress: 16.90% --- 42.00 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.27093987815
# Testing error
# 0.270271477946
# --- Progress: 17.00% --- 42.25 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.503174062535
# Testing error
# 0.505473478744
# --- Progress: 17.10% --- 42.50 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502591660356
# Testing error
# 0.504995890971
# --- Progress: 17.20% --- 42.75 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500675239659
# Testing error
# 0.503274525402
# --- Progress: 17.30% --- 43.00 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.48976780042
# Testing error
# 0.493598916929
# --- Progress: 17.40% --- 43.25 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.479564717751
# Testing error
# 0.48603798842
# --- Progress: 17.50% --- 43.50 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.423502323751
# Testing error
# 0.428617665288
# --- Progress: 17.60% --- 43.76 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.385054069424
# Testing error
# 0.392465824685
# --- Progress: 17.70% --- 44.01 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.36517533117
# Testing error
# 0.375705592138
# --- Progress: 17.80% --- 44.26 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.345286839715
# Testing error
# 0.351969659372
# --- Progress: 17.90% --- 44.51 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.30341210578
# Testing error
# 0.308062513001
# --- Progress: 18.00% --- 44.76 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.503379572875
# Testing error
# 0.505875633408
# --- Progress: 18.10% --- 45.01 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.503021584139
# Testing error
# 0.505317994705
# --- Progress: 18.20% --- 45.26 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502639179063
# Testing error
# 0.505333756988
# --- Progress: 18.30% --- 45.51 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499312016727
# Testing error
# 0.503090218091
# --- Progress: 18.40% --- 45.76 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.491938503181
# Testing error
# 0.496851635844
# --- Progress: 18.50% --- 46.00 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.468237453919
# Testing error
# 0.473433849223
# --- Progress: 18.60% --- 46.25 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.421962595021
# Testing error
# 0.427412279976
# --- Progress: 18.70% --- 46.50 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.413474221796
# Testing error
# 0.421694112062
# --- Progress: 18.80% --- 46.75 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.373657459971
# Testing error
# 0.383199736743
# --- Progress: 18.90% --- 47.00 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.319289182192
# Testing error
# 0.322469746044
# --- Progress: 19.00% --- 47.25 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.503857261135
# Testing error
# 0.506150822704
# --- Progress: 19.10% --- 47.49 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.503419136674
# Testing error
# 0.505630458118
# --- Progress: 19.20% --- 47.74 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502866189023
# Testing error
# 0.505610808172
# --- Progress: 19.30% --- 47.98 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502388038943
# Testing error
# 0.504896891699
# --- Progress: 19.40% --- 48.23 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.501073809182
# Testing error
# 0.504394783615
# --- Progress: 19.50% --- 48.48 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.494421667503
# Testing error
# 0.499104828374
# --- Progress: 19.60% --- 48.73 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.482292509769
# Testing error
# 0.489226103685
# --- Progress: 19.70% --- 48.98 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.444578236519
# Testing error
# 0.451667193892
# --- Progress: 19.80% --- 49.23 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.390235813505
# Testing error
# 0.395182629947
# --- Progress: 19.90% --- 49.47 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.35832612743
# Testing error
# 0.365393738846
# --- Progress: 20.00% --- 49.72 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.390900184452
# Testing error
# 0.408169230484
# --- Progress: 20.10% --- 49.98 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.354341478216
# Testing error
# 0.399474665601
# --- Progress: 20.20% --- 50.24 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.349744249434
# Testing error
# 0.837755613316
# --- Progress: 20.30% --- 50.49 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.342751424022
# Testing error
# 0.402464455607
# --- Progress: 20.40% --- 50.75 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.336667994143
# Testing error
# 0.401057451508
# --- Progress: 20.50% --- 51.01 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.352323092748
# Testing error
# 0.53911492078
# --- Progress: 20.60% --- 51.26 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.351968072634
# Testing error
# 0.441573215249
# --- Progress: 20.70% --- 51.51 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.369282112279
# Testing error
# 0.474301810974
# --- Progress: 20.80% --- 51.77 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.399694086521
# Testing error
# 0.4686201747
# --- Progress: 20.90% --- 52.03 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.396079458693
# Testing error
# 0.474184735432
# --- Progress: 21.00% --- 52.28 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.350964450725
# Testing error
# 0.356118337917
# --- Progress: 21.10% --- 52.53 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.293774953822
# Testing error
# 0.297372852526
# --- Progress: 21.20% --- 52.79 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.266801358878
# Testing error
# 0.289922731082
# --- Progress: 21.30% --- 53.04 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.261219448054
# Testing error
# 0.310973868395
# --- Progress: 21.40% --- 53.30 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.252768592661
# Testing error
# 0.378543399749
# --- Progress: 21.50% --- 53.55 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.242486980787
# Testing error
# 0.304640429787
# --- Progress: 21.60% --- 53.81 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.259127045477
# Testing error
# 0.449881861176
# --- Progress: 21.70% --- 54.07 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.241736660119
# Testing error
# 0.319487305277
# --- Progress: 21.80% --- 54.32 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.239809278082
# Testing error
# 0.296692002146
# --- Progress: 21.90% --- 54.58 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.337141590518
# Testing error
# 0.373924330329
# --- Progress: 22.00% --- 54.84 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.390949539448
# Testing error
# 0.394896002192
# --- Progress: 22.10% --- 55.09 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.334996892871
# Testing error
# 0.337173126069
# --- Progress: 22.20% --- 55.34 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.284358660793
# Testing error
# 0.285714225774
# --- Progress: 22.30% --- 55.59 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.243413064777
# Testing error
# 0.255304554626
# --- Progress: 22.40% --- 55.85 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.236314333059
# Testing error
# 0.265029097659
# --- Progress: 22.50% --- 56.10 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.25966801143
# Testing error
# 0.411055668984
# --- Progress: 22.60% --- 56.36 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212683155111
# Testing error
# 0.252624174818
# --- Progress: 22.70% --- 56.61 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.222964701431
# Testing error
# 0.420853360672
# --- Progress: 22.80% --- 56.87 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.252709702441
# Testing error
# 0.295752246026
# --- Progress: 22.90% --- 57.12 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.290016484123
# Testing error
# 0.31638334719
# --- Progress: 23.00% --- 57.38 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.452928118654
# Testing error
# 0.455358566432
# --- Progress: 23.10% --- 57.63 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.372017991135
# Testing error
# 0.373993069029
# --- Progress: 23.20% --- 57.88 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.333922411673
# Testing error
# 0.335789778372
# --- Progress: 23.30% --- 58.13 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.301800394234
# Testing error
# 0.302588978583
# --- Progress: 23.40% --- 58.38 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.278522604744
# Testing error
# 0.281708669714
# --- Progress: 23.50% --- 58.63 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.233752357821
# Testing error
# 0.246365254884
# --- Progress: 23.60% --- 58.89 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212508108778
# Testing error
# 0.287796236677
# --- Progress: 23.70% --- 59.14 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.200106129656
# Testing error
# 0.244651694235
# --- Progress: 23.80% --- 59.39 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226960337103
# Testing error
# 0.755569514934
# --- Progress: 23.90% --- 59.65 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.23382751432
# Testing error
# 0.266207039593
# --- Progress: 24.00% --- 59.90 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.488086046497
# Testing error
# 0.489312291822
# --- Progress: 24.10% --- 60.15 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.441433508047
# Testing error
# 0.443133823609
# --- Progress: 24.20% --- 60.40 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.37032012838
# Testing error
# 0.372438373084
# --- Progress: 24.30% --- 60.65 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.328991391623
# Testing error
# 0.331008990365
# --- Progress: 24.40% --- 60.91 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.315826982054
# ...
# training error:
# 0.32171813173
# Testing error
# 0.37045277072
# --- Progress: 92.00% --- 227.36 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.395499473488
# Testing error
# 0.396341842971
# --- Progress: 92.10% --- 227.60 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.333477474281
# Testing error
# 0.332834091685
# --- Progress: 92.20% --- 227.84 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.289441289684
# Testing error
# 0.287386723041
# --- Progress: 92.30% --- 228.09 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.246094483964
# Testing error
# 0.308411804106
# --- Progress: 92.40% --- 228.33 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.235499796468
# Testing error
# 0.40129447168
# --- Progress: 92.50% --- 228.57 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218225603437
# Testing error
# 0.300904011364
# --- Progress: 92.60% --- 228.81 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.197599631064
# Testing error
# 0.404972422772
# --- Progress: 92.70% --- 229.05 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226331205445
# Testing error
# 0.361868794604
# --- Progress: 92.80% --- 229.30 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.233945451207
# Testing error
# 0.273555178825
# --- Progress: 92.90% --- 229.54 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.289635495474
# Testing error
# 0.344284974
# --- Progress: 93.00% --- 229.78 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.448703873376
# Testing error
# 0.451487809885
# --- Progress: 93.10% --- 230.02 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.379625874114
# Testing error
# 0.382570362936
# --- Progress: 93.20% --- 230.26 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.333627556522
# Testing error
# 0.331753153589
# --- Progress: 93.30% --- 230.50 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.290309527868
# Testing error
# 0.288028142192
# --- Progress: 93.40% --- 230.74 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.24682243648
# Testing error
# 0.310100101312
# --- Progress: 93.50% --- 230.98 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.241246486474
# Testing error
# 0.338253265906
# --- Progress: 93.60% --- 231.23 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.220011030617
# Testing error
# 0.276162390763
# --- Progress: 93.70% --- 231.47 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.197447810503
# Testing error
# 0.446733567584
# --- Progress: 93.80% --- 231.71 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218112531843
# Testing error
# 0.302499742673
# --- Progress: 93.90% --- 231.95 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201140245543
# Testing error
# 0.565052112328
# --- Progress: 94.00% --- 232.19 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.487638385204
# Testing error
# 0.48938125898
# --- Progress: 94.10% --- 232.43 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.440286256888
# Testing error
# 0.44379018752
# --- Progress: 94.20% --- 232.67 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.389529003088
# Testing error
# 0.393138882448
# --- Progress: 94.30% --- 232.91 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.354704805519
# Testing error
# 0.356102069446
# --- Progress: 94.40% --- 233.15 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.336305733
# Testing error
# 0.337517454597
# --- Progress: 94.50% --- 233.38 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.300553888238
# Testing error
# 0.53333467418
# --- Progress: 94.60% --- 233.62 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.238957124749
# Testing error
# 0.298899276319
# --- Progress: 94.70% --- 233.86 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.213223680799
# Testing error
# 0.249833236617
# --- Progress: 94.80% --- 234.10 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.229767626595
# Testing error
# 0.427083736706
# --- Progress: 94.90% --- 234.34 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.182035972268
# Testing error
# 0.320813481877
# --- Progress: 95.00% --- 234.58 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500730440639
# Testing error
# 0.503188630386
# --- Progress: 95.10% --- 234.81 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.486496685891
# Testing error
# 0.489007966505
# --- Progress: 95.20% --- 235.05 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.449073299715
# Testing error
# 0.451840541797
# --- Progress: 95.30% --- 235.30 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.394315286191
# Testing error
# 0.399112138012
# --- Progress: 95.40% --- 235.54 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.366422586617
# Testing error
# 0.369999804171
# --- Progress: 95.50% --- 235.78 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.334857948549
# Testing error
# 0.344852929477
# --- Progress: 95.60% --- 236.01 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.309927998703
# Testing error
# 0.352943988633
# --- Progress: 95.70% --- 236.25 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.260994044347
# Testing error
# 0.272805289849
# --- Progress: 95.80% --- 236.49 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227931536172
# Testing error
# 0.259556836233
# --- Progress: 95.90% --- 236.73 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.249644801081
# Testing error
# 0.377203229539
# --- Progress: 96.00% --- 236.97 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.501918022831
# Testing error
# 0.504215343185
# --- Progress: 96.10% --- 237.20 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499367122502
# Testing error
# 0.50191478964
# --- Progress: 96.20% --- 237.44 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.484810998187
# Testing error
# 0.48793662726
# --- Progress: 96.30% --- 237.67 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.458444645254
# Testing error
# 0.461008642036
# --- Progress: 96.40% --- 237.91 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.41630606989
# Testing error
# 0.420369304992
# --- Progress: 96.50% --- 238.15 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.382842920231
# Testing error
# 0.385296329701
# --- Progress: 96.60% --- 238.39 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.336772461605
# Testing error
# 0.343051984402
# --- Progress: 96.70% --- 238.63 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.315980738297
# Testing error
# 0.432921558483
# --- Progress: 96.80% --- 238.87 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.258997746339
# Testing error
# 0.301263551718
# --- Progress: 96.90% --- 239.11 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.2753728048
# Testing error
# 0.409805541684
# --- Progress: 97.00% --- 239.35 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502349192024
# Testing error
# 0.504232771476
# --- Progress: 97.10% --- 239.58 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.501717810485
# Testing error
# 0.504054725205
# --- Progress: 97.20% --- 239.82 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499073899076
# Testing error
# 0.502037197088
# --- Progress: 97.30% --- 240.06 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.489578631923
# Testing error
# 0.49320812309
# --- Progress: 97.40% --- 240.29 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.465553976819
# Testing error
# 0.469591580353
# --- Progress: 97.50% --- 240.53 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.404036104387
# Testing error
# 0.407717217002
# --- Progress: 97.60% --- 240.76 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.393099345813
# Testing error
# 0.396242959676
# --- Progress: 97.70% --- 241.00 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.354214666676
# Testing error
# 0.366817114738
# --- Progress: 97.80% --- 241.24 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.284334089566
# Testing error
# 0.346647461012
# --- Progress: 97.90% --- 241.47 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.316473589928
# Testing error
# 0.458047049567
# --- Progress: 98.00% --- 241.71 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502855601639
# Testing error
# 0.504278160168
# --- Progress: 98.10% --- 241.94 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502178516132
# Testing error
# 0.504300568706
# --- Progress: 98.20% --- 242.18 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.501896870519
# Testing error
# 0.503962932268
# --- Progress: 98.30% --- 242.42 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.499321567198
# Testing error
# 0.501932256861
# --- Progress: 98.40% --- 242.65 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.491404660568
# Testing error
# 0.495165330452
# --- Progress: 98.50% --- 242.89 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.472760791314
# Testing error
# 0.476152859612
# --- Progress: 98.60% --- 243.12 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.417716369512
# Testing error
# 0.42241373674
# --- Progress: 98.70% --- 243.36 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.406451993788
# Testing error
# 0.410026640285
# --- Progress: 98.80% --- 243.59 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.380046713037
# Testing error
# 0.380460364788
# --- Progress: 98.90% --- 243.83 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.345905101413
# Testing error
# 0.360731758398
# --- Progress: 99.00% --- 244.07 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.503398559979
# Testing error
# 0.504670655704
# --- Progress: 99.10% --- 244.30 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502731819286
# Testing error
# 0.504234182017
# --- Progress: 99.20% --- 244.54 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.502217956691
# Testing error
# 0.504258560619
# --- Progress: 99.30% --- 244.78 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.501639091527
# Testing error
# 0.504182139163
# --- Progress: 99.40% --- 245.02 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.500141879136
# Testing error
# 0.502591188243
# --- Progress: 99.50% --- 245.25 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.496308314698
# Testing error
# 0.49942634473
# --- Progress: 99.60% --- 245.48 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.481061994467
# Testing error
# 0.485820755857
# --- Progress: 99.70% --- 245.72 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.433016085616
# Testing error
# 0.440117725828
# --- Progress: 99.80% --- 245.96 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.412832864676
# Testing error
# 0.41527987827
# --- Progress: 99.90% --- 246.19 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.37103973365
# Testing error
# 0.374047220085
# --- Progress: 100.00% --- 246.43 minutes ---
# Total time for Testbench:
# --- 14785.82 seconds ---
# --- 246.43 minutes ---

# %%
import pickle
#### Save Data
# with open('dataTimescale50sameDelta_Taverage10.p', 'wb') as outputFile:
#     pickle.dump(delta_t_error, outputFile)
#     pickle.dump(neurons_slow_error, outputFile)
#     pickle.dump(n_neurons_slow, outputFile)
#     pickle.dump(delta_t, outputFile)
#     pickle.dump(trials, outputFile)
#     pickle.dump(l_rate, outputFile)
#     pickle.dump(sp_rad, outputFile)
#### Load Data
with open('dataTimescale50sameDelta_Taverage10.p', 'rb') as inputFile:
    delta_t_error = pickle.load(inputFile)
    neurons_slow_error = pickle.load(inputFile)
    n_neurons_slow = pickle.load(inputFile)
    delta_t = pickle.load(inputFile)
    trials = pickle.load(inputFile)
    l_rate = pickle.load(inputFile)
    sp_rad = pickle.load(inputFile)

# %% [markdown]
# import plotly.plotly as py
# import plotly.graph_objs as go
#
# # c= ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, len(all_errors))]
# # c= ["blue", "orange", "green", "cyan", "yellow", "magenta", "red", "black"]
#
# x = np.repeat(l_rate,len(l_rate))
# y = np.tile(sp_rad, len(sp_rad))
# z = neurons_slow_error[0]
# trace1 = go.Scatter3d(
#     x=x,
#     y=y,
#     z=z,
#     name=("Averaged over", trials ,"Trials"),
#     mode='markers',
#     marker=dict(
#         size=7,
#         color=z,                # set color to an array/list of desired values
#         colorscale='Viridis',   # choose a colorscale
#         opacity=0.8
#     )
# )
#
# data = [trace1]
# layout = go.Layout(
# #     margin=dict(
# #         l=0,
# #         r=0,
# #         b=0,
# #         t=0
# #     ),
# #     go.zaxis=dict(
# #         range=[0, 0.8]
# #     ),
#     scene=go.Scene(
#         xaxis=go.XAxis(title='x = Leak-Rate'),
#         yaxis=go.YAxis(title='y = Spectral Radius'),
#         zaxis=go.ZAxis(title='z = Error')
#         )
# )
# fig = go.Figure(data=data, layout=layout)
# py.iplot(fig, filename='SlowESN average Error')

# %% [markdown]
# data = [
#      go.Contour(
#         z=errors_averaged_over_trials.reshape(10,10).T,
#         x=l_rate,
#         y=sp_rad,
#         colorscale='Jet',
#     )]
# py.iplot(data)

# %%
### Different delta_t

from matplotlib import pyplot
# %matplotlib inline
print(delta_t)
xx, yy = np.meshgrid(l_rate, sp_rad)
pyplot.figure(figsize=(12,14))
for p in range(len(delta_t)):
    pyplot.subplot(3,2,p+1)
    pyplot.contourf(xx,
                    yy,delta_t_error[p][0].reshape(10,10).T)
    pyplot.title("slowESN error delta 0.1 averaged over 10 trials")
    pyplot.xlabel("Leak-rate")
    pyplot.ylabel("Spectral-radius")
    pyplot.colorbar()
# Out:
# [0.1]

# %% [markdown]
# ### Different Neuronsizes
#
# from matplotlib import pyplot
# %matplotlib inline
# print(n_neurons_slow)
# xx, yy = np.meshgrid(l_rate, sp_rad)
# pyplot.figure(figsize=(12,9))
# for p in range(len(n_neurons_slow)):
#     pyplot.subplot(2,2,p+1)
#     pyplot.contourf(xx,
#                     yy,neurons_slow_error[p].reshape(10,10).T)
#     pyplot.title((n_neurons_slow[p],"Neurons"))
#     pyplot.xlabel("Leak-rate")
#     pyplot.ylabel("Spectral-radius")
#     pyplot.colorbar()

# %%
#### Get Parameters from a good performing slowESN

nParityESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=300,  
                          spectral_radius=0.5, 
                          leak_rate= 0.3,   # adjust leak_rate
                          sparsity=0.95,     # 0.95
                          delta_t= 0.1,
                          noise=0.01,      # 0.001
                          input_shift=-0.5,    # 0
                          input_scaling=3,  
                          teacher_forcing=False,
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          random_state=rng,
                          silent=False)
train_bits, test_bits, train_parity, test_parity = produceTrainingData(42)
nParityESN.fit(train_bits, train_parity)
# Out:
# harvesting states...
# fitting...
# training error:
# 0.21701840348
# array([[ 0.60953945],
#        [ 0.62801773],
#        [ 0.69122885],
#        ...,
#        [ 1.04918959],
#        [ 1.01147671],
#        [ 1.10838328]])

# %%
##### Create Training Data for fastESN with output from slowESN
start_time = time.time()

new_rng = np.random.RandomState(1337)
new_N= 1500
# new_bits, new_parity, new_target = Parity_Data_Generator.generateParityData(new_N, new_n, 
#                                                                             timescale=timescale,randomstate=new_rng)

# # Divide in training and test data
# traintest_cutoff = int(np.ceil(0.7 * len(bits)))
# new_train_bits, new_test_bits = new_bits[:traintest_cutoff], new_bits[traintest_cutoff:]
# # new_train_parity, new_test_parity = new_parity[:traintest_cutoff], new_parity[traintest_cutoff:]
# new_train_targets, new_test_targets = new_target[:traintest_cutoff], new_target[traintest_cutoff:]

# train_predicted_parity = nParityESN.predict(new_train_bits)
# test_predicted_parity = nParityESN.predict(new_test_bits)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0 seconds ---

# %%
#### FastESN ####
def runSomeFastConfigs(spectral_rad, leak_r, d_t, train_parity, test_parity, 
                       train_targets, test_targets, num_neurons=100):
    outputESN = ESN(n_inputs=1,
                              n_outputs=1,
                              n_reservoir=num_neurons,  
                              spectral_radius=spectral_rad,  # high spectral rad is better (high fluctuations 0->1->0)
                              leak_rate= leak_r,   # adjust leak_rate
                              delta_t= d_t,
                              sparsity=0.95,
                              noise=0.01,
                              input_shift=0,
                              input_scaling=3,  # 3 seems to be fine. Maybe use lower
                              teacher_forcing=False,
                              teacher_scaling=1.12,
                              teacher_shift=-0.4,
                              random_state=new_rng,
                              silent=False)
        # print(np.shape(bits),np.shape(parity),np.shape(target))
    outputESN.fit(train_parity, train_targets)
    pred_test = outputESN.predict(test_parity)
        
    print("Testing error")
    test_error = np.sqrt(np.mean((pred_test - test_targets) ** 2))
    print(test_error)
    return test_error

def produceFastTrainingData(randomState):
    bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(randomState))

    # Divide in training and test data
    traintest_cutoff = int(np.ceil(0.7 * len(bits)))
    train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
    train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
    
    train_predicted_parity = nParityESN.predict(train_bits)
    test_predicted_parity = nParityESN.predict(test_bits)
    
    return train_predicted_parity, test_predicted_parity, train_targets, test_targets

# %%
new_trials = 10
n_neurons_fast = 50
# num_neurons_fast = [100]
delta_t_fast = [0.1]
l_rate_fast = np.linspace(0.1, 1, num=10)
sp_rad_fast = np.linspace(0.1, 1, num=10)

run_time = time.time()
iterations, iterationcount = new_trials*len(sp_rad_fast)*len(l_rate_fast)*len(delta_t_fast), 0

delta_t_errors_fast = []
for dt_fast in delta_t_fast:
    all_errors_fast = [{} for _ in range(new_trials)]
    for newtrial in range(new_trials):
        errors = []

        new_train_parity, new_test_parity, new_train_targets, new_test_targets = produceFastTrainingData(iterationcount)

        for l in l_rate_fast:
            for s in sp_rad_fast:
                print("Neurons:", n_neurons_fast, "Leak-rate:", l, "Spectral-radius:", s,"Delta_t:",dt_fast)
                errors.append(runSomeFastConfigs(s,l,dt_fast,new_train_parity, new_test_parity, new_train_targets, new_test_targets,n_neurons_fast))
                iterationcount = iterationcount + 1
                print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
        ## Save leak-rate,spectral-radius and error in dictionary
        all_errors_fast[newtrial] = errors

    ### Average errors
    fast_errors_averaged_over_trials = np.zeros(100)
    for i in range(len(all_errors_fast)):
        e = all_errors_fast[i]
        fast_errors_averaged_over_trials = np.add(fast_errors_averaged_over_trials, np.array(e))

    fast_errors_averaged_over_trials = np.divide(fast_errors_averaged_over_trials, new_trials)
    
    delta_t_errors_fast.append(fast_errors_averaged_over_trials)
            
print("Total time for Testbench:")
print("--- {:.2f} seconds ---".format(time.time() - run_time))
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.220255560438
# Testing error
# 0.22070122131
# --- Progress: 0.10% --- 0.27 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.220178194982
# Testing error
# 0.219625535115
# --- Progress: 0.20% --- 0.36 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219956573539
# Testing error
# 0.219171819831
# --- Progress: 0.30% --- 0.44 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217765625916
# Testing error
# 0.220526435794
# --- Progress: 0.40% --- 0.52 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.2172484183
# Testing error
# 0.219986237338
# --- Progress: 0.50% --- 0.59 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218847484142
# Testing error
# 0.221607628139
# --- Progress: 0.60% --- 0.67 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.21863885206
# Testing error
# 0.221670136571
# --- Progress: 0.70% --- 0.75 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218153224898
# Testing error
# 0.220774738697
# --- Progress: 0.80% --- 0.83 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.21764285918
# Testing error
# 0.219936812671
# --- Progress: 0.90% --- 0.90 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216758058116
# Testing error
# 0.21983030228
# --- Progress: 1.00% --- 0.98 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217973192612
# Testing error
# 0.216680951933
# --- Progress: 1.10% --- 1.06 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.21763698776
# Testing error
# 0.216106921029
# --- Progress: 1.20% --- 1.14 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217100332744
# Testing error
# 0.216098685619
# --- Progress: 1.30% --- 1.22 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.209911208009
# Testing error
# 0.212212126084
# --- Progress: 1.40% --- 1.29 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212925456506
# Testing error
# 0.213502051444
# --- Progress: 1.50% --- 1.37 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.2152523043
# Testing error
# 0.216265559166
# --- Progress: 1.60% --- 1.45 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.214182688246
# Testing error
# 0.218759790312
# --- Progress: 1.70% --- 1.53 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.214933953953
# Testing error
# 0.216479396701
# --- Progress: 1.80% --- 1.61 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216918010927
# Testing error
# 0.220307114844
# --- Progress: 1.90% --- 1.68 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212820191049
# Testing error
# 0.212434509017
# --- Progress: 2.00% --- 1.76 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.21799004596
# Testing error
# 0.217044254891
# --- Progress: 2.10% --- 1.84 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217062236363
# Testing error
# 0.215673599576
# --- Progress: 2.20% --- 1.92 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208482561518
# Testing error
# 0.208639117626
# --- Progress: 2.30% --- 2.00 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.209838904757
# Testing error
# 0.208985168496
# --- Progress: 2.40% --- 2.08 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.21120255072
# Testing error
# 0.211398717466
# --- Progress: 2.50% --- 2.17 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.210962233578
# Testing error
# 0.209502046156
# --- Progress: 2.60% --- 2.26 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.203197747411
# Testing error
# 0.204548464611
# --- Progress: 2.70% --- 2.35 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208197015558
# Testing error
# 0.208755319085
# --- Progress: 2.80% --- 2.43 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208634839801
# Testing error
# 0.208659281112
# --- Progress: 2.90% --- 2.51 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206931656117
# Testing error
# 0.208215540102
# --- Progress: 3.00% --- 2.59 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.22193127957
# Testing error
# 0.222093838123
# --- Progress: 3.10% --- 2.67 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.209346613679
# Testing error
# 0.208413910651
# --- Progress: 3.20% --- 2.75 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.200466662591
# Testing error
# 0.200868194704
# --- Progress: 3.30% --- 2.83 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.200844277728
# Testing error
# 0.200256214478
# --- Progress: 3.40% --- 2.91 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.199105518439
# Testing error
# 0.199817702163
# --- Progress: 3.50% --- 2.98 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.196639821235
# Testing error
# 0.19861198503
# --- Progress: 3.60% --- 3.06 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201132250549
# Testing error
# 0.200513705494
# --- Progress: 3.70% --- 3.14 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206890767481
# Testing error
# 0.207954701703
# --- Progress: 3.80% --- 3.22 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.20279958248
# Testing error
# 0.20278673328
# --- Progress: 3.90% --- 3.30 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.197822002889
# Testing error
# 0.199074988074
# --- Progress: 4.00% --- 3.38 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.222559503227
# Testing error
# 0.224936978024
# --- Progress: 4.10% --- 3.45 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.210113218584
# Testing error
# 0.21058322285
# --- Progress: 4.20% --- 3.53 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205097157611
# Testing error
# 0.205703441373
# --- Progress: 4.30% --- 3.61 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198103840586
# Testing error
# 0.198569624652
# --- Progress: 4.40% --- 3.69 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205515626056
# Testing error
# 0.204610116527
# --- Progress: 4.50% --- 3.77 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.202265441727
# Testing error
# 0.201263465365
# --- Progress: 4.60% --- 3.85 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.200137683964
# Testing error
# 0.199224980656
# --- Progress: 4.70% --- 3.93 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.199979271922
# Testing error
# 0.201645722072
# --- Progress: 4.80% --- 4.01 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.190750921034
# Testing error
# 0.191391107639
# --- Progress: 4.90% --- 4.09 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.203192144552
# Testing error
# 0.202774667475
# --- Progress: 5.00% --- 4.16 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.231501491058
# Testing error
# 0.235315569015
# --- Progress: 5.10% --- 4.24 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.2190383583
# Testing error
# 0.22056660487
# --- Progress: 5.20% --- 4.32 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207062834684
# Testing error
# 0.208010761157
# --- Progress: 5.30% --- 4.39 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198765323957
# Testing error
# 0.200589852547
# --- Progress: 5.40% --- 4.47 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206712756582
# Testing error
# 0.206826981116
# --- Progress: 5.50% --- 4.55 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.196150646437
# Testing error
# 0.196418206331
# --- Progress: 5.60% --- 4.63 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.196662356393
# Testing error
# 0.198394098171
# --- Progress: 5.70% --- 4.71 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.191110296736
# Testing error
# 0.191680816827
# --- Progress: 5.80% --- 4.78 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.186977500818
# Testing error
# 0.189434612265
# --- Progress: 5.90% --- 4.86 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201691307735
# Testing error
# 0.201812891298
# --- Progress: 6.00% --- 4.94 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.240127880273
# Testing error
# 0.244402888005
# --- Progress: 6.10% --- 5.02 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.222019835424
# Testing error
# 0.226003370498
# --- Progress: 6.20% --- 5.10 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217281755512
# Testing error
# 0.219122577238
# --- Progress: 6.30% --- 5.18 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206234784872
# Testing error
# 0.207696075941
# --- Progress: 6.40% --- 5.25 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.199758768733
# Testing error
# 0.202444863313
# --- Progress: 6.50% --- 5.33 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.188945184037
# Testing error
# 0.189142718138
# --- Progress: 6.60% --- 5.41 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.189429318084
# Testing error
# 0.189210732982
# --- Progress: 6.70% --- 5.48 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.181040597418
# Testing error
# 0.182371117406
# --- Progress: 6.80% --- 5.56 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.191447098444
# Testing error
# 0.191281889781
# --- Progress: 6.90% --- 5.64 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.190949805596
# Testing error
# 0.191956962385
# --- Progress: 7.00% --- 5.72 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.24018390736
# Testing error
# 0.245055192206
# --- Progress: 7.10% --- 5.80 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.229255327909
# Testing error
# 0.233505141711
# --- Progress: 7.20% --- 5.88 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.223001422237
# Testing error
# 0.22697299693
# --- Progress: 7.30% --- 5.96 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212922314069
# Testing error
# 0.214555250923
# --- Progress: 7.40% --- 6.04 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.193768130163
# Testing error
# 0.194532546192
# --- Progress: 7.50% --- 6.12 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.202305124437
# Testing error
# 0.202474401523
# --- Progress: 7.60% --- 6.20 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.192166848742
# Testing error
# 0.192376550444
# --- Progress: 7.70% --- 6.28 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.187098768844
# Testing error
# 0.186910087521
# --- Progress: 7.80% --- 6.36 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.186197889545
# Testing error
# 0.188583439425
# --- Progress: 7.90% --- 6.44 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.185205539049
# Testing error
# 0.184407224526
# --- Progress: 8.00% --- 6.51 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.248142245524
# Testing error
# 0.252645755275
# --- Progress: 8.10% --- 6.59 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.231287372288
# Testing error
# 0.235268933577
# --- Progress: 8.20% --- 6.67 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.231372401516
# Testing error
# 0.234371634781
# --- Progress: 8.30% --- 6.75 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212986691131
# Testing error
# 0.215132629613
# --- Progress: 8.40% --- 6.83 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.203837146576
# Testing error
# 0.204540247327
# --- Progress: 8.50% --- 6.91 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.200053886946
# Testing error
# 0.200464531641
# --- Progress: 8.60% --- 6.98 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.194769584555
# Testing error
# 0.19620147943
# --- Progress: 8.70% --- 7.06 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.190352671533
# Testing error
# 0.191062465936
# --- Progress: 8.80% --- 7.14 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.190578441109
# Testing error
# 0.19317209374
# --- Progress: 8.90% --- 7.22 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.185248550996
# Testing error
# 0.185922236184
# --- Progress: 9.00% --- 7.30 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.251725893525
# Testing error
# 0.256344531276
# --- Progress: 9.10% --- 7.37 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.234991279328
# Testing error
# 0.238884445428
# --- Progress: 9.20% --- 7.45 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.229475708984
# Testing error
# 0.23334509424
# --- Progress: 9.30% --- 7.53 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.229525570231
# Testing error
# 0.233307287886
# --- Progress: 9.40% --- 7.60 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.213574868666
# Testing error
# 0.215475523184
# --- Progress: 9.50% --- 7.68 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.213507535511
# Testing error
# 0.216774249783
# --- Progress: 9.60% --- 7.76 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.200169287516
# Testing error
# 0.201381197145
# --- Progress: 9.70% --- 7.84 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.195646471484
# Testing error
# 0.195455081999
# --- Progress: 9.80% --- 7.92 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198875436585
# Testing error
# 0.199866405731
# --- Progress: 9.90% --- 8.00 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.179766338951
# Testing error
# 0.180410011332
# --- Progress: 10.00% --- 8.07 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221290375043
# Testing error
# 0.214330889712
# --- Progress: 10.10% --- 8.33 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.222341883413
# Testing error
# 0.215364367426
# --- Progress: 10.20% --- 8.41 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219915120226
# Testing error
# 0.212580298984
# --- Progress: 10.30% --- 8.49 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.220325188221
# Testing error
# 0.212519605511
# --- Progress: 10.40% --- 8.57 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.220726460394
# Testing error
# 0.213168906447
# --- Progress: 10.50% --- 8.65 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.222316200797
# Testing error
# 0.214611925568
# --- Progress: 10.60% --- 8.73 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.220276132174
# Testing error
# 0.213646177263
# --- Progress: 10.70% --- 8.81 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221708753789
# Testing error
# 0.215864265655
# --- Progress: 10.80% --- 8.88 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221617449855
# Testing error
# 0.217650647929
# --- Progress: 10.90% --- 8.96 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221465434268
# Testing error
# 0.214955973228
# --- Progress: 11.00% --- 9.04 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218292036569
# Testing error
# 0.210720009467
# --- Progress: 11.10% --- 9.12 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219405099911
# Testing error
# 0.21089918889
# --- Progress: 11.20% --- 9.19 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217471902014
# Testing error
# 0.209746816901
# --- Progress: 11.30% --- 9.27 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.21631015092
# Testing error
# 0.2083536093
# --- Progress: 11.40% --- 9.35 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216329801351
# Testing error
# 0.209119252536
# --- Progress: 11.50% --- 9.43 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.215772464654
# Testing error
# 0.208141938585
# --- Progress: 11.60% --- 9.50 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216244642187
# Testing error
# 0.208268945305
# --- Progress: 11.70% --- 9.58 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217215396534
# Testing error
# 0.208586421665
# --- Progress: 11.80% --- 9.66 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218149581195
# Testing error
# 0.20972025054
# --- Progress: 11.90% --- 9.74 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216696807288
# Testing error
# 0.210056189451
# --- Progress: 12.00% --- 9.81 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219861332786
# Testing error
# 0.209721758364
# --- Progress: 12.10% --- 9.89 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.213042202122
# Testing error
# 0.204906549075
# --- Progress: 12.20% --- 9.97 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.214599073336
# Testing error
# 0.206204438546
# --- Progress: 12.30% --- 10.04 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211329088217
# Testing error
# 0.203085834042
# --- Progress: 12.40% --- 10.12 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212061915786
# Testing error
# 0.202556036932
# --- Progress: 12.50% --- 10.20 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.214413554652
# Testing error
# 0.205391780377
# --- Progress: 12.60% --- 10.28 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212129744947
# Testing error
# 0.205567102564
# --- Progress: 12.70% --- 10.35 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.213981198746
# Testing error
# 0.205777310783
# --- Progress: 12.80% --- 10.43 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211506825114
# Testing error
# 0.204129541868
# --- Progress: 12.90% --- 10.51 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.214153670197
# Testing error
# 0.205383569967
# --- Progress: 13.00% --- 10.58 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.222834886705
# Testing error
# 0.211989258749
# --- Progress: 13.10% --- 10.66 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217559417427
# Testing error
# 0.208743701417
# --- Progress: 13.20% --- 10.74 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208766601702
# Testing error
# 0.200273954032
# --- Progress: 13.30% --- 10.81 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205514722554
# Testing error
# 0.198275346659
# --- Progress: 13.40% --- 10.89 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207290838208
# Testing error
# 0.196975593755
# --- Progress: 13.50% --- 10.97 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.204986465633
# Testing error
# 0.196288940751
# --- Progress: 13.60% --- 11.05 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206204616518
# Testing error
# 0.198179528649
# --- Progress: 13.70% --- 11.12 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206828385976
# Testing error
# 0.198510306331
# --- Progress: 13.80% --- 11.20 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.203750338759
# Testing error
# 0.197161314372
# --- Progress: 13.90% --- 11.28 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206260442337
# Testing error
# 0.197923839298
# --- Progress: 14.00% --- 11.35 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.231922544428
# Testing error
# 0.222459608698
# --- Progress: 14.10% --- 11.43 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221340554376
# Testing error
# 0.211194998683
# --- Progress: 14.20% --- 11.51 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205837020512
# Testing error
# 0.195782697377
# --- Progress: 14.30% --- 11.58 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205666638574
# Testing error
# 0.196977143939
# --- Progress: 14.40% --- 11.66 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.197220298879
# Testing error
# 0.188654738167
# --- Progress: 14.50% --- 11.73 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.192280905828
# Testing error
# 0.185316465024
# --- Progress: 14.60% --- 11.81 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.19660315554
# Testing error
# 0.189520324742
# --- Progress: 14.70% --- 11.89 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.202753093219
# Testing error
# 0.194327395882
# --- Progress: 14.80% --- 11.96 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.197995098118
# Testing error
# 0.189654851106
# --- Progress: 14.90% --- 12.04 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201440587695
# Testing error
# 0.194232681319
# --- Progress: 15.00% --- 12.12 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.243538504162
# Testing error
# 0.23763006485
# --- Progress: 15.10% --- 12.19 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226317770139
# Testing error
# 0.217595525871
# --- Progress: 15.20% --- 12.27 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212782217319
# Testing error
# 0.201758113606
# --- Progress: 15.30% --- 12.35 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198812910872
# Testing error
# 0.188792504223
# --- Progress: 15.40% --- 12.42 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.196488520388
# Testing error
# 0.187325424655
# --- Progress: 15.50% --- 12.50 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.188489437142
# Testing error
# 0.18042081872
# --- Progress: 15.60% --- 12.58 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.200499576106
# Testing error
# 0.192222944776
# --- Progress: 15.70% --- 12.65 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.188265023605
# Testing error
# 0.181435015478
# --- Progress: 15.80% --- 12.73 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.189895118879
# Testing error
# 0.183059818304
# --- Progress: 15.90% --- 12.81 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.190725451683
# Testing error
# 0.181771922246
# --- Progress: 16.00% --- 12.88 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.245466280899
# Testing error
# 0.240104453946
# --- Progress: 16.10% --- 12.96 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.229306681022
# Testing error
# 0.221945507446
# --- Progress: 16.20% --- 13.04 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218289899128
# Testing error
# 0.207728189349
# --- Progress: 16.30% --- 13.11 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.210226648806
# Testing error
# 0.199703309362
# --- Progress: 16.40% --- 13.19 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198980229184
# Testing error
# 0.188672295336
# --- Progress: 16.50% --- 13.27 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.197573790067
# Testing error
# 0.187105500446
# --- Progress: 16.60% --- 13.34 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.19832352793
# Testing error
# 0.187847695669
# --- Progress: 16.70% --- 13.42 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.185786121727
# Testing error
# 0.177151236982
# --- Progress: 16.80% --- 13.50 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.192859424323
# Testing error
# 0.18272460662
# --- Progress: 16.90% --- 13.57 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201851299294
# Testing error
# 0.191457544889
# --- Progress: 17.00% --- 13.65 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.242935305361
# Testing error
# 0.238988319433
# --- Progress: 17.10% --- 13.73 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.228845710938
# Testing error
# 0.223149904617
# --- Progress: 17.20% --- 13.80 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227514397194
# Testing error
# 0.218839458702
# --- Progress: 17.30% --- 13.88 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.220543688187
# Testing error
# 0.212198656072
# --- Progress: 17.40% --- 13.95 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.204361759524
# Testing error
# 0.192489472871
# --- Progress: 17.50% --- 14.03 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208787303224
# Testing error
# 0.197755272652
# --- Progress: 17.60% --- 14.11 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.19012661242
# Testing error
# 0.180335730344
# --- Progress: 17.70% --- 14.18 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.188047299319
# Testing error
# 0.1792873271
# --- Progress: 17.80% --- 14.26 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198695654274
# Testing error
# 0.189492460482
# --- Progress: 17.90% --- 14.34 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.196841251141
# Testing error
# 0.185396366267
# --- Progress: 18.00% --- 14.41 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.246798872798
# Testing error
# 0.244046834111
# --- Progress: 18.10% --- 14.49 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.23811567856
# Testing error
# 0.233345622667
# --- Progress: 18.20% --- 14.57 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.230758515594
# Testing error
# 0.224983797747
# --- Progress: 18.30% --- 14.64 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.223935503253
# Testing error
# 0.216643748935
# --- Progress: 18.40% --- 14.72 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221692275237
# Testing error
# 0.21628378544
# --- Progress: 18.50% --- 14.79 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212752235779
# Testing error
# 0.203526140614
# --- Progress: 18.60% --- 14.87 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206743855749
# Testing error
# 0.195186248583
# --- Progress: 18.70% --- 14.95 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.202688709563
# Testing error
# 0.189558563167
# --- Progress: 18.80% --- 15.02 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.200826748668
# Testing error
# 0.189399621543
# --- Progress: 18.90% --- 15.10 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.190386912132
# Testing error
# 0.181131809664
# --- Progress: 19.00% --- 15.18 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.258142341864
# Testing error
# 0.256028597069
# --- Progress: 19.10% --- 15.25 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.244177890267
# Testing error
# 0.241161222361
# --- Progress: 19.20% --- 15.33 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.23753811741
# Testing error
# 0.231793420694
# --- Progress: 19.30% --- 15.41 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.232759286253
# Testing error
# 0.227306828845
# --- Progress: 19.40% --- 15.48 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227716946669
# Testing error
# 0.222050617734
# --- Progress: 19.50% --- 15.56 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.227493778986
# Testing error
# 0.220624218234
# --- Progress: 19.60% --- 15.63 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.22031587803
# Testing error
# 0.212657557613
# --- Progress: 19.70% --- 15.71 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201831972944
# Testing error
# 0.190351836892
# --- Progress: 19.80% --- 15.79 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205645331332
# Testing error
# 0.194949070584
# --- Progress: 19.90% --- 15.86 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.177012048143
# Testing error
# 0.169417918926
# --- Progress: 20.00% --- 15.94 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.22262381468
# Testing error
# 0.224249436117
# --- Progress: 20.10% --- 16.19 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219534392671
# Testing error
# 0.221520813244
# --- Progress: 20.20% --- 16.27 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.220277280896
# Testing error
# 0.221772190734
# --- Progress: 20.30% --- 16.35 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219880190415
# Testing error
# 0.223504671156
# --- Progress: 20.40% --- 16.42 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.22030486379
# Testing error
# 0.222051483979
# --- Progress: 20.50% --- 16.50 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.220492752184
# Testing error
# 0.224454484734
# --- Progress: 20.60% --- 16.58 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.220750798441
# Testing error
# 0.224078164983
# --- Progress: 20.70% --- 16.66 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216523250621
# Testing error
# 0.218151378567
# --- Progress: 20.80% --- 16.74 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221233570027
# Testing error
# 0.224373647578
# --- Progress: 20.90% --- 16.83 minutes ---
# Neurons: 50 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216922612437
# Testing error
# 0.219498800635
# --- Progress: 21.00% --- 16.91 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219540696628
# Testing error
# 0.220602781369
# --- Progress: 21.10% --- 17.00 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216536204514
# Testing error
# 0.217363365267
# --- Progress: 21.20% --- 17.08 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218455913091
# Testing error
# 0.218338004999
# --- Progress: 21.30% --- 17.17 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216004258578
# Testing error
# 0.217815864575
# --- Progress: 21.40% --- 17.25 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.214973356144
# Testing error
# 0.217017476563
# --- Progress: 21.50% --- 17.33 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216421215694
# Testing error
# 0.217576614346
# --- Progress: 21.60% --- 17.42 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.216945525818
# Testing error
# 0.218344788481
# --- Progress: 21.70% --- 17.50 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217801270861
# Testing error
# 0.220316899566
# --- Progress: 21.80% --- 17.58 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.215715641502
# Testing error
# 0.217850915892
# --- Progress: 21.90% --- 17.66 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212980865043
# Testing error
# 0.215548260697
# --- Progress: 22.00% --- 17.74 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.22013335504
# Testing error
# 0.220592337251
# --- Progress: 22.10% --- 17.82 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.209135456663
# Testing error
# 0.209734301246
# --- Progress: 22.20% --- 17.90 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211939825414
# Testing error
# 0.214245339854
# --- Progress: 22.30% --- 17.98 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.209259068642
# Testing error
# 0.210347081816
# --- Progress: 22.40% --- 18.06 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206671228993
# Testing error
# 0.207649451126
# --- Progress: 22.50% --- 18.15 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212941097994
# Testing error
# 0.215277074885
# --- Progress: 22.60% --- 18.23 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206664384634
# Testing error
# 0.209521869398
# --- Progress: 22.70% --- 18.32 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207331367531
# Testing error
# 0.208003398721
# --- Progress: 22.80% --- 18.40 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207872455817
# Testing error
# 0.207592387329
# --- Progress: 22.90% --- 18.49 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207581841959
# Testing error
# 0.208403139247
# --- Progress: 23.00% --- 18.57 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.223876206768
# Testing error
# 0.225146975264
# --- Progress: 23.10% --- 18.66 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.214244077334
# Testing error
# 0.214519135924
# --- Progress: 23.20% --- 18.74 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206791354165
# Testing error
# 0.205793196234
# --- Progress: 23.30% --- 18.83 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.199948296923
# Testing error
# 0.20039099104
# --- Progress: 23.40% --- 18.91 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.20289751588
# Testing error
# 0.206568663587
# --- Progress: 23.50% --- 18.99 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.201644002589
# Testing error
# 0.202024260695
# --- Progress: 23.60% --- 19.07 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.203649825799
# Testing error
# 0.206229082651
# --- Progress: 23.70% --- 19.16 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.204497121117
# Testing error
# 0.206510162753
# --- Progress: 23.80% --- 19.24 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.199063369814
# Testing error
# 0.202982689389
# --- Progress: 23.90% --- 19.33 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.204967129254
# Testing error
# 0.206288999114
# --- Progress: 24.00% --- 19.41 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226945288051
# Testing error
# 0.227158600318
# --- Progress: 24.10% --- 19.49 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208549104103
# Testing error
# 0.209252945683
# --- Progress: 24.20% --- 19.58 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.209698037802
# Testing error
# 0.210308053483
# --- Progress: 24.30% --- 19.66 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.200879460893
# Testing error
# 0.202404071249
# --- Progress: 24.40% --- 19.75 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.200217719936
# Testing error
# 0.200709506965
# --- Progress: 24.50% --- 19.84 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.199589623735
# Testing error
# 0.200412674292
# --- Progress: 24.60% --- 19.93 minutes ---
# ...
# 0.217244774953
# --- Progress: 91.90% --- 79.12 minutes ---
# Neurons: 50 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.213175532471
# Testing error
# 0.217552303969
# --- Progress: 92.00% --- 79.20 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217087500238
# Testing error
# 0.21731103629
# --- Progress: 92.10% --- 79.29 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212811020605
# Testing error
# 0.213014425707
# --- Progress: 92.20% --- 79.38 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.212133555441
# Testing error
# 0.214068392085
# --- Progress: 92.30% --- 79.46 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208330555554
# Testing error
# 0.210846607972
# --- Progress: 92.40% --- 79.55 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211961824753
# Testing error
# 0.215874563368
# --- Progress: 92.50% --- 79.63 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.210903283953
# Testing error
# 0.211392147072
# --- Progress: 92.60% --- 79.72 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.213956681061
# Testing error
# 0.215851550229
# --- Progress: 92.70% --- 79.81 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.209557939127
# Testing error
# 0.207666181145
# --- Progress: 92.80% --- 79.89 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211184206608
# Testing error
# 0.212020422291
# --- Progress: 92.90% --- 79.98 minutes ---
# Neurons: 50 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.206397315729
# Testing error
# 0.205956241277
# --- Progress: 93.00% --- 80.06 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.22057778655
# Testing error
# 0.219915588565
# --- Progress: 93.10% --- 80.15 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208491159592
# Testing error
# 0.210222024661
# --- Progress: 93.20% --- 80.23 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.211821918192
# Testing error
# 0.211328289598
# --- Progress: 93.30% --- 80.32 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.202955209215
# Testing error
# 0.20418259056
# --- Progress: 93.40% --- 80.41 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.204311720664
# Testing error
# 0.204778883908
# --- Progress: 93.50% --- 80.49 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205562573722
# Testing error
# 0.205040946087
# --- Progress: 93.60% --- 80.58 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.1911954016
# Testing error
# 0.191816386088
# --- Progress: 93.70% --- 80.67 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.209924144765
# Testing error
# 0.211770885281
# --- Progress: 93.80% --- 80.75 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.205631949815
# Testing error
# 0.205714040453
# --- Progress: 93.90% --- 80.84 minutes ---
# Neurons: 50 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207738898128
# Testing error
# 0.208418789838
# --- Progress: 94.00% --- 80.92 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.226293076069
# Testing error
# 0.226260490022
# --- Progress: 94.10% --- 81.01 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.215681272835
# Testing error
# 0.214281129905
# --- Progress: 94.20% --- 81.09 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.202843870534
# Testing error
# 0.203878476436
# --- Progress: 94.30% --- 81.18 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.203954936749
# Testing error
# 0.203527003469
# --- Progress: 94.40% --- 81.26 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.192528625303
# Testing error
# 0.193653653149
# --- Progress: 94.50% --- 81.35 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198776418164
# Testing error
# 0.199233477563
# --- Progress: 94.60% --- 81.43 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.194277025213
# Testing error
# 0.194478627029
# --- Progress: 94.70% --- 81.52 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.198065673021
# Testing error
# 0.198914228237
# --- Progress: 94.80% --- 81.60 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.197628117581
# Testing error
# 0.196945747404
# --- Progress: 94.90% --- 81.69 minutes ---
# Neurons: 50 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.199737618103
# Testing error
# 0.199514947501
# --- Progress: 95.00% --- 81.78 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.233697137313
# Testing error
# 0.234616106416
# --- Progress: 95.10% --- 81.86 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.221074439577
# Testing error
# 0.220213369685
# --- Progress: 95.20% --- 81.95 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208432970628
# Testing error
# 0.207394063127
# --- Progress: 95.30% --- 82.03 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.20060323131
# Testing error
# 0.201534451423
# --- Progress: 95.40% --- 82.12 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.194145633395
# Testing error
# 0.194908200389
# --- Progress: 95.50% --- 82.21 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.189779317468
# Testing error
# 0.189278252558
# --- Progress: 95.60% --- 82.29 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.19308243007
# Testing error
# 0.192795392423
# --- Progress: 95.70% --- 82.38 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.19306496285
# Testing error
# 0.194049353551
# --- Progress: 95.80% --- 82.47 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.189513108888
# Testing error
# 0.189070344269
# --- Progress: 95.90% --- 82.55 minutes ---
# Neurons: 50 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.191592701671
# Testing error
# 0.191447863424
# --- Progress: 96.00% --- 82.64 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.238039922666
# Testing error
# 0.238509091274
# --- Progress: 96.10% --- 82.72 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.233275813088
# Testing error
# 0.235114241741
# --- Progress: 96.20% --- 82.81 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.217947170274
# Testing error
# 0.217960985244
# --- Progress: 96.30% --- 82.89 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.208835441101
# Testing error
# 0.208929302852
# --- Progress: 96.40% --- 82.97 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.193776403195
# Testing error
# 0.192267966041
# --- Progress: 96.50% --- 83.06 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.192260358979
# Testing error
# 0.194509052392
# --- Progress: 96.60% --- 83.15 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.184106548588
# Testing error
# 0.185994381817
# --- Progress: 96.70% --- 83.23 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.193584963363
# Testing error
# 0.192655550738
# --- Progress: 96.80% --- 83.32 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.194942872021
# Testing error
# 0.195557077572
# --- Progress: 96.90% --- 83.40 minutes ---
# Neurons: 50 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.190835591323
# Testing error
# 0.191719803821
# --- Progress: 97.00% --- 83.49 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.242073248924
# Testing error
# 0.243782523651
# --- Progress: 97.10% --- 83.57 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.233200692778
# Testing error
# 0.23412099732
# --- Progress: 97.20% --- 83.66 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.219443055661
# Testing error
# 0.219760373745
# --- Progress: 97.30% --- 83.75 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.210081348451
# Testing error
# 0.210692897046
# --- Progress: 97.40% --- 83.83 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207309170978
# Testing error
# 0.208863783171
# --- Progress: 97.50% --- 83.92 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.193819967651
# Testing error
# 0.194170020812
# --- Progress: 97.60% --- 84.01 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.193888471067
# Testing error
# 0.195546681852
# --- Progress: 97.70% --- 84.09 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.191144159322
# Testing error
# 0.192664582996
# --- Progress: 97.80% --- 84.18 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.18778107986
# Testing error
# 0.189794217858
# --- Progress: 97.90% --- 84.26 minutes ---
# Neurons: 50 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.184336157609
# Testing error
# 0.183384906989
# --- Progress: 98.00% --- 84.35 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.245643114491
# Testing error
# 0.246680853813
# --- Progress: 98.10% --- 84.43 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.235945148907
# Testing error
# 0.237253868508
# --- Progress: 98.20% --- 84.52 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.23091733011
# Testing error
# 0.232735312503
# --- Progress: 98.30% --- 84.61 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.218820321819
# Testing error
# 0.221152679063
# --- Progress: 98.40% --- 84.69 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.214342008495
# Testing error
# 0.215595042152
# --- Progress: 98.50% --- 84.78 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.210210480644
# Testing error
# 0.213648564418
# --- Progress: 98.60% --- 84.86 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.199060173006
# Testing error
# 0.200304282127
# --- Progress: 98.70% --- 84.95 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.178511344871
# Testing error
# 0.180891078379
# --- Progress: 98.80% --- 85.03 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.184236849459
# Testing error
# 0.186826992818
# --- Progress: 98.90% --- 85.12 minutes ---
# Neurons: 50 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.186426292588
# Testing error
# 0.188542019077
# --- Progress: 99.00% --- 85.20 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.252750158582
# Testing error
# 0.254282938458
# --- Progress: 99.10% --- 85.29 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.243506981501
# Testing error
# 0.246159361632
# --- Progress: 99.20% --- 85.37 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.233535653524
# Testing error
# 0.23588983519
# --- Progress: 99.30% --- 85.45 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.234053326423
# Testing error
# 0.234856019491
# --- Progress: 99.40% --- 85.54 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.213943441324
# Testing error
# 0.216024211211
# --- Progress: 99.50% --- 85.63 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.202316868048
# Testing error
# 0.204765574338
# --- Progress: 99.60% --- 85.71 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.207424153997
# Testing error
# 0.211011396759
# --- Progress: 99.70% --- 85.80 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.193487366796
# Testing error
# 0.194949399699
# --- Progress: 99.80% --- 85.88 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.187947558459
# Testing error
# 0.191785058238
# --- Progress: 99.90% --- 85.97 minutes ---
# Neurons: 50 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# harvesting states...
# fitting...
# training error:
# 0.199591518804
# Testing error
# 0.200718400064
# --- Progress: 100.00% --- 86.06 minutes ---
# Total time for Testbench:
# --- 5163.31 seconds ---
# --- 86.06 minutes ---

# %%
import pickle
#### Save Data
# with open('dataFastDelta_t01ErrorsAveraged10.p','wb') as outputFile:
#     pickle.dump(delta_t_errors_fast,outputFile)
#     pickle.dump(fast_errors_averaged_over_trials, outputFile)
#     pickle.dump(n_neurons_fast, outputFile)
#     pickle.dump(delta_t_fast, outputFile)
#     pickle.dump(new_trials, outputFile)
#     pickle.dump(l_rate_fast, outputFile)
#     pickle.dump(sp_rad_fast, outputFile)
#### Load Data
with open('dataFastDelta_tErrorsAveraged10.p', 'rb') as inputFile:
    delta_t_errors_fast = pickle.load(inputFile)
    fast_errors_averaged_over_trials = pickle.load(inputFile)
    n_neurons_fast = pickle.load(inputFile)
    delta_t_fast = pickle.load(inputFile)
    new_trials = pickle.load(inputFile)
    l_rate_fast = pickle.load(inputFile)
    sp_rad_fast = pickle.load(inputFile)

# %% [markdown]
# data = [
#      go.Contour(
#         z=fast_errors_averaged_over_trials.reshape(10,10).T,
#         x=l_rate_fast,
#         y=sp_rad_fast,
#         colorscale='Jet',
#     )]
# py.iplot(data)

# %%
### Different delta_t

from matplotlib import pyplot
# %matplotlib inline
print(delta_t_fast)
xx, yy = np.meshgrid(l_rate_fast, sp_rad_fast)
pyplot.figure(figsize=(12,14))
for p in range(len(delta_t_fast)):
    pyplot.subplot(3,2,p+1)
    pyplot.contourf(xx,
                    yy,delta_t_errors_fast[p].reshape(10,10).T)
    pyplot.title("Fast ESN trained using best slow ESN averaged 10")
    pyplot.xlabel("Leak-rate")
    pyplot.ylabel("Spectral-radius")
    pyplot.colorbar()
# Out:
# [0.1]

# %% [markdown]
# import plotly.plotly as py
# import plotly.graph_objs as go
#
# # c= ['hsl('+str(h)+',50%'+',50%)' for h in np.linspace(0, 360, len(all_errors_fast))]
# c= ["blue", "orange", "green", "cyan", "yellow", "magenta", "red", "black"]
# data = []
#
#
# x = np.repeat(l_rate_fast,len(l_rate_fast))
# y = np.tile(sp_rad_fast,len(sp_rad_fast))
# z = fast_errors_averaged_over_trials
#
# trace1 = go.Scatter3d(
#     x=x,
#     y=y,
#     z=z,
#     name=("Fast network averaged over",new_trials,"Trials"),
#     mode='markers',
#     marker=dict(
#         size=7,
#         color=z,                # set color to an array/list of desired values
#         colorscale='Viridis',   # choose a colorscale
#         opacity=0.8
#     )
# )
#
#
# data = [trace1]
# layout = go.Layout(
# #     margin=dict(
# #         l=0,
# #         r=0,
# #         b=0,
# #         t=0
# #     ),
# #     go.zaxis=dict(
# #         range=[0, 0.8]
# #     ),
#     scene=go.Scene(
#         xaxis=go.XAxis(title='x = Leak-Rate'),
#         yaxis=go.YAxis(title='y = Spectral Radius'),
#         zaxis=go.ZAxis(title='z = Error')
#         )
# )
# fig = go.Figure(data=data, layout=layout)
# py.iplot(fig, filename='Fast Network Averaged')
