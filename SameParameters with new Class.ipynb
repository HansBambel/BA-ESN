# %%
import Parity_Data_Generator
import numpy as np
from newESN import ESN
import time

N = 4000   # number of datapoints
n = 3       # n-parity
timescale = 50
rng = np.random.RandomState(42)

def produceTrainingData(i):
    bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(i))

    # Divide in training and test data
    traintest_cutoff = int(np.ceil(0.7 * len(bits)))
    train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
    train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
    train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
    return train_bits, test_bits, train_parity, test_parity, train_targets, test_targets

# %%
trials = 10
num_neurons_slow = 300
num_neurons_fast = 50

delta_t = [0.1]

l_rate = np.linspace(0.1, 1, num=10)
# l_rate =[0.2]
# l_rate = [0.1,0.2,0.3]

# sp_rad = np.linspace(0.9, 1.0, num=5)
sp_rad = np.linspace(0.1, 1, num=10)
# sp_rad = [0.8]


run_time = time.time()
iterations, iterationcount = trials*len(sp_rad)*len(l_rate)*len(delta_t), 0

delta_t_error = []
for dt in delta_t:
    all_errors = [{} for _ in range(trials)] # empty dict
    for i in range(trials):
        errors = []
        # produce training and testing data
        train_bits, test_bits, train_parity, test_parity, train_targets, test_targets = produceTrainingData(i)
        for l in l_rate:
            for s in sp_rad:
                print("Neurons:", num_neurons_slow,"Leak-rate:",l,"Spectral-radius:",s,"Delta_t:",dt)
                ## Create slow ESN
                nParityESN = ESN(inputs=1,
                      neurons=num_neurons_slow,  
                      spectral_radius=s,  
                      leak_rate= l,   
                      dt= dt,
                      sparsity=0.95,
                      noise=0.01)
                nParityESN.train(train_bits, train_parity)

                ## Get trainingdata for output-ESN from parity-ESN
                new_train_bits, new_test_bits, new_train_parity, new_test_parity, new_train_targets, new_test_targets = produceTrainingData(i+123)

                predictedParityTrain = nParityESN.predict(new_train_bits)
                predictedParityTest = nParityESN.predict(new_test_bits)

                outputESN = ESN(inputs=1,
                          neurons=num_neurons_fast,  
                          spectral_radius=s,  
                          leak_rate= l,   
                          dt= dt,
                          sparsity=0.95,
                          noise=0.01)

                outputESN.train(predictedParityTrain, new_train_targets)
                predictedOutput = outputESN.predict(predictedParityTest)

                print("Testing error")
                test_error = np.sqrt(np.mean((predictedOutput - new_test_targets) ** 2))
                print(test_error)

                errors.append(test_error)
                iterationcount = iterationcount + 1
                print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
        ## Save leak-rate,spectral-radius and error in dictionary
        all_errors[i] = errors

    ### Average errors
    errors_averaged_over_trials = np.zeros(len(sp_rad)*len(l_rate))
    for i in range(len(all_errors)):
        e = all_errors[i]
        errors_averaged_over_trials = np.add(errors_averaged_over_trials, np.array(e))
    errors_averaged_over_trials = np.divide(errors_averaged_over_trials, trials)
    
    delta_t_error.append(errors_averaged_over_trials)
            
print("Total time for Testbench:")
print("--- {:.2f} seconds ---".format(time.time() - run_time))
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# C:\Users\Kevin\Documents\Python-projects\BA-ESN\BlockedLeastSquares.py:101: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self._LHS == None:
# Testing error
# 0.41717928587
# --- Progress: 0.10% --- 0.40 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.432814369761
# --- Progress: 0.20% --- 0.83 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.56053487918
# --- Progress: 0.30% --- 1.23 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.589890650051
# --- Progress: 0.40% --- 1.63 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.50904432749
# --- Progress: 0.50% --- 2.04 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.507499417907
# --- Progress: 0.60% --- 2.46 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.509808184775
# --- Progress: 0.70% --- 2.89 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.544043830018
# --- Progress: 0.80% --- 3.31 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 1.21978146324
# --- Progress: 0.90% --- 3.72 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.505621893754
# --- Progress: 1.00% --- 4.15 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.439607864239
# --- Progress: 1.10% --- 4.55 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.364842350831
# --- Progress: 1.20% --- 4.94 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.334854308448
# --- Progress: 1.30% --- 5.33 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.353644666764
# --- Progress: 1.40% --- 5.72 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.489905862344
# --- Progress: 1.50% --- 6.12 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.440902489038
# --- Progress: 1.60% --- 6.53 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.499941563765
# --- Progress: 1.70% --- 6.94 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.504467197604
# --- Progress: 1.80% --- 7.35 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.502854318185
# --- Progress: 1.90% --- 7.75 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.502274446305
# --- Progress: 2.00% --- 8.15 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.490566957494
# --- Progress: 2.10% --- 8.54 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.427135373113
# --- Progress: 2.20% --- 8.93 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.337035560094
# --- Progress: 2.30% --- 9.32 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.262891554925
# --- Progress: 2.40% --- 9.71 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.253586542969
# --- Progress: 2.50% --- 10.11 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.296078909088
# --- Progress: 2.60% --- 10.51 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.421080999565
# --- Progress: 2.70% --- 10.91 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.429729089442
# --- Progress: 2.80% --- 11.31 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.491812162011
# --- Progress: 2.90% --- 11.71 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.498564006486
# --- Progress: 3.00% --- 12.12 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.477921635366
# --- Progress: 3.10% --- 12.51 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.480713811438
# --- Progress: 3.20% --- 12.90 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.433589573894
# --- Progress: 3.30% --- 13.29 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.332783441678
# --- Progress: 3.40% --- 13.68 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.262078831578
# --- Progress: 3.50% --- 14.07 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.225851168992
# --- Progress: 3.60% --- 14.46 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.251111719391
# --- Progress: 3.70% --- 14.85 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.282919418031
# --- Progress: 3.80% --- 15.25 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.320401353448
# --- Progress: 3.90% --- 15.65 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.419724580806
# --- Progress: 4.00% --- 16.05 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.495026661541
# --- Progress: 4.10% --- 16.43 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.479916016447
# --- Progress: 4.20% --- 16.81 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.462324297648
# --- Progress: 4.30% --- 17.20 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.421453733896
# --- Progress: 4.40% --- 17.58 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.37370704088
# --- Progress: 4.50% --- 17.96 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.27138179228
# --- Progress: 4.60% --- 18.35 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.285841049375
# --- Progress: 4.70% --- 18.73 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.237166073361
# --- Progress: 4.80% --- 19.11 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.232792192031
# --- Progress: 4.90% --- 19.50 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.215497506172
# --- Progress: 5.00% --- 19.89 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.511550123303
# --- Progress: 5.10% --- 20.28 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.497774354589
# --- Progress: 5.20% --- 20.66 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.481107130762
# --- Progress: 5.30% --- 21.04 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.474499844512
# --- Progress: 5.40% --- 21.43 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.454771149409
# --- Progress: 5.50% --- 21.82 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.383618687248
# --- Progress: 5.60% --- 22.21 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.291840168463
# --- Progress: 5.70% --- 22.60 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.275841983997
# --- Progress: 5.80% --- 22.99 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.270438268099
# --- Progress: 5.90% --- 23.37 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.236283425236
# --- Progress: 6.00% --- 23.76 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.537253631996
# --- Progress: 6.10% --- 24.14 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.511000523715
# --- Progress: 6.20% --- 24.53 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.486544679393
# --- Progress: 6.30% --- 24.91 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.479562513766
# --- Progress: 6.40% --- 25.29 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.481523410469
# --- Progress: 6.50% --- 25.67 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.467057339067
# --- Progress: 6.60% --- 26.06 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.424398604401
# --- Progress: 6.70% --- 26.44 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.345729399663
# --- Progress: 6.80% --- 26.83 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.312870160561
# --- Progress: 6.90% --- 27.22 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.302892582804
# --- Progress: 7.00% --- 27.62 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.561557004448
# --- Progress: 7.10% --- 28.00 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.53365151483
# --- Progress: 7.20% --- 28.38 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.510208457432
# --- Progress: 7.30% --- 28.77 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.488490478762
# --- Progress: 7.40% --- 29.15 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.483746110231
# --- Progress: 7.50% --- 29.55 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.481108342888
# --- Progress: 7.60% --- 29.98 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.453962188167
# --- Progress: 7.70% --- 30.41 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.411477939449
# --- Progress: 7.80% --- 30.82 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.394905140463
# --- Progress: 7.90% --- 31.25 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.302190169097
# --- Progress: 8.00% --- 31.70 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.568014910547
# --- Progress: 8.10% --- 32.12 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.551705074839
# --- Progress: 8.20% --- 32.53 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.536099231845
# --- Progress: 8.30% --- 32.92 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.498745013108
# --- Progress: 8.40% --- 33.32 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.479003459277
# --- Progress: 8.50% --- 33.72 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.479245664011
# --- Progress: 8.60% --- 34.11 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.464590894813
# --- Progress: 8.70% --- 34.50 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.44833895231
# --- Progress: 8.80% --- 34.89 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.452722309127
# --- Progress: 8.90% --- 35.28 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.393774419648
# --- Progress: 9.00% --- 35.68 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.570959758036
# --- Progress: 9.10% --- 36.07 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.562327339974
# --- Progress: 9.20% --- 36.46 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.546184411856
# --- Progress: 9.30% --- 36.85 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.538702375411
# --- Progress: 9.40% --- 37.24 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.5023182028
# --- Progress: 9.50% --- 37.63 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.48233542174
# --- Progress: 9.60% --- 38.03 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.482405021405
# --- Progress: 9.70% --- 38.43 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.476304808854
# --- Progress: 9.80% --- 38.83 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.472561525783
# --- Progress: 9.90% --- 39.22 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.452311640445
# --- Progress: 10.00% --- 39.61 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.434873334256
# --- Progress: 10.10% --- 40.01 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.42986481881
# --- Progress: 10.20% --- 40.41 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.510277023121
# --- Progress: 10.30% --- 40.82 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.507893137573
# --- Progress: 10.40% --- 41.23 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.504367330915
# --- Progress: 10.50% --- 41.64 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.502474738493
# --- Progress: 10.60% --- 42.05 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.503311284857
# --- Progress: 10.70% --- 42.46 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.539736837515
# --- Progress: 10.80% --- 42.87 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.54687384851
# --- Progress: 10.90% --- 43.29 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.503638613768
# --- Progress: 11.00% --- 43.70 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.447330256354
# --- Progress: 11.10% --- 44.10 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.367596481305
# --- Progress: 11.20% --- 44.49 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.303494300338
# --- Progress: 11.30% --- 44.90 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.38840769193
# --- Progress: 11.40% --- 45.30 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.41453394504
# --- Progress: 11.50% --- 45.70 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.50655528544
# --- Progress: 11.60% --- 46.10 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.499081753963
# --- Progress: 11.70% --- 46.50 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.50105667598
# --- Progress: 11.80% --- 46.90 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.505776714519
# --- Progress: 11.90% --- 47.31 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.503157531261
# --- Progress: 12.00% --- 47.72 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.489789570756
# --- Progress: 12.10% --- 48.11 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.423192234301
# --- Progress: 12.20% --- 48.50 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.359567288966
# --- Progress: 12.30% --- 48.90 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.259770282795
# --- Progress: 12.40% --- 49.29 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.242460450964
# --- Progress: 12.50% --- 49.68 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.296894119495
# --- Progress: 12.60% --- 50.09 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.349969988332
# --- Progress: 12.70% --- 50.48 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.487894830307
# --- Progress: 12.80% --- 50.89 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.50231874882
# --- Progress: 12.90% --- 51.30 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.500026886011
# --- Progress: 13.00% --- 51.70 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.47886063667
# --- Progress: 13.10% --- 52.08 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.481759405166
# --- Progress: 13.20% --- 52.47 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.417109481411
# --- Progress: 13.30% --- 52.86 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.330049885908
# --- Progress: 13.40% --- 53.25 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.279060910704
# --- Progress: 13.50% --- 53.63 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.236111432993
# --- Progress: 13.60% --- 54.03 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.255970192751
# --- Progress: 13.70% --- 54.43 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.259560643378
# --- Progress: 13.80% --- 54.83 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.316943861427
# --- Progress: 13.90% --- 55.23 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.376264291315
# --- Progress: 14.00% --- 55.62 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.495656435928
# --- Progress: 14.10% --- 56.01 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.482586012336
# --- Progress: 14.20% --- 56.40 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.472315783552
# --- Progress: 14.30% --- 56.79 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.423998470139
# --- Progress: 14.40% --- 57.18 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.373407905271
# --- Progress: 14.50% --- 57.57 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.290563179046
# --- Progress: 14.60% --- 57.97 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.262313123322
# --- Progress: 14.70% --- 58.36 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.246622821924
# --- Progress: 14.80% --- 58.76 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.215087944939
# --- Progress: 14.90% --- 59.15 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.28350313301
# --- Progress: 15.00% --- 59.55 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.518723482077
# --- Progress: 15.10% --- 59.94 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.481380174021
# --- Progress: 15.20% --- 60.33 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.481285565805
# --- Progress: 15.30% --- 60.72 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.479949298787
# --- Progress: 15.40% --- 61.13 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.457273224991
# --- Progress: 15.50% --- 61.52 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.397048957993
# --- Progress: 15.60% --- 61.92 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.352944644012
# --- Progress: 15.70% --- 62.31 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.243000054588
# --- Progress: 15.80% --- 62.71 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.250919681755
# --- Progress: 15.90% --- 63.11 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.248402077025
# --- Progress: 16.00% --- 63.51 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.535817043016
# --- Progress: 16.10% --- 63.90 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.512947915776
# --- Progress: 16.20% --- 64.29 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.487192811305
# --- Progress: 16.30% --- 64.68 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.48272730145
# --- Progress: 16.40% --- 65.07 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.47631902216
# --- Progress: 16.50% --- 65.46 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.440538324326
# --- Progress: 16.60% --- 65.86 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.413145213117
# --- Progress: 16.70% --- 66.27 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.349793159324
# --- Progress: 16.80% --- 66.67 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.34884619615
# --- Progress: 16.90% --- 67.06 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.239631092868
# --- Progress: 17.00% --- 67.45 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.551980484567
# --- Progress: 17.10% --- 67.83 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.516981518169
# --- Progress: 17.20% --- 68.22 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.499196249215
# --- Progress: 17.30% --- 68.62 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.479528389423
# --- Progress: 17.40% --- 69.01 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.48021320068
# --- Progress: 17.50% --- 69.39 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.476403462117
# --- Progress: 17.60% --- 69.78 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.45183053005
# --- Progress: 17.70% --- 70.19 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.433980272893
# --- Progress: 17.80% --- 70.57 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.390258051742
# --- Progress: 17.90% --- 70.96 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.357065762963
# --- Progress: 18.00% --- 71.36 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.554835501819
# --- Progress: 18.10% --- 71.73 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.536805476431
# --- Progress: 18.20% --- 72.12 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.516997144904
# --- Progress: 18.30% --- 72.50 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.506251657731
# --- Progress: 18.40% --- 72.90 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.485556674644
# --- Progress: 18.50% --- 73.29 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.480995005175
# --- Progress: 18.60% --- 73.68 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.475832786185
# --- Progress: 18.70% --- 74.06 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.470719187673
# --- Progress: 18.80% --- 74.45 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.43463889785
# --- Progress: 18.90% --- 74.84 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.418075266173
# --- Progress: 19.00% --- 75.23 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.558446455035
# --- Progress: 19.10% --- 75.62 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.551845708138
# --- Progress: 19.20% --- 76.00 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.538813417245
# --- Progress: 19.30% --- 76.38 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.532060579533
# --- Progress: 19.40% --- 76.77 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.499291322397
# --- Progress: 19.50% --- 77.15 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.489998064472
# --- Progress: 19.60% --- 77.55 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.482843873472
# --- Progress: 19.70% --- 77.93 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.469906701806
# --- Progress: 19.80% --- 78.32 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.467185007153
# --- Progress: 19.90% --- 78.72 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.464651305806
# --- Progress: 20.00% --- 79.11 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.411062645517
# --- Progress: 20.10% --- 79.50 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.419686084116
# --- Progress: 20.20% --- 79.90 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.500946719674
# --- Progress: 20.30% --- 80.30 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.55501875502
# --- Progress: 20.40% --- 80.71 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.503639391584
# --- Progress: 20.50% --- 81.11 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.518694756699
# --- Progress: 20.60% --- 81.51 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.50937955232
# --- Progress: 20.70% --- 81.92 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.513279319728
# --- Progress: 20.80% --- 82.33 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.516516130384
# --- Progress: 20.90% --- 82.74 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.505018123684
# --- Progress: 21.00% --- 83.15 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.447141211105
# --- Progress: 21.10% --- 83.54 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.353206282226
# --- Progress: 21.20% --- 83.93 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.304459838838
# --- Progress: 21.30% --- 84.32 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.316957676014
# --- Progress: 21.40% --- 84.72 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.447595266668
# --- Progress: 21.50% --- 85.12 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.47945066406
# --- Progress: 21.60% --- 85.52 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.499186837407
# --- Progress: 21.70% --- 85.93 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.502333480346
# --- Progress: 21.80% --- 86.34 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.521393795962
# --- Progress: 21.90% --- 86.74 minutes ---
# Neurons: 300 Leak-rate: 0.2 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.507633279553
# --- Progress: 22.00% --- 87.15 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.497901984252
# --- Progress: 22.10% --- 87.54 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.434494949558
# --- Progress: 22.20% --- 87.93 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.332897614754
# --- Progress: 22.30% --- 88.32 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.24390881637
# --- Progress: 22.40% --- 88.71 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.262197892561
# --- Progress: 22.50% --- 89.10 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.288870922925
# --- Progress: 22.60% --- 89.50 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.393225050823
# --- Progress: 22.70% --- 89.90 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0
minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.271162227976
# --- Progress: 92.50% --- 371.56 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.285608009927
# --- Progress: 92.60% --- 371.95 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.387336442718
# --- Progress: 92.70% --- 372.34 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.418438821355
# --- Progress: 92.80% --- 372.74 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.473942072485
# --- Progress: 92.90% --- 373.14 minutes ---
# Neurons: 300 Leak-rate: 0.3 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.50205991849
# --- Progress: 93.00% --- 373.53 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.486680886125
# --- Progress: 93.10% --- 373.92 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.480935698652
# --- Progress: 93.20% --- 374.30 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.4348136345
# --- Progress: 93.30% --- 374.68 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.334603648526
# --- Progress: 93.40% --- 375.07 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.251639794771
# --- Progress: 93.50% --- 375.46 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.247158676732
# --- Progress: 93.60% --- 375.85 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.284234848321
# --- Progress: 93.70% --- 376.23 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.316658397058
# --- Progress: 93.80% --- 376.62 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.385941996502
# --- Progress: 93.90% --- 377.02 minutes ---
# Neurons: 300 Leak-rate: 0.4 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.433609347966
# --- Progress: 94.00% --- 377.42 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.488092509894
# --- Progress: 94.10% --- 377.80 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.490094157139
# --- Progress: 94.20% --- 378.18 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.484081074583
# --- Progress: 94.30% --- 378.56 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.423686080327
# --- Progress: 94.40% --- 378.94 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.387400190384
# --- Progress: 94.50% --- 379.32 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.328254486571
# --- Progress: 94.60% --- 379.71 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.267036344272
# --- Progress: 94.70% --- 380.09 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.221144501233
# --- Progress: 94.80% --- 380.47 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.232568255295
# --- Progress: 94.90% --- 380.86 minutes ---
# Neurons: 300 Leak-rate: 0.5 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.305178883615
# --- Progress: 95.00% --- 381.24 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.525925251802
# --- Progress: 95.10% --- 381.63 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.500138734401
# --- Progress: 95.20% --- 382.01 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.487206136189
# --- Progress: 95.30% --- 382.39 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.480013319646
# --- Progress: 95.40% --- 382.77 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.444349162956
# --- Progress: 95.50% --- 383.15 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.417732040668
# --- Progress: 95.60% --- 383.54 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.316655290648
# --- Progress: 95.70% --- 383.92 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.253403474714
# --- Progress: 95.80% --- 384.30 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.238076757739
# --- Progress: 95.90% --- 384.70 minutes ---
# Neurons: 300 Leak-rate: 0.6 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.257439225115
# --- Progress: 96.00% --- 385.09 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.544579592391
# --- Progress: 96.10% --- 385.47 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.524768969209
# --- Progress: 96.20% --- 385.85 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.48249526559
# --- Progress: 96.30% --- 386.23 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.49205414492
# --- Progress: 96.40% --- 386.61 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.48581058419
# --- Progress: 96.50% --- 387.00 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.451803997218
# --- Progress: 96.60% --- 387.38 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.408064657384
# --- Progress: 96.70% --- 387.76 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.375286241906
# --- Progress: 96.80% --- 388.14 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.306445859733
# --- Progress: 96.90% --- 388.53 minutes ---
# Neurons: 300 Leak-rate: 0.7 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.262703320528
# --- Progress: 97.00% --- 388.91 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.555439279435
# --- Progress: 97.10% --- 389.30 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.540154387555
# --- Progress: 97.20% --- 389.68 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.522685973912
# --- Progress: 97.30% --- 390.06 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.484422236884
# --- Progress: 97.40% --- 390.44 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.489497717079
# --- Progress: 97.50% --- 390.83 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.48337556009
# --- Progress: 97.60% --- 391.21 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.445116921825
# --- Progress: 97.70% --- 391.59 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.445403831265
# --- Progress: 97.80% --- 391.97 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.385535545731
# --- Progress: 97.90% --- 392.35 minutes ---
# Neurons: 300 Leak-rate: 0.8 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.356818484946
# --- Progress: 98.00% --- 392.73 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.565566322022
# --- Progress: 98.10% --- 393.11 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.550201804435
# --- Progress: 98.20% --- 393.49 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.537037469672
# --- Progress: 98.30% --- 393.88 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.508121957752
# --- Progress: 98.40% --- 394.26 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.487611000217
# --- Progress: 98.50% --- 394.64 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.485076284351
# --- Progress: 98.60% --- 395.03 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.481816702134
# --- Progress: 98.70% --- 395.41 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.456080530374
# --- Progress: 98.80% --- 395.80 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.44338354972
# --- Progress: 98.90% --- 396.18 minutes ---
# Neurons: 300 Leak-rate: 0.9 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.412253532516
# --- Progress: 99.00% --- 396.57 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.56668772314
# --- Progress: 99.10% --- 396.95 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.2 Delta_t: 0.1
# Testing error
# 0.559001837635
# --- Progress: 99.20% --- 397.33 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.3 Delta_t: 0.1
# Testing error
# 0.546201857797
# --- Progress: 99.30% --- 397.72 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.4 Delta_t: 0.1
# Testing error
# 0.535554076906
# --- Progress: 99.40% --- 398.10 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.5 Delta_t: 0.1
# Testing error
# 0.505132808906
# --- Progress: 99.50% --- 398.48 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.6 Delta_t: 0.1
# Testing error
# 0.493939029533
# --- Progress: 99.60% --- 398.86 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.7 Delta_t: 0.1
# Testing error
# 0.493221033261
# --- Progress: 99.70% --- 399.24 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.8 Delta_t: 0.1
# Testing error
# 0.482084071228
# --- Progress: 99.80% --- 399.62 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 0.9 Delta_t: 0.1
# Testing error
# 0.475352330432
# --- Progress: 99.90% --- 400.01 minutes ---
# Neurons: 300 Leak-rate: 1.0 Spectral-radius: 1.0 Delta_t: 0.1
# Testing error
# 0.460145573985
# --- Progress: 100.00% --- 400.39 minutes ---
# Total time for Testbench:
# --- 24023.66 seconds ---
# --- 400.39 minutes ---

# %%
import pickle
#### Save Data
# with open('dataNewClassSameLeakAndSpectErrorsAveraged10.p','wb') as outputFile:
#     pickle.dump(delta_t_error,outputFile)
#     pickle.dump(num_neurons_slow, outputFile)
#     pickle.dump(num_neurons_fast, outputFile)
#     pickle.dump(delta_t, outputFile)
#     pickle.dump(l_rate, outputFile)
#     pickle.dump(sp_rad, outputFile)
#### Load Data
with open('dataNewClassSameLeakAndSpectErrorsAveraged10.p', 'rb') as inputFile:
    delta_t_error = pickle.load(inputFile)
    num_neurons_slow = pickle.load(inputFile)
    num_neurons_fast = pickle.load(inputFile)
    delta_t = pickle.load(inputFile)
    l_rate = pickle.load(inputFile)
    sp_rad = pickle.load(inputFile)

# %%
### Errors
import numpy as np
from matplotlib import pyplot
# %matplotlib inline
xx, yy = np.meshgrid(l_rate, sp_rad)
pyplot.figure(figsize=(10,6))
pyplot.subplot(111)
pyplot.contourf(xx,
                yy,delta_t_error[0].reshape(10,10).T)
# pyplot.title("Slow and fast trained using the same parameters averaged over 10 trials")
pyplot.xlabel("Leak-rate")
pyplot.ylabel("Spectral-radius")
pyplot.colorbar()
