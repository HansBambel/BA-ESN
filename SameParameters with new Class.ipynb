# %%
import Parity_Data_Generator
import numpy as np
from newESN import ESN
import time

N = 4000   # number of datapoints
n = 3       # n-parity
timescale = 50
rng = np.random.RandomState(42)

def produceTrainingData(i):
    bits, parity, target = Parity_Data_Generator.generateParityData(N, n, timescale=timescale, 
                                                                    randomstate=np.random.RandomState(i))

    # Divide in training and test data
    traintest_cutoff = int(np.ceil(0.7 * len(bits)))
    train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
    train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
    train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]
    return train_bits, test_bits, train_parity, test_parity, train_targets, test_targets

# %%
trials = 10
num_neurons_slow = 300
num_neurons_fast = 50

delta_t = [0.1]

l_rate = np.linspace(0.1, 1.5, num=10)
# l_rate =[0.2]
# l_rate = [0.1,0.2,0.3]

# sp_rad = np.linspace(0.9, 1.0, num=5)
sp_rad = np.linspace(0.1, 2, num=10)
# sp_rad = [0.8]


run_time = time.time()
iterations, iterationcount = trials*len(sp_rad)*len(l_rate)*len(delta_t), 0

delta_t_error = []
for dt in delta_t:
    all_errors = [{} for _ in range(trials)] # empty dict
    for i in range(trials):
        errors = []
        # produce training and testing data
        train_bits, test_bits, train_parity, test_parity, train_targets, test_targets = produceTrainingData(i)
        # z-transformation
        scale = 1/np.std(train_bits)
        shift = -np.mean(train_bits)/np.std(train_bits)
        for l in l_rate:
            for s in sp_rad:
                print("Neurons:", num_neurons_slow,"Leak-rate:",l,"Spectral-radius:",s,"Delta_t:",dt)
                ## Create slow ESN
                nParityESN = ESN(inputs=1,
                      neurons=num_neurons_slow,  
                      spectral_radius=s,  
                      leak_rate= l,   
                      dt= dt,
                      sparsity=0.95,
                      noise=0.01,
                      input_scale=scale,          
                      input_shift=shift)
                nParityESN.train(train_bits, train_parity)

                ## Get trainingdata for output-ESN from parity-ESN
                new_train_bits, new_test_bits, new_train_parity, new_test_parity, new_train_targets, new_test_targets = produceTrainingData(i+123)

                predictedParityTrain = nParityESN.predict(new_train_bits)
                predictedParityTest = nParityESN.predict(new_test_bits)

                # z-transformation for fast network
                fast_scale = 1/np.std(predictedParityTrain)
                fast_shift = -np.mean(predictedParityTrain)/np.std(predictedParityTrain)
                outputESN = ESN(inputs=1,
                          neurons=num_neurons_fast,  
                          spectral_radius=s,  
                          leak_rate= l,   
                          dt= dt,
                          sparsity=0.95,
                          noise=0.01,
                          input_scale=fast_scale,
                          input_shift=fast_shift)

                outputESN.train(predictedParityTrain, new_train_targets)
                predictedOutput = outputESN.predict(predictedParityTest)

                print("Testing error")
                test_error = np.sqrt(np.mean((predictedOutput - new_test_targets) ** 2))
                print(test_error)

                errors.append(test_error)
                iterationcount = iterationcount + 1
                print("--- Progress: {:.2f}% --- {:.2f} minutes ---".format(iterationcount/iterations*100, ((time.time() - run_time)/60) ))
        ## Save leak-rate,spectral-radius and error in dictionary
        all_errors[i] = errors

    ### Average errors
    errors_averaged_over_trials = np.zeros(len(sp_rad)*len(l_rate))
    for i in range(len(all_errors)):
        e = all_errors[i]
        errors_averaged_over_trials = np.add(errors_averaged_over_trials, np.array(e))
    errors_averaged_over_trials = np.divide(errors_averaged_over_trials, trials)
    
    delta_t_error.append(errors_averaged_over_trials)
            
print("Total time for Testbench:")
print("--- {:.2f} seconds ---".format(time.time() - run_time))
print("--- {:.2f} minutes ---".format(((time.time() - run_time)/60)))
# Out:
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# C:\Users\Kevin\Documents\Python-projects\BA-ESN\BlockedLeastSquares.py:101: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self._LHS == None:
# Testing error
# 0.362006203031
# --- Progress: 0.10% --- 0.49 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.488407003231
# --- Progress: 0.20% --- 0.98 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.502612615948
# --- Progress: 0.30% --- 1.40 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.505098124293
# --- Progress: 0.40% --- 1.82 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.511403296872
# --- Progress: 0.50% --- 2.24 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.502468082833
# --- Progress: 0.60% --- 2.67 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.502536054877
# --- Progress: 0.70% --- 3.20 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.50382595336
# --- Progress: 0.80% --- 3.69 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.502868676191
# --- Progress: 0.90% --- 4.16 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.502906495027
# --- Progress: 1.00% --- 4.64 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.401776022353
# --- Progress: 1.10% --- 5.10 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.212466585869
# --- Progress: 1.20% --- 5.56 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.205525951195
# --- Progress: 1.30% --- 6.01 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.390917720867
# --- Progress: 1.40% --- 6.46 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.48182648863
# --- Progress: 1.50% --- 6.92 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.501462477077
# --- Progress: 1.60% --- 7.38 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.504409536268
# --- Progress: 1.70% --- 7.86 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.503132145132
# --- Progress: 1.80% --- 8.35 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.50622877958
# --- Progress: 1.90% --- 8.84 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.501700168348
# --- Progress: 2.00% --- 9.34 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.49811720975
# --- Progress: 2.10% --- 9.83 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.318246818655
# --- Progress: 2.20% --- 10.36 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.168537991677
# --- Progress: 2.30% --- 10.87 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.167676959785
# --- Progress: 2.40% --- 11.37 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.228775377503
# --- Progress: 2.50% --- 11.87 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.330670725691
# --- Progress: 2.60% --- 12.36 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.440947873038
# --- Progress: 2.70% --- 12.85 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.487207557905
# --- Progress: 2.80% --- 13.33 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.462784713974
# --- Progress: 2.90% --- 13.82 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.500355184273
# --- Progress: 3.00% --- 14.31 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.501626983758
# --- Progress: 3.10% --- 14.78 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.480007654486
# --- Progress: 3.20% --- 15.26 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.33145814863
# --- Progress: 3.30% --- 15.74 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.195797552263
# --- Progress: 3.40% --- 16.22 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.147163493063
# --- Progress: 3.50% --- 16.70 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.191257402031
# --- Progress: 3.60% --- 17.18 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.186593167763
# --- Progress: 3.70% --- 17.65 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.314149687622
# --- Progress: 3.80% --- 18.11 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.380127042481
# --- Progress: 3.90% --- 18.57 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.457325223128
# --- Progress: 4.00% --- 19.03 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.500797425342
# --- Progress: 4.10% --- 19.48 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.501149846848
# --- Progress: 4.20% --- 19.92 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.499908076339
# --- Progress: 4.30% --- 20.37 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.351187981772
# --- Progress: 4.40% --- 20.82 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.166991964093
# --- Progress: 4.50% --- 21.27 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.158422997263
# --- Progress: 4.60% --- 21.74 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.154709692729
# --- Progress: 4.70% --- 22.24 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.260801768671
# --- Progress: 4.80% --- 22.74 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.324165719215
# --- Progress: 4.90% --- 23.23 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.410276569475
# --- Progress: 5.00% --- 23.74 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.501121914729
# --- Progress: 5.10% --- 24.29 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.501031027097
# --- Progress: 5.20% --- 24.81 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501177656673
# --- Progress: 5.30% --- 25.33 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.499407282144
# --- Progress: 5.40% --- 25.85 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.421853982818
# --- Progress: 5.50% --- 26.38 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.29021945873
# --- Progress: 5.60% --- 26.92 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.170864142283
# --- Progress: 5.70% --- 27.43 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.140122409851
# --- Progress: 5.80% --- 27.94 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.147740688242
# --- Progress: 5.90% --- 28.46 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.162542850992
# --- Progress: 6.00% --- 28.99 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.50124553991
# --- Progress: 6.10% --- 29.49 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.500965895042
# --- Progress: 6.20% --- 29.98 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501557858449
# --- Progress: 6.30% --- 30.45 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.501192904717
# --- Progress: 6.40% --- 30.92 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.495108131913
# --- Progress: 6.50% --- 31.42 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.427126315463
# --- Progress: 6.60% --- 31.91 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.255192551185
# --- Progress: 6.70% --- 32.41 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.199420931413
# --- Progress: 6.80% --- 32.91 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.183896539142
# --- Progress: 6.90% --- 33.42 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.171213263971
# --- Progress: 7.00% --- 33.93 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.501175870348
# --- Progress: 7.10% --- 34.43 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.499875686358
# --- Progress: 7.20% --- 34.93 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.49986095275
# --- Progress: 7.30% --- 35.43 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.501767834226
# --- Progress: 7.40% --- 35.94 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.500946625082
# --- Progress: 7.50% --- 36.45 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.498718593937
# --- Progress: 7.60% --- 36.96 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.4947333632
# --- Progress: 7.70% --- 37.47 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.461956703318
# --- Progress: 7.80% --- 37.98 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.297012464839
# --- Progress: 7.90% --- 38.49 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.18286353855
# --- Progress: 8.00% --- 39.00 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.500874704808
# --- Progress: 8.10% --- 39.51 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.499734075593
# --- Progress: 8.20% --- 40.01 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.500332451248
# --- Progress: 8.30% --- 40.51 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.500508645025
# --- Progress: 8.40% --- 41.02 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.5010964359
# --- Progress: 8.50% --- 41.52 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.500099068987
# --- Progress: 8.60% --- 42.03 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.500146516053
# --- Progress: 8.70% --- 42.55 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.499611239829
# --- Progress: 8.80% --- 43.07 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.487078602791
# --- Progress: 8.90% --- 43.59 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.35415250374
# --- Progress: 9.00% --- 44.10 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.500527181996
# --- Progress: 9.10% --- 44.60 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.500441761718
# --- Progress: 9.20% --- 45.11 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.500810568794
# --- Progress: 9.30% --- 45.61 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.499744303619
# --- Progress: 9.40% --- 46.12 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.500606552
# --- Progress: 9.50% --- 46.62 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.499647541065
# --- Progress: 9.60% --- 47.13 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.500082899435
# --- Progress: 9.70% --- 47.65 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.499664477652
# --- Progress: 9.80% --- 48.16 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.498831070068
# --- Progress: 9.90% --- 48.66 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.487822950768
# --- Progress: 10.00% --- 49.17 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.370117282099
# --- Progress: 10.10% --- 49.68 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.491612466083
# --- Progress: 10.20% --- 50.19 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.50550769061
# --- Progress: 10.30% --- 50.72 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.505570797957
# --- Progress: 10.40% --- 51.25 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.504120977303
# --- Progress: 10.50% --- 51.77 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.508917672415
# --- Progress: 10.60% --- 52.30 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.508713228333
# --- Progress: 10.70% --- 52.83 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.504591851464
# --- Progress: 10.80% --- 53.35 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.507566272844
# --- Progress: 10.90% --- 53.87 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.502635234132
# --- Progress: 11.00% --- 54.38 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.406845867834
# --- Progress: 11.10% --- 54.89 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.197948344229
# --- Progress: 11.20% --- 55.40 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.222466284785
# --- Progress: 11.30% --- 55.92 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.43107713882
# --- Progress: 11.40% --- 56.45 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.47670819104
# --- Progress: 11.50% --- 56.97 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.498316236484
# --- Progress: 11.60% --- 57.50 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.499117212216
# --- Progress: 11.70% --- 58.03 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.503268209866
# --- Progress: 11.80% --- 58.55 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.502776546725
# --- Progress: 11.90% --- 59.07 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.503646592839
# --- Progress: 12.00% --- 59.60 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.496713220137
# --- Progress: 12.10% --- 60.11 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.340495304475
# --- Progress: 12.20% --- 60.63 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.1904707172
# --- Progress: 12.30% --- 61.11 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.175182627001
# --- Progress: 12.40% --- 61.56 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.281198206384
# --- Progress: 12.50% --- 62.03 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.32592717328
# --- Progress: 12.60% --- 62.48 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.47532167867
# --- Progress: 12.70% --- 62.95 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.452301129457
# --- Progress: 12.80% --- 63.40 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.498126295633
# --- Progress: 12.90% --- 63.86 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.503330706772
# --- Progress: 13.00% --- 64.31 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.50196522673
# --- Progress: 13.10% --- 64.75 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.485735153061
# --- Progress: 13.20% --- 65.17 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.324954733351
# --- Progress: 13.30% --- 65.61 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.204660749773
# --- Progress: 13.40% --- 66.04 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.163297904126
# --- Progress: 13.50% --- 66.48 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.158942508128
# --- Progress: 13.60% --- 66.92 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.230481741824
# --- Progress: 13.70% --- 67.36 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.305626709145
# --- Progress: 13.80% --- 67.81 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.398160677104
# --- Progress: 13.90% --- 68.26 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.424841372226
# --- Progress: 14.00% --- 68.71 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.50092293951
# --- Progress: 14.10% --- 69.14 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.500835159745
# --- Progress: 14.20% --- 69.57 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.451937718283
# --- Progress: 14.30% --- 70.00 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.384586818234
# --- Progress: 14.40% --- 70.43 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.226458654626
# --- Progress: 14.50% --- 70.87 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.138037878258
# --- Progress: 14.60% --- 71.31 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.142740893038
# --- Progress: 14.70% --- 71.74 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.125528586354
# --- Progress: 14.80% --- 72.18 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.156878547897
# --- Progress: 14.90% --- 72.62 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.399011831567
# --- Progress: 15.00% --- 73.06 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.501069087512
# --- Progress: 15.10% --- 73.49 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.500692560969
# --- Progress: 15.20% --- 73.92 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501264417697
# --- Progress: 15.30% --- 74.37 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.49317083914
# --- Progress: 15.40% --- 74.81 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.443047940984
# --- Progress: 15.50% --- 75.28 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.256648329852
# --- Progress: 15.60% --- 75.74 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.179066879536
# --- Progress: 15.70% --- 76.22 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.154715777012
# --- Progress: 15.80% --- 76.72 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.149128025309
# --- Progress: 15.90% --- 77.24 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.239793008962
# --- Progress: 16.00% --- 77.78 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.501292105132
# --- Progress: 16.10% --- 78.30 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.500475503956
# --- Progress: 16.20% --- 78.89 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.500860741639
# --- Progress: 16.30% --- 79.42 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.501110568149
# --- Progress: 16.40% --- 79.96 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.500410131505
# --- Progress: 16.50% --- 80.49 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.479923898317
# --- Progress: 16.60% --- 81.03 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.390147880608
# --- Progress: 16.70% --- 81.58 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.18609815937
# --- Progress: 16.80% --- 82.10 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.175611437311
# --- Progress: 16.90% --- 82.64 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.200229407622
# --- Progress: 17.00% --- 83.17 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.501366047965
# --- Progress: 17.10% --- 83.70 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.501172120991
# --- Progress: 17.20% --- 84.22 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.500424860042
# --- Progress: 17.30% --- 84.74 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.502222684117
# --- Progress: 17.40% --- 85.27 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.49980118377
# --- Progress: 17.50% --- 85.78 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.501757037828
# --- Progress: 17.60% --- 86.31 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.485561567092
# --- Progress: 17.70% --- 86.83 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.374065766709
# --- Progress: 17.80% --- 87.36 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.217017985292
# --- Progress: 17.90% --- 87.90 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.182186231395
# --- Progress: 18.00% --- 88.44 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.500450069737
# --- Progress: 18.10% --- 88.97 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.501485741138
# --- Progress: 18.20% --- 89.50 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.500815104279
# --- Progress: 18.30% --- 90.04 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.50152559606
# --- Progress: 18.40% --- 90.57 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.501751822971
# --- Progress: 18.50% --- 91.11 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.500717363618
# --- Progress: 18.60% --- 91.65 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.501329756817
# --- Progress: 18.70% --- 92.18 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.499889888274
# --- Progress: 18.80% --- 92.71 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.476628215059
# --- Progress: 18.90% --- 93.24 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.403785353141
# --- Progress: 19.00% --- 93.77 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.500866317021
# --- Progress: 19.10% --- 94.30 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.501055791977
# --- Progress: 19.20% --- 94.83 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501011131444
# --- Progress: 19.30% --- 95.35 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.501235848188
# --- Progress: 19.40% --- 95.88 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.500973459622
# --- Progress: 19.50% --- 96.39 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.500488092486
# --- Progress: 19.60% --- 96.85 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.500695674458
# --- Progress: 19.70% --- 97.32 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.500971607762
# --- Progress: 19.80% --- 97.79 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.496911934166
# --- Progress: 19.90% --- 98.28 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.500249624432
# --- Progress: 20.00% --- 98.78 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.359399480524
# --- Progress: 20.10% --- 99.27 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.486107298721
# --- Progress: 20.20% --- 99.77 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.506062141733
# --- Progress: 20.30% --- 100.27 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.50373857406
# --- Progress: 20.40% --- 100.78 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.501366057266
# --- Progress: 20.50% --- 101.29 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.505810118652
# --- Progress: 20.60% --- 101.79 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.505201336927
# --- Progress: 20.70% --- 102.30 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.501818988382
# --- Progress: 20.80% --- 102.83 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.506678426766
# --- Progress: 20.90% --- 103.38 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.503762778249
# --- Progress: 21.00% --- 103.92 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.40083583404
# --- Progress: 21.10% --- 104.45 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.217352992781
# --- Progress: 21.20% --- 104.99 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.217488358928
# --- Progress: 21.30% --- 105.54 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.43513783612
# --- Progress: 21.40% --- 106.08 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.477566832324
# --- Progress: 21.50% --- 106.65 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.499483266259
# --- Progress: 21.60% --- 107.21 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.504366851616
# --- Progress: 21.70% --- 107.77 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.500670431888
# --- Progress: 21.80% --- 108.33 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.505294140023
# --- Progress: 21.90% --- 108.90 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.504996063424
# --- Progress: 22.00% --- 109.46 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.494092328014
# --- Progress: 22.10% --- 110.01 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.321848885364
# --- Progress: 22.20% --- 110.57 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.179500026338
# --- Progress: 22.30% --- 111.12 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.150260549459
# --- Progress: 22.40% --- 111.67 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.235984357529
# --- Progress: 22.50% --- 112.21 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.327370091345
# --- Progress: 22.60% --- 112.76 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.36325912076
# --- Progress: 22.70% --- 113.31 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.459642980116
# --- Progress: 22.80% --- 113.85 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.476979155175
# --- Progress: 22.90% --- 114.36 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.479781169161
# --- Progress: 23.00% --- 114.85 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.501694506682
# --- Progress: 23.10% --- 115.36 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.459816339997
# --- Progress: 23.20% --- 115.86 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.302198774628
# --- Progress: 23.30% --- 116.35 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.189503254186
# --- Progress: 23.40% --- 116.85 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.1434744184
# --- Progress: 23.50% --- 117.53 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.199027895641
# --- Progress: 23.60% --- 118.06 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.187509899458
# --- Progress: 23.70% --- 118.59 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.37217534317
# --- Progress: 23.80% --- 119.12 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.417430936627
# --- Progress: 23.90% --- 119.64 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.383825336947
# --- Progress: 24.00% --- 120.18 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.502900292114
# --- Progress: 24.10% --- 120.70 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.502066028918
# --- Progress: 24.20% --- 121.23 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.492508477966
# --- Progress: 24.30% --- 121.75 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.367510496871
# --- Progress: 24.40% --- 122.28 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.187960071385
# --- Progress: 24.50% --- 122.82 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.166802477105
# --- Progress: 24.60% --- 123.35 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.169588289629
# --- Progress: 24.70% --- 123.87 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.169404818899
# --- Progress: 24.80% --- 124.41 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.28632039848
# --- Progress: 24.90% --- 124.95 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.434830255297
# --- Progress: 25.00% --- 125.51 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.502493592115
# --- Progress: 25.10% --- 126.06 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.501343075074
# --- Progress: 25.20% --- 126.61 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.50125973033
# --- Progress: 25.30% --- 127.15 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.495204109266
# --- Progress: 25.40% --- 127.71 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.441889632668
# --- Progress: 25.50% --- 128.29 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.286547837325
# --- Progress: 25.60% --- 128.87 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.170818271386
# --- Progress: 25.70% --- 129.44 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.171626841187
# --- Progress: 25.80% --- 130.01 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.222775965384
# --- Progress: 25.90% --- 130.58 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.132047532062
# --- Progress: 26.00% --- 131.15 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.502197726181
# --- Progress: 26.10% --- 131.70 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.501383095939
# --- Progress: 26.20% --- 132.24 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.50105366725
# --- Progress: 26.30% --- 132.79 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.501791420345
# --- Progress: 26.40% --- 133.33 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.502725912399
# --- Progress: 26.50% --- 133.88 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.473716959318
# --- Progress: 26.60% --- 134.43 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.406888722522
# --- Progress: 26.70% --- 134.96 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.205675871388
# --- Progress: 26.80% --- 135.51 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.144813111746
# --- Progress: 26.90% --- 136.06 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.169799735784
# --- Progress: 27.00% --- 136.61 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.501762105791
# --- Progress: 27.10% --- 137.15 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.501166499502
# --- Progress: 27.20% --- 137.70 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501179231832
# --- Progress: 27.30% --- 138.24 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.501470278041
# --- Progress: 27.40% --- 138.80 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.501703114705
# --- Progress: 27.50% --- 139.34 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.494709409924
# --- Progress: 27.60% --- 139.88 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.476205006048
# --- Progress: 27.70% --- 140.43 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.397916190764
# --- Progress: 27.80% --- 140.98 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.321940293063
# --- Progress: 27.90% --- 141.53 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.214128784733
# --- Progress: 28.00% --- 142.06 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.50123026004
# --- Progress: 28.10% --- 142.57 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.50091948784
# --- Progress: 28.20% --- 143.07 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501391554351
# --- Progress: 28.30% --- 143.57 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.501494493457
# --- Progress: 28.40% --- 144.07 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.501819101438
# --- Progress: 28.50% --- 144.57 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.501579309851
# --- Progress: 28.60% --- 145.08 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.501512834088
# --- Progress: 28.70% --- 145.58 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.497991191031
# --- Progress: 28.80% --- 146.09 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.448695999867
# --- Progress: 28.90% --- 146.60 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.465086244519
# --- Progress: 29.00% --- 147.12 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.500533563246
# --- Progress: 29.10% --- 147.64 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.500777067873
# --- Progress: 29.20% --- 148.16 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501276821587
# --- Progress: 29.30% --- 148.72 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.500997110486
# --- Progress: 29.40% --- 149.28 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.501148279405
# --- Progress: 29.50% --- 149.83 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.500942633223
# --- Progress: 29.60% --- 150.39 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.500636502318
# --- Progress: 29.70% --- 150.94 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.501565336444
# --- Progress: 29.80% --- 151.49 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.500372221505
# --- Progress: 29.90% --- 152.04 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.493662062213
# --- Progress: 30.00% --- 152.59 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.353255435745
# --- Progress: 30.10% --- 153.11 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.500942888772
# --- Progress: 30.20% --- 153.60 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.505947536414
# --- Progress: 30.30% --- 154.12 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.504578182122
# --- Progress: 30.40% --- 154.65 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.506169767821
# --- Progress: 30.50% --- 155.19 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.507225343786
# --- Progress: 30.60% --- 155.72 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.504764032879
# --- Progress: 30.70% --- 156.25 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.502934618474
# --- Progress: 30.80% --- 156.75 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.509366487981
# --- Progress: 30.90% --- 157.26 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.502898351253
# --- Progress: 31.00% --- 157.76 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.422255903512
# --- Progress: 31.10% --- 158.32 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.202884949056
# --- Progress: 31.20% --- 158.85 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.235764945776
# --- Progress: 31.30% --- 159.38 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.446629030002
# --- Progress: 31.40% --- 159.91 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.429547875426
# --- Progress: 31.50% --- 160.49 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.501803642994
# --- Progress: 31.60% --- 161.04 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.49825140732
# --- Progress: 31.70% --- 161.57 minutes ---
# ...
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.500910716767
# --- Progress: 89.60% --- 450.05 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.500184309777
# --- Progress: 89.70% --- 450.54 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.500292210665
# --- Progress: 89.80% --- 451.02 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.500721651916
# --- Progress: 89.90% --- 451.48 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.50021237047
# --- Progress: 90.00% --- 451.93 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.352010164858
# --- Progress: 90.10% --- 452.36 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.487285736039
# --- Progress: 90.20% --- 452.79 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.504153044729
# --- Progress: 90.30% --- 453.24 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.50232910516
# --- Progress: 90.40% --- 453.68 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.503048437484
# --- Progress: 90.50% --- 454.13 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.502835662941
# --- Progress: 90.60% --- 454.61 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.503455251093
# --- Progress: 90.70% --- 455.09 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.504459351441
# --- Progress: 90.80% --- 455.57 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.504660544276
# --- Progress: 90.90% --- 456.04 minutes ---
# Neurons: 300 Leak-rate: 0.1 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.501217431498
# --- Progress: 91.00% --- 456.51 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.401730023771
# --- Progress: 91.10% --- 456.97 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.198572443852
# --- Progress: 91.20% --- 457.42 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.21851967783
# --- Progress: 91.30% --- 457.85 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.386483058167
# --- Progress: 91.40% --- 458.28 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.490582668519
# --- Progress: 91.50% --- 458.71 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.494657651936
# --- Progress: 91.60% --- 459.15 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.501757269309
# --- Progress: 91.70% --- 459.59 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.500170149188
# --- Progress: 91.80% --- 460.02 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.50193830712
# --- Progress: 91.90% --- 460.46 minutes ---
# Neurons: 300 Leak-rate: 0.255555555556 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.502354530754
# --- Progress: 92.00% --- 460.90 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.503710251999
# --- Progress: 92.10% --- 461.32 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.327427330078
# --- Progress: 92.20% --- 461.74 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.195687990459
# --- Progress: 92.30% --- 462.17 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.155376203727
# --- Progress: 92.40% --- 462.60 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.241282723026
# --- Progress: 92.50% --- 463.03 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.311663961835
# --- Progress: 92.60% --- 463.46 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.386834595211
# --- Progress: 92.70% --- 463.89 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.442967789333
# --- Progress: 92.80% --- 464.32 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.498664483147
# --- Progress: 92.90% --- 464.77 minutes ---
# Neurons: 300 Leak-rate: 0.411111111111 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.493653678983
# --- Progress: 93.00% --- 465.20 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.503983990819
# --- Progress: 93.10% --- 465.63 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.478480479332
# --- Progress: 93.20% --- 466.05 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.290676110728
# --- Progress: 93.30% --- 466.47 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.200401445333
# --- Progress: 93.40% --- 466.90 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.155739847551
# --- Progress: 93.50% --- 467.33 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.189799268364
# --- Progress: 93.60% --- 467.76 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.222229561738
# --- Progress: 93.70% --- 468.19 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.29818253098
# --- Progress: 93.80% --- 468.62 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.417579655919
# --- Progress: 93.90% --- 469.06 minutes ---
# Neurons: 300 Leak-rate: 0.566666666667 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.422863035871
# --- Progress: 94.00% --- 469.49 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.501448528068
# --- Progress: 94.10% --- 469.91 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.500873676472
# --- Progress: 94.20% --- 470.33 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.49562380672
# --- Progress: 94.30% --- 470.76 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.387936956516
# --- Progress: 94.40% --- 471.18 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.266537954381
# --- Progress: 94.50% --- 471.60 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.162117278595
# --- Progress: 94.60% --- 472.03 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.167495900366
# --- Progress: 94.70% --- 472.46 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.157876294962
# --- Progress: 94.80% --- 472.88 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.224215685978
# --- Progress: 94.90% --- 473.32 minutes ---
# Neurons: 300 Leak-rate: 0.722222222222 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.368649727319
# --- Progress: 95.00% --- 473.75 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.501716102604
# --- Progress: 95.10% --- 474.17 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.501569872856
# --- Progress: 95.20% --- 474.61 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501557563498
# --- Progress: 95.30% --- 475.03 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.497267897614
# --- Progress: 95.40% --- 475.45 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.451513073739
# --- Progress: 95.50% --- 475.88 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.288351193314
# --- Progress: 95.60% --- 476.31 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.179459534247
# --- Progress: 95.70% --- 476.74 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.152127084698
# --- Progress: 95.80% --- 477.17 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.1383413362
# --- Progress: 95.90% --- 477.59 minutes ---
# Neurons: 300 Leak-rate: 0.877777777778 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.254711635509
# --- Progress: 96.00% --- 478.02 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.501135097306
# --- Progress: 96.10% --- 478.45 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.501812573922
# --- Progress: 96.20% --- 478.87 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501448600013
# --- Progress: 96.30% --- 479.29 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.502148924774
# --- Progress: 96.40% --- 479.71 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.501375610186
# --- Progress: 96.50% --- 480.14 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.401376505501
# --- Progress: 96.60% --- 480.56 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.307207845509
# --- Progress: 96.70% --- 480.98 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.293026213695
# --- Progress: 96.80% --- 481.41 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.161918169003
# --- Progress: 96.90% --- 481.85 minutes ---
# Neurons: 300 Leak-rate: 1.03333333333 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.154921344177
# --- Progress: 97.00% --- 482.28 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.500723208188
# --- Progress: 97.10% --- 482.70 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.502463367245
# --- Progress: 97.20% --- 483.12 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501251285417
# --- Progress: 97.30% --- 483.55 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.502525051168
# --- Progress: 97.40% --- 483.97 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.501553515796
# --- Progress: 97.50% --- 484.40 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.494936300521
# --- Progress: 97.60% --- 484.82 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.471223163296
# --- Progress: 97.70% --- 485.25 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.413111458467
# --- Progress: 97.80% --- 485.68 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.382008658307
# --- Progress: 97.90% --- 486.10 minutes ---
# Neurons: 300 Leak-rate: 1.18888888889 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.205443551029
# --- Progress: 98.00% --- 486.53 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.502115190769
# --- Progress: 98.10% --- 486.95 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.501018753568
# --- Progress: 98.20% --- 487.38 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501469291336
# --- Progress: 98.30% --- 487.80 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.501233461103
# --- Progress: 98.40% --- 488.22 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.501343321104
# --- Progress: 98.50% --- 488.65 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.501080935736
# --- Progress: 98.60% --- 489.08 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.501556321535
# --- Progress: 98.70% --- 489.51 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.48994103418
# --- Progress: 98.80% --- 489.96 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.457362168467
# --- Progress: 98.90% --- 490.39 minutes ---
# Neurons: 300 Leak-rate: 1.34444444444 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.367750967289
# --- Progress: 99.00% --- 490.82 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.1 Delta_t: 0.1
# Testing error
# 0.500486083281
# --- Progress: 99.10% --- 491.26 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.311111111111 Delta_t: 0.1
# Testing error
# 0.500554785199
# --- Progress: 99.20% --- 491.72 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.522222222222 Delta_t: 0.1
# Testing error
# 0.501446471986
# --- Progress: 99.30% --- 492.16 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.733333333333 Delta_t: 0.1
# Testing error
# 0.50034125388
# --- Progress: 99.40% --- 492.59 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 0.944444444444 Delta_t: 0.1
# Testing error
# 0.501901578977
# --- Progress: 99.50% --- 493.04 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.15555555556 Delta_t: 0.1
# Testing error
# 0.501091470138
# --- Progress: 99.60% --- 493.47 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.36666666667 Delta_t: 0.1
# Testing error
# 0.501350307663
# --- Progress: 99.70% --- 493.93 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.57777777778 Delta_t: 0.1
# Testing error
# 0.501169501907
# --- Progress: 99.80% --- 494.40 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 1.78888888889 Delta_t: 0.1
# Testing error
# 0.501617172902
# --- Progress: 99.90% --- 494.85 minutes ---
# Neurons: 300 Leak-rate: 1.5 Spectral-radius: 2.0 Delta_t: 0.1
# Testing error
# 0.488535083478
# --- Progress: 100.00% --- 495.30 minutes ---
# Total time for Testbench:
# --- 29718.17 seconds ---
# --- 495.30 minutes ---

# %%
import pickle
#### Save Data
with open('dataNewClassSameParametersErrorsAveraged10withShiftScaleLargeValues.p','wb') as outputFile:
    pickle.dump(delta_t_error,outputFile)
    pickle.dump(num_neurons_slow, outputFile)
    pickle.dump(num_neurons_fast, outputFile)
    pickle.dump(delta_t, outputFile)
    pickle.dump(l_rate, outputFile)
    pickle.dump(sp_rad, outputFile)
#### Load Data
# with open('dataNewClassSameLeakAndSpectErrorsAveraged10.p', 'rb') as inputFile:
#     delta_t_error = pickle.load(inputFile)
#     num_neurons_slow = pickle.load(inputFile)
#     num_neurons_fast = pickle.load(inputFile)
#     delta_t = pickle.load(inputFile)
#     l_rate = pickle.load(inputFile)
#     sp_rad = pickle.load(inputFile)

# %%
### Errors
import numpy as np
from matplotlib import pyplot
# %matplotlib inline
xx, yy = np.meshgrid(l_rate, sp_rad)
pyplot.figure(figsize=(10,6))
pyplot.subplot(111)
pyplot.contourf(xx,
                yy,delta_t_error[0].reshape(10,10).T,30)
# pyplot.title("Slow and fast trained using the same parameters averaged over 10 trials")
pyplot.xlabel("Leak-rate")
pyplot.ylabel("Spectral-radius")
cbar = pyplot.colorbar()
cbar.ax.set_title('Test error')
print("Best Error:", np.min(delta_t_error[0]))
print("with leak-rate",l_rate[np.argmin(delta_t_error[0].reshape(10,10).T)%10])
print("with sp_rad",sp_rad[np.argmin(delta_t_error[0].reshape(10,10).T)/10])
# Out:
# Best Error: 0.146790211071
# with leak-rate 0.877777777778
# with sp_rad 1.57777777778
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:17: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
