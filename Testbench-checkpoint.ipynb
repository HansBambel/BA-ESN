# %%
import Parity_Data_Generator
import InputToParityESN
# import ParityToOutputESN
import numpy as np
from pyESN import ESN
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
import time

start_time = time.time()
rng = np.random.RandomState(42)

N = 50000   # number of datapoints
n = 3       # n-parity
# produce Data
bits, parity, target = Parity_Data_Generator.generateParityData(N, n, randomstate=rng)

# Divide in training and test data
traintest_cutoff = int(np.ceil(0.7 * len(bits)))
train_bits, test_bits = bits[:traintest_cutoff], bits[traintest_cutoff:]
train_parity, test_parity = parity[:traintest_cutoff], parity[traintest_cutoff:]
train_targets, test_targets = target[:traintest_cutoff], target[traintest_cutoff:]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 148.84233260154724 seconds ---

# %%
def runSomeConfigs(spectral_rad, leak_r,num_neurons=500):
#     print("Spectral-radius:",spectral_rad, "leak-rate:", leak_r)
    nParityESN = ESN(n_inputs=1,
                          n_outputs=1,
                          n_reservoir=num_neurons,  # from 200 onwards test error decreases significantly
                          spectral_radius=spectral_rad,  # from 0.9 the test error is 0.0
                          leak_rate= leak_r,   # adjust leak_rate
                          sparsity=0.95,
                          noise=0.001,
                          input_shift=0,
                          input_scaling=3,  # 3 seems to be fine. Maybe use lower
                          teacher_scaling=1.12,
                          teacher_shift=-0.7,
                          out_activation=np.tanh,
                          inverse_out_activation=np.arctanh,
                          random_state=rng,
                          silent=False)
    # print(np.shape(bits),np.shape(parity),np.shape(target))
    nParityESN.fit(train_bits, train_parity)
    pred_test = nParityESN.predict(test_bits)

    #### Rounding
    better_pred_test = []           # Maybe don't round and return "true" results from pred_test
    for x in pred_test:
        better_pred_test.append(0 if x < 0.5 else 1)
    predictedParity = np.array(better_pred_test).reshape(-1,1)

    print("Testing error")
    test_error = np.sqrt(np.mean((predictedParity - test_parity) ** 2))
    print(test_error)
    return test_error

# %%
# num_neurons = [500, 600, 700, 800, 900, 1000]
num_neurons = [500]
sp_rad = np.linspace(0.1, 1.0, num=7)
l_rate = np.linspace(0.1, 1.0, num=7)

run_time = time.time()
errors = np.zeros((len(l_rate),len(sp_rad)))

for n in num_neurons:
    for i,l in enumerate(l_rate):
        for j,s in enumerate(sp_rad):
            print("Neurons:", n, "Spectral-radius:", s, "Leak-rate:", l)
            errors[i][j] = runSomeConfigs(s,l,n)
            print("--- %s minutes ---" % (((time.time() - run_time)/60)))
        
plt.imshow(errors, interpolation="nearest", origin="upper")
plt.xlabel("leak-rate")
plt.ylabel("spectral-radius")
plt.colorbar()
plt.show()

print("Total time for Testbench:")
print("--- %s seconds ---" % (time.time() - run_time))
print("--- %s minutes ---" % (((time.time() - run_time)/60)))
print("--- %s hours ---" % (((time.time() - run_time)/3600)))
# Out:
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.162333760652
# Testing error
# 0.701707441412
# --- 2.413364617029826 minutes ---
# Neurons: 500 Spectral-radius: 0.25 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.144489456266
# Testing error
# 0.702616538376
# --- 4.7760757605234785 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.129781959352
# Testing error
# 0.70270904363
# --- 7.137849152088165 minutes ---
# Neurons: 500 Spectral-radius: 0.55 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.122108023919
# Testing error
# 0.702713787161
# --- 9.671464947859446 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.117986163135
# Testing error
# 0.70270904363
# --- 12.266028181711834 minutes ---
# Neurons: 500 Spectral-radius: 0.85 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.113666794203
# Testing error
# 0.685519267903
# --- 14.839614697297414 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.1
# harvesting states...
# fitting...
# training error:
# 0.116538363654
# Testing error
# 0.596109609608
# --- 17.418732221921285 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.25
# harvesting states...
# fitting...
# training error:
# 0.140038191623
# Testing error
# 0.710265208684
# --- 19.95793724457423 minutes ---
# Neurons: 500 Spectral-radius: 0.25 Leak-rate: 0.25
# harvesting states...
# fitting...
# training error:
# 0.13764617272
# Testing error
# 0.670668820407
# --- 22.538690265019735 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.25
# harvesting states...
# fitting...
# training error:
# 0.136333172992
# Testing error
# 0.679252039624
# --- 25.118272709846497 minutes ---
# Neurons: 500 Spectral-radius: 0.55 Leak-rate: 0.25
# harvesting states...
# fitting...
# training error:
# 0.133113358313
# Testing error
# 0.70270904363
# --- 27.717691191037495 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.25
# harvesting states...
# fitting...
# training error:
# 0.127657776797
# Testing error
# 0.700235674612
# --- 30.287773609161377 minutes ---
# Neurons: 500 Spectral-radius: 0.85 Leak-rate: 0.25
# harvesting states...
# fitting...
# training error:
# 0.121264727811
# Testing error
# 0.750735195214
# --- 32.886962151527406 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.25
# harvesting states...
# fitting...
# training error:
# 0.115616334545
# Testing error
# 0.714434508312
# --- 35.50732456843058 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.137232163855
# Testing error
# 0.705802144136
# --- 38.137211537361146 minutes ---
# Neurons: 500 Spectral-radius: 0.25 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.136551632772
# Testing error
# 0.685422011124
# --- 40.73234328826268 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.136354021111
# Testing error
# 0.720062497288
# --- 43.31377752224604 minutes ---
# Neurons: 500 Spectral-radius: 0.55 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.13599941471
# Testing error
# 0.725853520577
# --- 45.893662031491594 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.134458529886
# Testing error
# 0.699180472649
# --- 48.49858208100001 minutes ---
# Neurons: 500 Spectral-radius: 0.85 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.130962024584
# Testing error
# 0.703756586707
# --- 51.14052110115687 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.4
# harvesting states...
# fitting...
# training error:
# 0.125996010641
# Testing error
# 0.695818462915
# --- 53.79364005327225 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.55
# harvesting states...
# fitting...
# training error:
# 0.136943368241
# Testing error
# 0.709196728701
# --- 56.430194862683614 minutes ---
# Neurons: 500 Spectral-radius: 0.25 Leak-rate: 0.55
# harvesting states...
# fitting...
# training error:
# 0.136664581
# Testing error
# 0.709419950852
# --- 59.05906802018483 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.55
# harvesting states...
# fitting...
# training error:
# 0.136458795875
# Testing error
# 0.708707744184
# --- 61.6758766969045 minutes ---
# Neurons: 500 Spectral-radius: 0.55 Leak-rate: 0.55
# harvesting states...
# fitting...
# training error:
# 0.136286191583
# Testing error
# 0.715837504838
# --- 64.30150333642959 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.55
# harvesting states...
# fitting...
# training error:
# 0.135935901376
# Testing error
# 0.711477336252
# --- 66.915007797877 minutes ---
# Neurons: 500 Spectral-radius: 0.85 Leak-rate: 0.55
# harvesting states...
# fitting...
# training error:
# 0.135052918038
# Testing error
# 0.711493733868
# --- 69.55970975955327 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.55
# harvesting states...
# fitting...
# training error:
# 0.128684836825
# Testing error
# 0.709365914039
# --- 72.197192410628 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.136875674374
# Testing error
# 0.709361214991
# --- 74.80372337500255 minutes ---
# Neurons: 500 Spectral-radius: 0.25 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.136779670743
# Testing error
# 0.708825319337
# --- 77.411436855793 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.136645903484
# Testing error
# 0.709619616414
# --- 80.10450175205867 minutes ---
# Neurons: 500 Spectral-radius: 0.55 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.136475893631
# Testing error
# 0.716903061787
# --- 82.74551697174708 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.136125997915
# Testing error
# 0.669362881154
# --- 85.35587706168492 minutes ---
# Neurons: 500 Spectral-radius: 0.85 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.135282806008
# Testing error
# 0.691932077591
# --- 87.96083700656891 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.7
# harvesting states...
# fitting...
# training error:
# 0.133320583309
# Testing error
# 0.708978137886
# --- 90.58766282002131 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 0.85
# harvesting states...
# fitting...
# training error:
# 0.136895920042
# Testing error
# 0.703059978475
# --- 93.19458900292715 minutes ---
# Neurons: 500 Spectral-radius: 0.25 Leak-rate: 0.85
# harvesting states...
# fitting...
# training error:
# 0.136830470586
# Testing error
# 0.702713787161
# --- 95.83114699920019 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 0.85
# harvesting states...
# fitting...
# training error:
# 0.136749969971
# Testing error
# 0.702931954981
# --- 98.43256313403448 minutes ---
# Neurons: 500 Spectral-radius: 0.55 Leak-rate: 0.85
# harvesting states...
# fitting...
# training error:
# 0.136618647378
# Testing error
# 0.680874437764
# --- 101.05798812309901 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 0.85
# harvesting states...
# fitting...
# training error:
# 0.136362411695
# Testing error
# 0.709450491578
# --- 103.66194683710734 minutes ---
# Neurons: 500 Spectral-radius: 0.85 Leak-rate: 0.85
# harvesting states...
# fitting...
# training error:
# 0.135374074861
# Testing error
# 0.69668979228
# --- 106.28755726416905 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 0.85
# harvesting states...
# fitting...
# training error:
# 0.133020802652
# Testing error
# 0.736118197031
# --- 108.88756086031596 minutes ---
# Neurons: 500 Spectral-radius: 0.1 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.136918973778
# Testing error
# 0.708291371306
# --- 111.47674430211386 minutes ---
# Neurons: 500 Spectral-radius: 0.25 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.13688238621
# Testing error
# 0.708797103079
# --- 114.06014753977458 minutes ---
# Neurons: 500 Spectral-radius: 0.4 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.136824011654
# Testing error
# 0.703064719638
# --- 116.62042566935222 minutes ---
# Neurons: 500 Spectral-radius: 0.55 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.136726301865
# Testing error
# 0.712441810489
# --- 119.2050762295723 minutes ---
# Neurons: 500 Spectral-radius: 0.7 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.136499807302
# Testing error
# 0.741343375232
# --- 121.80168240070343 minutes ---
# Neurons: 500 Spectral-radius: 0.85 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.133606823644
# Testing error
# 0.736211020474
# --- 124.3886900862058 minutes ---
# Neurons: 500 Spectral-radius: 1.0 Leak-rate: 1.0
# harvesting states...
# fitting...
# training error:
# 0.129033016616
# Testing error
# 0.709809833688
# --- 126.96173910697301 minutes ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ba4fef21a22e> in <module>()
#      14             print("--- %s minutes ---" % (((time.time() - run_time)/60)))
#      15
# ---> 16 plt.imshow(errors, interpolation="nearest", origin="upper")
#      17 plt.xlabel("leak-rate")
#      18 plt.ylabel("spectral-radius")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # plt.subplot(111)
# # plt.plot(errors)
# # plt.show()
# from matplotlib import cm
# from matplotlib.ticker import LinearLocator, FormatStrFormatter
# import random
#
# sp_rad = np.linspace(0.1, 1.0, num=7)
# l_rate = np.linspace(0.1, 1.0, num=7)
# errors = np.zeros((len(l_rate),len(sp_rad)))
# for i,l in enumerate(l_rate):
#     for j,s in enumerate(sp_rad):
#         errors[i][j] = random.randint(-5,6)
# print(sp_rad)
# print(l_rate)
# print(errors)
# l_rate, sp_rad = np.meshgrid(l_rate, sp_rad)
#
# fig = plt.figure()
# ax = fig.gca(projection='3d')
#
# surf = ax.plot_surface(l_rate, sp_rad, errors, cmap=cm.coolwarm,
#                        linewidth=0, antialiased=False)
#
# # Customize the z axis.
# # ax.set_zlim(-0.01, 2.01)
# ax.zaxis.set_major_locator(LinearLocator(10))
# ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
#
# # Add a color bar which maps values to colors.
# fig.colorbar(surf, shrink=0.5, aspect=5)
#
# plt.show()

# %% [markdown]
# print("### Input-->Parity ###")
# run_time = time.time()
# # get good configs for a slow ESN
# nParityESN = ESN(n_inputs=1,
#                           n_outputs=1,
#                           n_reservoir=500,  # from 200 onwards test error decreases significantly
#                           spectral_radius=0.95,  # from 0.9 the test error is 0.0
#                           leak_rate= 0.5,   # adjust leak_rate
#                           sparsity=0.95,
#                           noise=0.001,
#                           input_shift=0,
#                           input_scaling=3,  # 3 seems to be fine. Maybe use lower
#                           teacher_scaling=1.12,
#                           teacher_shift=-0.7,
#                           out_activation=np.tanh,
#                           inverse_out_activation=np.arctanh,
#                           random_state=rng,
#                           silent=False)
# # print(np.shape(bits),np.shape(parity),np.shape(target))
# nParityESN.fit(train_bits, train_parity)
# pred_test = nParityESN.predict(test_bits)
#
# #### Rounding
# better_pred_test = []           # Maybe don't round and return "true" results from pred_test
# for x in pred_test:
#     better_pred_test.append(0 if x < 0.5 else 1)
# predictedParity = np.array(better_pred_test).reshape(-1,1)
#
# print("Testing error")
# print(np.sqrt(np.mean((predictedParity - test_parity) ** 2)))
#
# print("--- %s seconds ---" % (time.time() - run_time))
# print("--- %s minutes ---" % (((time.time() - run_time)/60)))
